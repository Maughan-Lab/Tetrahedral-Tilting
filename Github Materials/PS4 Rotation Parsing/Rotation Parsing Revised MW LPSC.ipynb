# %%
#import necessary packages
import pandas as pd
from datetime import datetime, timedelta, timezone
import os
from PyEIS import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import csv
import glob
import statistics
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress
import math
from colour import Color
import re
import matplotlib.ticker as ticker
from matplotlib.ticker import FormatStrFormatter
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.ticker import AutoMinorLocator

from matplotlib.pyplot import rc

allSized=20
rc('text',usetex=True)
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']},size=allSized)
rc('text.latex', preamble=r'\usepackage{sfmath}')
plt.rc('font',   size=     allSized,**{'family':"sans-serif"})     # controls default text sizes
plt.rc('axes',   titlesize=allSized)     # fontsize of the axes title
plt.rc('axes',   labelsize=allSized)    # fontsize of the x and y labels
plt.rc('xtick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('ytick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('legend', fontsize= allSized)    # legend fontsize
plt.rc('figure', titlesize=allSized)  # fontsize of the figure title

# %%
# Function to calculate Euclidean distance between two points
def calculate_distance(coord1, coord2):
    return math.sqrt((coord1[0] - coord2[0])**2 + (coord1[1] - coord2[1])**2 + (coord1[2] - coord2[2])**2)


def cartesian_to_spherical(x, y, z):
    r = np.sqrt(x**2 + y**2 + z**2)
    theta = np.arccos(z / r) if r != 0 else 0  # θ: angle from z-axis
    phi = np.arctan2(y, x)  # φ: angle from x-axis in the xy-plane
    return r, np.degrees(theta), np.degrees(phi)

# %%
start_file="C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Python Processed Str/Consolidated strs/3by3/Li6PS5Cl_P1_dualLi_limited rotation_beqpdfgui_site disorder_Lioccref.txt"

end_file="C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/PDF SA_ Joint Refinement working copy/MW LPSC/Full Joint Refinement/6_28_2024_Cl_MW_3by3_Joint_Lorchdamping_Lioccref.inp"

material=r'MW Li$_6$PS$_5$Cl'

datacolor='#39f'

lattice_param=29.572655

#filter non-alphanumeric and space characters from the material name so that it's easier to deal with from a file management perspective
cleaned_matname = filter(lambda x: x.isalnum() or x.isspace(), material)

# filter returns a generator, so we need to re-join the string
cleaned_matname = "".join(cleaned_matname)

print(cleaned_matname)

saveloc='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/Paper Plotting/PS4 Rotations and cifs/rotation plots'
# Out:
# MW Li6PS5Cl

# %%
start_coordinates={}

# Regular expression pattern to match the lines with start_coordinates
pattern = re.compile(r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.-]+)\s+y\s+([\d.-]+)\s+z\s+([\d.-]+)")

# Open the file and process each line
with open(start_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)

# Example: Accessing the start_coordinates for a specific thiophosphate unit
example_unit = 1
print(f"start_coordinates for P{example_unit}: {start_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"start_coordinates for S{example_unit}{i}: {start_coordinates[example_unit]['S'][i]}")
# Out:
# start_coordinates for P1: (0.25, 0.25, 0.083333)
# start_coordinates for S11: (0.29, 0.21, 0.12333)
# start_coordinates for S12: (0.21, 0.29, 0.12333)
# start_coordinates for S13: (0.29, 0.29, 0.04333)
# start_coordinates for S14: (0.21, 0.21, 0.04333)

# %%
# Initialize the dictionary to store the end_coordinates
end_coordinates = {}

# Regular expression pattern to match the lines with end_coordinates, accounting for '_0.00000' or any number
pattern = re.compile(
    r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+\s+y\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+\s+z\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+"
)
# Open the file and process each line
with open(end_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)


# Example: Accessing the end_coordinates for a specific thiophosphate unit
example_unit = 50
print(f"end_coordinates for P{example_unit}: {end_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"end_coordinates for S{example_unit}{i}: {end_coordinates[example_unit]['S'][i]}")
# Out:
# end_coordinates for P50: (0.75, 0.58333, 0.58333)
# end_coordinates for S501: (0.79735, 0.62762, 0.5596)
# end_coordinates for S502: (0.7208, 0.55022, 0.53025)
# end_coordinates for S503: (0.78028, 0.53752, 0.62519)
# end_coordinates for S504: (0.70158, 0.61796, 0.6183)

# %%
# Dictionary to store closest sulfur pairs
closest_sulfur_pairs = {}

# Find the closest sulfur atom for each S1 from start to end units
for unit_number, start_sulfurs in start_coordinates.items():
    if 'S' in start_sulfurs:
        start_sulfur1_coords = start_sulfurs['S'].get(1)
        if start_sulfur1_coords:
            min_distance = float('inf')
            closest_sulfur = None
            for sulfur_number, end_sulfur_coords in end_coordinates[unit_number]['S'].items():
                distance = calculate_distance(start_sulfur1_coords, end_sulfur_coords)
                if distance < min_distance:
                    min_distance = distance
                    closest_sulfur = sulfur_number
            closest_sulfur_pairs[unit_number] = {
                'start_sulfur': start_sulfur1_coords,
                'closest_end_sulfur': closest_sulfur,
                'end_sulfur_coords': end_coordinates[unit_number]['S'][closest_sulfur],
                'distance': min_distance
            }

# Example: Print out the closest sulfur atom pairs
for unit, data in closest_sulfur_pairs.items():
    print(f"Unit {unit}:")
    print(f"  Start S{unit}1 Coordinates: {data['start_sulfur']}")
    print(f"  Closest End S{unit}{data['closest_end_sulfur']} Coordinates: {data['end_sulfur_coords']}")
    print(f"  Distance: {data['distance']:.5f}")
# Out:
# Unit 1:
#   Start S11 Coordinates: (0.29, 0.21, 0.12333)
#   Closest End S14 Coordinates: (0.29593, 0.223, 0.12725)
#   Distance: 0.01482
# Unit 2:
#   Start S21 Coordinates: (0.29, 0.29, 0.37667)
#   Closest End S21 Coordinates: (0.29365, 0.28073, 0.37288)
#   Distance: 0.01066
# Unit 3:
#   Start S31 Coordinates: (0.29, 0.29, 0.71)
#   Closest End S33 Coordinates: (0.28186, 0.2881, 0.70204)
#   Distance: 0.01154
# Unit 4:
#   Start S41 Coordinates: (0.21, 0.62333, 0.12333)
#   Closest End S41 Coordinates: (0.20763, 0.62078, 0.12295)
#   Distance: 0.00350
# Unit 5:
#   Start S51 Coordinates: (0.29, 0.62333, 0.37667)
#   Closest End S53 Coordinates: (0.29763, 0.61032, 0.37459)
#   Distance: 0.01523
# Unit 6:
#   Start S61 Coordinates: (0.29, 0.62333, 0.71)
#   Closest End S64 Coordinates: (0.285, 0.62176, 0.70455)
#   Distance: 0.00756
# Unit 7:
#   Start S71 Coordinates: (0.29, 0.87667, 0.12333)
#   Closest End S74 Coordinates: (0.29863, 0.88878, 0.12363)
#   Distance: 0.01487
# Unit 8:
#   Start S81 Coordinates: (0.21, 0.87667, 0.37667)
#   Closest End S81 Coordinates: (0.20662, 0.87543, 0.38225)
#   Distance: 0.00664
# Unit 9:
#   Start S91 Coordinates: (0.29, 0.87667, 0.79)
#   Closest End S94 Coordinates: (0.30142, 0.88111, 0.7793)
#   Distance: 0.01627
# Unit 10:
#   Start S101 Coordinates: (0.62333, 0.21, 0.12333)
#   Closest End S104 Coordinates: (0.62256, 0.20692, 0.12037)
#   Distance: 0.00434
# Unit 11:
#   Start S111 Coordinates: (0.62333, 0.29, 0.37667)
#   Closest End S111 Coordinates: (0.62017, 0.28932, 0.37349)
#   Distance: 0.00453
# Unit 12:
#   Start S121 Coordinates: (0.62333, 0.29, 0.71)
#   Closest End S121 Coordinates: (0.61928, 0.29511, 0.71206)
#   Distance: 0.00684
# Unit 13:
#   Start S131 Coordinates: (0.54333, 0.62333, 0.12333)
#   Closest End S134 Coordinates: (0.54644, 0.62771, 0.12124)
#   Distance: 0.00576
# Unit 14:
#   Start S141 Coordinates: (0.62333, 0.62333, 0.37667)
#   Closest End S141 Coordinates: (0.62557, 0.61185, 0.37008)
#   Distance: 0.01343
# Unit 15:
#   Start S151 Coordinates: (0.62333, 0.62333, 0.71)
#   Closest End S152 Coordinates: (0.62097, 0.60407, 0.69596)
#   Distance: 0.02395
# Unit 16:
#   Start S161 Coordinates: (0.62333, 0.87667, 0.12333)
#   Closest End S162 Coordinates: (0.62905, 0.88052, 0.12035)
#   Distance: 0.00751
# Unit 17:
#   Start S171 Coordinates: (0.62333, 0.95667, 0.37667)
#   Closest End S172 Coordinates: (0.62137, 0.95272, 0.37172)
#   Distance: 0.00663
# Unit 18:
#   Start S181 Coordinates: (0.62333, 0.87667, 0.79)
#   Closest End S182 Coordinates: (0.6273, 0.88686, 0.79411)
#   Distance: 0.01168
# Unit 19:
#   Start S191 Coordinates: (0.87667, 0.29, 0.12333)
#   Closest End S194 Coordinates: (0.88387, 0.29219, 0.12705)
#   Distance: 0.00839
# Unit 20:
#   Start S201 Coordinates: (0.87667, 0.21, 0.37667)
#   Closest End S202 Coordinates: (0.87765, 0.20885, 0.37728)
#   Distance: 0.00163
# Unit 21:
#   Start S211 Coordinates: (0.87667, 0.29, 0.79)
#   Closest End S211 Coordinates: (0.87528, 0.28356, 0.79391)
#   Distance: 0.00766
# Unit 22:
#   Start S221 Coordinates: (0.87667, 0.62333, 0.12333)
#   Closest End S222 Coordinates: (0.87945, 0.62258, 0.12625)
#   Distance: 0.00410
# Unit 23:
#   Start S231 Coordinates: (0.87667, 0.54333, 0.37667)
#   Closest End S234 Coordinates: (0.87127, 0.55108, 0.37585)
#   Distance: 0.00948
# Unit 24:
#   Start S241 Coordinates: (0.87667, 0.62333, 0.79)
#   Closest End S241 Coordinates: (0.8726, 0.62145, 0.78705)
#   Distance: 0.00537
# Unit 25:
#   Start S251 Coordinates: (0.95667, 0.87667, 0.12333)
#   Closest End S252 Coordinates: (0.9601, 0.87361, 0.11538)
#   Distance: 0.00918
# Unit 26:
#   Start S261 Coordinates: (0.87667, 0.87667, 0.37667)
#   Closest End S264 Coordinates: (0.87259, 0.87667, 0.38168)
#   Distance: 0.00646
# Unit 27:
#   Start S271 Coordinates: (0.87667, 0.87667, 0.71)
#   Closest End S271 Coordinates: (0.88026, 0.86666, 0.71933)
#   Distance: 0.01415
# Unit 28:
#   Start S281 Coordinates: (0.12333, 0.21, 0.29)
#   Closest End S284 Coordinates: (0.13045, 0.21439, 0.28577)
#   Distance: 0.00937
# Unit 29:
#   Start S291 Coordinates: (0.12333, 0.21, 0.62333)
#   Closest End S292 Coordinates: (0.11678, 0.2131, 0.63115)
#   Distance: 0.01066
# Unit 30:
#   Start S301 Coordinates: (0.12333, 0.29, 0.87667)
#   Closest End S301 Coordinates: (0.12442, 0.2864, 0.87478)
#   Distance: 0.00421
# Unit 31:
#   Start S311 Coordinates: (0.12333, 0.62333, 0.21)
#   Closest End S313 Coordinates: (0.11986, 0.623, 0.20687)
#   Distance: 0.00468
# Unit 32:
#   Start S321 Coordinates: (0.12333, 0.62333, 0.54333)
#   Closest End S322 Coordinates: (0.11748, 0.62524, 0.54038)
#   Distance: 0.00682
# Unit 33:
#   Start S331 Coordinates: (0.12333, 0.62333, 0.87667)
#   Closest End S331 Coordinates: (0.12186, 0.62689, 0.87945)
#   Distance: 0.00475
# Unit 34:
#   Start S341 Coordinates: (0.12333, 0.87667, 0.29)
#   Closest End S343 Coordinates: (0.12309, 0.88058, 0.2934)
#   Distance: 0.00519
# Unit 35:
#   Start S351 Coordinates: (0.12333, 0.87667, 0.62333)
#   Closest End S352 Coordinates: (0.12241, 0.87792, 0.62503)
#   Distance: 0.00230
# Unit 36:
#   Start S361 Coordinates: (0.12333, 0.87667, 0.95667)
#   Closest End S362 Coordinates: (0.10955, 0.86692, 0.95673)
#   Distance: 0.01688
# Unit 37:
#   Start S371 Coordinates: (0.37667, 0.29, 0.29)
#   Closest End S374 Coordinates: (0.37777, 0.27426, 0.30163)
#   Distance: 0.01960
# Unit 38:
#   Start S381 Coordinates: (0.37667, 0.29, 0.62333)
#   Closest End S382 Coordinates: (0.36928, 0.28375, 0.62052)
#   Distance: 0.01008
# Unit 39:
#   Start S391 Coordinates: (0.37667, 0.21, 0.87667)
#   Closest End S391 Coordinates: (0.37991, 0.21186, 0.87238)
#   Distance: 0.00569
# Unit 40:
#   Start S401 Coordinates: (0.37667, 0.62333, 0.29)
#   Closest End S401 Coordinates: (0.36563, 0.62102, 0.27724)
#   Distance: 0.01703
# Unit 41:
#   Start S411 Coordinates: (0.37667, 0.62333, 0.62333)
#   Closest End S414 Coordinates: (0.3717, 0.62079, 0.61996)
#   Distance: 0.00652
# Unit 42:
#   Start S421 Coordinates: (0.37667, 0.62333, 0.95667)
#   Closest End S423 Coordinates: (0.3687, 0.61627, 0.95383)
#   Distance: 0.01102
# Unit 43:
#   Start S431 Coordinates: (0.37667, 0.87667, 0.21)
#   Closest End S434 Coordinates: (0.37871, 0.87334, 0.21193)
#   Distance: 0.00436
# Unit 44:
#   Start S441 Coordinates: (0.37667, 0.87667, 0.54333)
#   Closest End S441 Coordinates: (0.37999, 0.88139, 0.53668)
#   Distance: 0.00880
# Unit 45:
#   Start S451 Coordinates: (0.37667, 0.87667, 0.87667)
#   Closest End S452 Coordinates: (0.37458, 0.87571, 0.88035)
#   Distance: 0.00434
# Unit 46:
#   Start S461 Coordinates: (0.71, 0.29, 0.29)
#   Closest End S462 Coordinates: (0.70894, 0.289, 0.2895)
#   Distance: 0.00154
# Unit 47:
#   Start S471 Coordinates: (0.71, 0.29, 0.62333)
#   Closest End S471 Coordinates: (0.71491, 0.29626, 0.62069)
#   Distance: 0.00838
# Unit 48:
#   Start S481 Coordinates: (0.79, 0.29, 0.87667)
#   Closest End S482 Coordinates: (0.78866, 0.2912, 0.87698)
#   Distance: 0.00183
# Unit 49:
#   Start S491 Coordinates: (0.71, 0.62333, 0.29)
#   Closest End S491 Coordinates: (0.7177, 0.63141, 0.28758)
#   Distance: 0.01142
# Unit 50:
#   Start S501 Coordinates: (0.71, 0.62333, 0.62333)
#   Closest End S504 Coordinates: (0.70158, 0.61796, 0.6183)
#   Distance: 0.01118
# Unit 51:
#   Start S511 Coordinates: (0.79, 0.62333, 0.87667)
#   Closest End S511 Coordinates: (0.79616, 0.62326, 0.88439)
#   Distance: 0.00988
# Unit 52:
#   Start S521 Coordinates: (0.79, 0.87667, 0.29)
#   Closest End S523 Coordinates: (0.78742, 0.87792, 0.29319)
#   Distance: 0.00429
# Unit 53:
#   Start S531 Coordinates: (0.79, 0.87667, 0.62333)
#   Closest End S533 Coordinates: (0.78015, 0.8724, 0.6269)
#   Distance: 0.01131
# Unit 54:
#   Start S541 Coordinates: (0.71, 0.87667, 0.87667)
#   Closest End S542 Coordinates: (0.70527, 0.87973, 0.87922)
#   Distance: 0.00618
# Unit 55:
#   Start S551 Coordinates: (0.21, 0.12333, 0.29)
#   Closest End S553 Coordinates: (0.21362, 0.12362, 0.29266)
#   Distance: 0.00450
# Unit 56:
#   Start S561 Coordinates: (0.21, 0.12333, 0.62333)
#   Closest End S564 Coordinates: (0.20811, 0.11558, 0.62775)
#   Distance: 0.00912
# Unit 57:
#   Start S571 Coordinates: (0.29, 0.12333, 0.87667)
#   Closest End S572 Coordinates: (0.30307, 0.11663, 0.88765)
#   Distance: 0.01834
# Unit 58:
#   Start S581 Coordinates: (0.29, 0.37667, 0.29)
#   Closest End S583 Coordinates: (0.28156, 0.37662, 0.29655)
#   Distance: 0.01068
# Unit 59:
#   Start S591 Coordinates: (0.29, 0.37667, 0.62333)
#   Closest End S591 Coordinates: (0.2833, 0.37107, 0.62307)
#   Distance: 0.00874
# Unit 60:
#   Start S601 Coordinates: (0.21, 0.37667, 0.87667)
#   Closest End S603 Coordinates: (0.20367, 0.38924, 0.87344)
#   Distance: 0.01444
# Unit 61:
#   Start S611 Coordinates: (0.29, 0.71, 0.29)
#   Closest End S611 Coordinates: (0.28082, 0.69913, 0.28507)
#   Distance: 0.01506
# Unit 62:
#   Start S621 Coordinates: (0.29, 0.71, 0.62333)
#   Closest End S624 Coordinates: (0.28474, 0.7052, 0.62274)
#   Distance: 0.00715
# Unit 63:
#   Start S631 Coordinates: (0.29, 0.79, 0.87667)
#   Closest End S634 Coordinates: (0.29545, 0.78516, 0.87839)
#   Distance: 0.00749
# Unit 64:
#   Start S641 Coordinates: (0.62333, 0.12333, 0.21)
#   Closest End S641 Coordinates: (0.62248, 0.11946, 0.20607)
#   Distance: 0.00558
# Unit 65:
#   Start S651 Coordinates: (0.62333, 0.12333, 0.54333)
#   Closest End S653 Coordinates: (0.6075, 0.14396, 0.5608)
#   Distance: 0.03133
# Unit 66:
#   Start S661 Coordinates: (0.62333, 0.12333, 0.87667)
#   Closest End S661 Coordinates: (0.6197, 0.12675, 0.87717)
#   Distance: 0.00501
# Unit 67:
#   Start S671 Coordinates: (0.62333, 0.37667, 0.29)
#   Closest End S671 Coordinates: (0.62671, 0.37745, 0.28671)
#   Distance: 0.00478
# Unit 68:
#   Start S681 Coordinates: (0.62333, 0.37667, 0.62333)
#   Closest End S684 Coordinates: (0.63599, 0.37869, 0.60682)
#   Distance: 0.02090
# Unit 69:
#   Start S691 Coordinates: (0.62333, 0.37667, 0.95667)
#   Closest End S694 Coordinates: (0.60303, 0.36263, 0.95487)
#   Distance: 0.02475
# Unit 70:
#   Start S701 Coordinates: (0.62333, 0.71, 0.29)
#   Closest End S703 Coordinates: (0.62753, 0.71283, 0.28785)
#   Distance: 0.00550
# Unit 71:
#   Start S711 Coordinates: (0.62333, 0.71, 0.62333)
#   Closest End S713 Coordinates: (0.61491, 0.70177, 0.62134)
#   Distance: 0.01194
# Unit 72:
#   Start S721 Coordinates: (0.62333, 0.79, 0.87667)
#   Closest End S723 Coordinates: (0.62469, 0.79121, 0.87982)
#   Distance: 0.00364
# Unit 73:
#   Start S731 Coordinates: (0.87667, 0.12333, 0.29)
#   Closest End S734 Coordinates: (0.8775, 0.11919, 0.29412)
#   Distance: 0.00590
# Unit 74:
#   Start S741 Coordinates: (0.87667, 0.12333, 0.62333)
#   Closest End S743 Coordinates: (0.86893, 0.11997, 0.61719)
#   Distance: 0.01044
# Unit 75:
#   Start S751 Coordinates: (0.95667, 0.12333, 0.87667)
#   Closest End S754 Coordinates: (0.95665, 0.12331, 0.87704)
#   Distance: 0.00037
# Unit 76:
#   Start S761 Coordinates: (0.87667, 0.37667, 0.21)
#   Closest End S762 Coordinates: (0.87457, 0.37084, 0.22008)
#   Distance: 0.01183
# Unit 77:
#   Start S771 Coordinates: (0.87667, 0.37667, 0.54333)
#   Closest End S771 Coordinates: (0.87127, 0.37843, 0.54806)
#   Distance: 0.00739
# Unit 78:
#   Start S781 Coordinates: (0.87667, 0.37667, 0.87667)
#   Closest End S781 Coordinates: (0.86776, 0.38937, 0.8763)
#   Distance: 0.01552
# Unit 79:
#   Start S791 Coordinates: (0.87667, 0.79, 0.29)
#   Closest End S794 Coordinates: (0.87902, 0.75977, 0.30705)
#   Distance: 0.03479
# Unit 80:
#   Start S801 Coordinates: (0.87667, 0.79, 0.62333)
#   Closest End S803 Coordinates: (0.87357, 0.79088, 0.61853)
#   Distance: 0.00578
# Unit 81:
#   Start S811 Coordinates: (0.87667, 0.71, 0.87667)
#   Closest End S813 Coordinates: (0.86857, 0.71744, 0.87934)
#   Distance: 0.01132
# Unit 82:
#   Start S821 Coordinates: (0.04333, 0.12333, 0.12333)
#   Closest End S823 Coordinates: (0.05029, 0.13757, 0.11041)
#   Distance: 0.02045
# Unit 83:
#   Start S831 Coordinates: (0.12333, 0.12333, 0.37667)
#   Closest End S833 Coordinates: (0.12856, 0.11774, 0.37745)
#   Distance: 0.00769
# Unit 84:
#   Start S841 Coordinates: (0.12333, 0.12333, 0.71)
#   Closest End S844 Coordinates: (0.12412, 0.11184, 0.70213)
#   Distance: 0.01395
# Unit 85:
#   Start S851 Coordinates: (0.12333, 0.37667, 0.12333)
#   Closest End S852 Coordinates: (0.13554, 0.39314, 0.12191)
#   Distance: 0.02055
# Unit 86:
#   Start S861 Coordinates: (0.04333, 0.37667, 0.37667)
#   Closest End S864 Coordinates: (0.0505, 0.37071, 0.37695)
#   Distance: 0.00933
# Unit 87:
#   Start S871 Coordinates: (0.12333, 0.37667, 0.79)
#   Closest End S871 Coordinates: (0.12689, 0.37587, 0.78473)
#   Distance: 0.00641
# Unit 88:
#   Start S881 Coordinates: (0.12333, 0.71, 0.12333)
#   Closest End S884 Coordinates: (0.12571, 0.73637, 0.13611)
#   Distance: 0.02940
# Unit 89:
#   Start S891 Coordinates: (0.12333, 0.79, 0.37667)
#   Closest End S894 Coordinates: (0.11395, 0.79958, 0.37962)
#   Distance: 0.01373
# Unit 90:
#   Start S901 Coordinates: (0.12333, 0.71, 0.79)
#   Closest End S904 Coordinates: (0.13072, 0.71158, 0.78233)
#   Distance: 0.01077
# Unit 91:
#   Start S911 Coordinates: (0.37667, 0.12333, 0.12333)
#   Closest End S914 Coordinates: (0.38078, 0.12573, 0.12434)
#   Distance: 0.00487
# Unit 92:
#   Start S921 Coordinates: (0.37667, 0.04333, 0.37667)
#   Closest End S923 Coordinates: (0.36502, 0.05115, 0.38405)
#   Distance: 0.01585
# Unit 93:
#   Start S931 Coordinates: (0.37667, 0.12333, 0.79)
#   Closest End S932 Coordinates: (0.38255, 0.12329, 0.79479)
#   Distance: 0.00758
# Unit 94:
#   Start S941 Coordinates: (0.37667, 0.45667, 0.12333)
#   Closest End S944 Coordinates: (0.36992, 0.44836, 0.12305)
#   Distance: 0.01071
# Unit 95:
#   Start S951 Coordinates: (0.37667, 0.37667, 0.37667)
#   Closest End S951 Coordinates: (0.37679, 0.37516, 0.37854)
#   Distance: 0.00241
# Unit 96:
#   Start S961 Coordinates: (0.37667, 0.37667, 0.71)
#   Closest End S962 Coordinates: (0.37378, 0.37263, 0.71855)
#   Distance: 0.00989
# Unit 97:
#   Start S971 Coordinates: (0.37667, 0.79, 0.12333)
#   Closest End S974 Coordinates: (0.37862, 0.79179, 0.12299)
#   Distance: 0.00267
# Unit 98:
#   Start S981 Coordinates: (0.37667, 0.71, 0.37667)
#   Closest End S982 Coordinates: (0.37978, 0.70019, 0.38624)
#   Distance: 0.01405
# Unit 99:
#   Start S991 Coordinates: (0.37667, 0.79, 0.79)
#   Closest End S994 Coordinates: (0.37862, 0.77807, 0.80032)
#   Distance: 0.01589
# Unit 100:
#   Start S1001 Coordinates: (0.71, 0.12333, 0.12333)
#   Closest End S1003 Coordinates: (0.70372, 0.11557, 0.12316)
#   Distance: 0.00998
# Unit 101:
#   Start S1011 Coordinates: (0.79, 0.12333, 0.37667)
#   Closest End S1011 Coordinates: (0.79677, 0.11737, 0.37898)
#   Distance: 0.00931
# Unit 102:
#   Start S1021 Coordinates: (0.71, 0.12333, 0.79)
#   Closest End S1021 Coordinates: (0.70871, 0.12313, 0.78845)
#   Distance: 0.00203
# Unit 103:
#   Start S1031 Coordinates: (0.79, 0.37667, 0.12333)
#   Closest End S1033 Coordinates: (0.79951, 0.39155, 0.12438)
#   Distance: 0.01769
# Unit 104:
#   Start S1041 Coordinates: (0.71, 0.37667, 0.37667)
#   Closest End S1042 Coordinates: (0.70998, 0.37295, 0.38125)
#   Distance: 0.00590
# Unit 105:
#   Start S1051 Coordinates: (0.79, 0.37667, 0.79)
#   Closest End S1052 Coordinates: (0.80673, 0.39802, 0.78465)
#   Distance: 0.02765
# Unit 106:
#   Start S1061 Coordinates: (0.71, 0.79, 0.12333)
#   Closest End S1064 Coordinates: (0.70901, 0.78353, 0.12763)
#   Distance: 0.00783
# Unit 107:
#   Start S1071 Coordinates: (0.79, 0.79, 0.37667)
#   Closest End S1071 Coordinates: (0.78318, 0.79421, 0.37529)
#   Distance: 0.00813
# Unit 108:
#   Start S1081 Coordinates: (0.71, 0.79, 0.79)
#   Closest End S1081 Coordinates: (0.69734, 0.77998, 0.7831)
#   Distance: 0.01756

# %%
# Dictionary to store rotation information
rotation_data = {}

# Calculate theta and phi for each thiophosphate unit
for unit, data in closest_sulfur_pairs.items():
    # Vector from P to starting S1
    start_p_coords = start_coordinates[unit]['P']
    start_s_coords = data['start_sulfur']
    start_vector = np.array([start_s_coords[0] - start_p_coords[0], 
                             start_s_coords[1] - start_p_coords[1], 
                             start_s_coords[2] - start_p_coords[2]])
    
    # Vector from P to ending Sx
    end_p_coords=end_coordinates[unit]['P']
    end_s_coords = data['end_sulfur_coords']
    end_vector = np.array([end_s_coords[0] - end_p_coords[0], 
                           end_s_coords[1] - end_p_coords[1], 
                           end_s_coords[2] - end_p_coords[2]])
    
    # Convert vectors to spherical coordinates
    start_r, start_theta, start_phi = cartesian_to_spherical(*start_vector)
    end_r, end_theta, end_phi = cartesian_to_spherical(*end_vector)
    
    # Store the rotation data
    rotation_data[unit] = {
        'start_theta': start_theta, 'start_phi': start_phi,  # Reference (0, 0)
        'end_theta': end_theta, 
        'end_phi': end_phi,
        'rotation_theta': end_theta-start_theta,  # Since start_theta is 0
        'rotation_phi': end_phi-start_phi  # Since start_phi is 0
    }

# Example: Print the rotational data for each thiophosphate unit
for unit, data in rotation_data.items():
    print(f"Unit {unit}:")
    print(f"  Start θ: {data['start_theta']}°, Start φ: {data['start_phi']}°")
    print(f"  End θ: {data['end_theta']}°, End φ: {data['end_phi']}°")
    print(f"  Rotation θ: {data['rotation_theta']}°, Rotation φ: {data['rotation_phi']}°")
# Out:
# Unit 1:
#   Start θ: 54.737636079599916°, Start φ: -45.00000000000002°
#   End θ: 50.499453004103515°, End φ: -30.449187315909338°
#   Rotation θ: -4.238183075496401°, Rotation φ: 14.550812684090683°
# Unit 2:
#   Start θ: 125.2623639204001°, Start φ: 45.0°
#   End θ: 129.36242109046697°, End φ: 35.14589655570581°
#   Rotation θ: 4.1000571700668615°, Rotation φ: -9.85410344429419°
# Unit 3:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 133.99911005973553°, End φ: 50.096941983303175°
#   Rotation θ: 8.734720376980846°, Rotation φ: 5.096941983303175°
# Unit 4:
#   Start θ: 54.73662324273851°, Start φ: 135.00214867230594°
#   End θ: 54.983416147561655°, End φ: 138.5271741756288°
#   Rotation θ: 0.24679290482314542°, Rotation φ: 3.5250255033228655°
# Unit 5:
#   Start θ: 125.26337675726151°, Start φ: 44.997851327694114°
#   End θ: 127.5475626771127°, End φ: 29.538478742744147°
#   Rotation θ: 2.2841859198511827°, Rotation φ: -15.459372584949968°
# Unit 6:
#   Start θ: 125.26540254493958°, Start φ: 44.997851327694114°
#   End θ: 131.165920981362°, End φ: 47.6744079557321°
#   Rotation θ: 5.900518436422431°, Rotation φ: 2.6765566280379858°
# Unit 7:
#   Start θ: 54.7366232427385°, Start φ: -44.997851327694114°
#   End θ: 54.288699108337646°, End φ: -29.83488720439607°
#   Rotation θ: -0.4479241344008571°, Rotation φ: 15.162964123298046°
# Unit 8:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230594°
#   End θ: 119.90153370234755°, End φ: -136.44867452991508°
#   Rotation θ: -5.361843054913962°, Rotation φ: -1.4465258576091458°
# Unit 9:
#   Start θ: 54.73459745506044°, Start φ: -44.997851327694114°
#   End θ: 64.88924049083631°, End φ: -34.6661723604567°
#   Rotation θ: 10.154643035775877°, Rotation φ: 10.331678967237416°
# Unit 10:
#   Start θ: 54.73662324273851°, Start φ: -45.00214867230591°
#   End θ: 57.55548560944797°, End φ: -47.678023214066236°
#   Rotation θ: 2.8188623667094603°, Rotation φ: -2.6758745417603294°
# Unit 11:
#   Start θ: 125.26337675726151°, Start φ: 45.00214867230589°
#   End θ: 128.70812142037403°, End φ: 46.8650648914445°
#   Rotation θ: 3.444744663112516°, Rotation φ: 1.8629162191386044°
# Unit 12:
#   Start θ: 125.26540254493958°, Start φ: 45.00214867230589°
#   End θ: 123.33428547760515°, End φ: 51.44722854534988°
#   Rotation θ: -1.9311170673344265°, Rotation φ: 6.445079873043987°
# Unit 13:
#   Start θ: 54.737636155562235°, Start φ: 135.0042971834554°
#   End θ: 56.69892851754145°, End φ: 129.73438519379405°
#   Rotation θ: 1.9612923619792113°, Rotation φ: -5.269911989661352°
# Unit 14:
#   Start θ: 125.26438968275463°, Start φ: 45.0°
#   End θ: 132.43123463312287°, End φ: 34.02680419017318°
#   Rotation θ: 7.166844950368244°, Rotation φ: -10.97319580982682°
# Unit 15:
#   Start θ: 125.2664154957558°, Start φ: 45.0°
#   End θ: 141.50622309284435°, End φ: 28.855184616744268°
#   Rotation θ: 16.239807597088557°, Rotation φ: -16.144815383255732°
# Unit 16:
#   Start θ: 54.735610317245396°, Start φ: -45.0°
#   End θ: 57.578129418043936°, End φ: -38.33280213066153°
#   Rotation θ: 2.8425191007985404°, Rotation φ: 6.667197869338473°
# Unit 17:
#   Start θ: 125.26236384443777°, Start φ: 45.00429718345539°
#   End θ: 130.61924124581603°, End φ: 43.461449659379475°
#   Rotation θ: 5.356877401378256°, Rotation φ: -1.542847524075917°
# Unit 18:
#   Start θ: 54.733584504244206°, Start φ: -45.0°
#   End θ: 50.29561118498916°, End φ: -34.13578876717027°
#   Rotation θ: -4.437973319255043°, Rotation φ: 10.864211232829732°
# Unit 19:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769412°
#   End θ: 50.712940885713884°, End φ: 127.8627592477178°
#   Rotation θ: -4.023682357024619°, Rotation φ: -7.135092079976317°
# Unit 20:
#   Start θ: 125.26337675726151°, Start φ: -134.9978513276941°
#   End θ: 124.78391114649688°, End φ: -133.47809271527794°
#   Rotation θ: -0.4794656107646347°, Rotation φ: 1.5197586124161546°
# Unit 21:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769412°
#   End θ: 50.51002056471963°, End φ: 140.96403563878118°
#   Rotation θ: -4.224576890340806°, Rotation φ: 5.966184311087062°
# Unit 22:
#   Start θ: 54.735610317245396°, Start φ: 135.0°
#   End θ: 51.56904571318572°, End φ: 133.47936285754326°
#   Rotation θ: -3.1665646040596727°, Rotation φ: -1.520637142456735°
# Unit 23:
#   Start θ: 125.26236384443777°, Start φ: -134.99570281654462°
#   End θ: 126.24157736115075°, End φ: -144.6118255205159°
#   Rotation θ: 0.9792135167129743°, Rotation φ: -9.616122703971286°
# Unit 24:
#   Start θ: 54.733584504244206°, Start φ: 135.0°
#   End θ: 57.55008750645141°, End φ: 139.1406035912028°
#   Rotation θ: 2.816503002207206°, Rotation φ: 4.14060359120279°
# Unit 25:
#   Start θ: 54.737636155562235°, Start φ: -44.995702816544615°
#   End θ: 62.343190318399984°, End φ: -44.754892946021954°
#   Rotation θ: 7.605554162837748°, Rotation φ: 0.24080987052266067°
# Unit 26:
#   Start θ: 125.26438968275463°, Start φ: -135.0°
#   End θ: 120.44850742428459°, End φ: -137.7781107985376°
#   Rotation θ: -4.81588225847004°, Rotation φ: -2.778110798537597°
# Unit 27:
#   Start θ: 125.2664154957558°, Start φ: -135.0°
#   End θ: 116.3719891383745°, End φ: -126.05665491096637°
#   Rotation θ: -8.894426357381292°, Rotation φ: 8.943345089033627°
# Unit 28:
#   Start θ: 54.73459745506047°, Start φ: -45.002148672305964°
#   End θ: 58.79961519015559°, End φ: -37.07943733633471°
#   Rotation θ: 4.065017735095125°, Rotation φ: 7.92271133597125°
# Unit 29:
#   Start θ: 54.73662324273844°, Start φ: -45.002148672305964°
#   End θ: 46.164681949252°, End φ: -47.807565083800945°
#   Rotation θ: -8.57194129348644°, Rotation φ: -2.8054164114949813°
# Unit 30:
#   Start θ: 125.26337675726158°, Start φ: 45.002148672305935°
#   End θ: 127.34752344905226°, End φ: 41.53645879067116°
#   Rotation θ: 2.0841466917906786°, Rotation φ: -3.4656898816347734°
# Unit 31:
#   Start θ: 125.2664154957558°, Start φ: 45.00000000000005°
#   End θ: 128.65215563438136°, End φ: 47.35967218119179°
#   Rotation θ: 3.3857401386255646°, Rotation φ: 2.3596721811917405°
# Unit 32:
#   Start θ: 125.26844120745872°, Start φ: 45.00000000000005°
#   End θ: 128.46581348891218°, End φ: 50.82542912883228°
#   Rotation θ: 3.197372281453454°, Rotation φ: 5.8254291288322335°
# Unit 33:
#   Start θ: 125.26438968275468°, Start φ: 45.00000000000005°
#   End θ: 122.61968501396092°, End φ: 48.50636982581061°
#   Rotation θ: -2.6447046687937643°, Rotation φ: 3.506369825810559°
# Unit 34:
#   Start θ: 54.73358450424422°, Start φ: -45.00000000000005°
#   End θ: 51.05340372495519°, End φ: -42.22990575414577°
#   Rotation θ: -3.6801807792890315°, Rotation φ: 2.770094245854281°
# Unit 35:
#   Start θ: 54.735610317245325°, Start φ: -45.00000000000005°
#   End θ: 52.848610947975374°, End φ: -44.75706676171751°
#   Rotation θ: -1.886999369269951°, Rotation φ: 0.24293323828253932°
# Unit 36:
#   Start θ: 54.731558792541286°, Start φ: -45.00000000000005°
#   End θ: 54.53590637959864°, End φ: -62.209192120005085°
#   Rotation θ: -0.19565241294264268°, Rotation φ: -17.209192120005035°
# Unit 37:
#   Start θ: 54.73459745506047°, Start φ: 134.99785132769406°
#   End θ: 41.6035189948909°, End φ: 148.05025660655477°
#   Rotation θ: -13.131078460169569°, Rotation φ: 13.052405278860704°
# Unit 38:
#   Start θ: 54.73662324273844°, Start φ: 134.99785132769406°
#   End θ: 57.41220138697822°, End φ: 144.54245931541485°
#   Rotation θ: 2.675578144239779°, Rotation φ: 9.54460798772078°
# Unit 39:
#   Start θ: 125.26337675726155°, Start φ: -134.99785132769406°
#   End θ: 129.89944596206956°, End φ: -133.94446955140054°
#   Rotation θ: 4.63606920480801°, Rotation φ: 1.05338177629352°
# Unit 40:
#   Start θ: 54.73358450424422°, Start φ: 134.99999999999997°
#   End θ: 66.76471990086375°, End φ: 143.5563405573613°
#   Rotation θ: 12.031135396619533°, Rotation φ: 8.556340557361324°
# Unit 41:
#   Start θ: 54.735610317245325°, Start φ: 134.99999999999997°
#   End θ: 57.95952894541105°, End φ: 140.20570957821425°
#   Rotation θ: 3.223918628165727°, Rotation φ: 5.205709578214282°
# Unit 42:
#   Start θ: 54.731558792541286°, Start φ: 134.99999999999997°
#   End θ: 57.4381316496292°, End φ: 145.52342463181753°
#   Rotation θ: 2.706572857087913°, Rotation φ: 10.523424631817562°
# Unit 43:
#   Start θ: 125.2664154957558°, Start φ: -134.99999999999997°
#   End θ: 123.45946905765821°, End φ: -131.2205444024985°
#   Rotation θ: -1.806946438097583°, Rotation φ: 3.7794555975014816°
# Unit 44:
#   Start θ: 125.26844120745872°, Start φ: -134.99999999999997°
#   End θ: 132.5092560537438°, End φ: -136.11456327248473°
#   Rotation θ: 7.240814846285076°, Rotation φ: -1.1145632724847587°
# Unit 45:
#   Start θ: 125.26438968275468°, Start φ: -134.99999999999997°
#   End θ: 121.73332666581696°, End φ: -135.7795332440646°
#   Rotation θ: -3.531063016937722°, Rotation φ: -0.7795332440646234°
# Unit 46:
#   Start θ: 54.73561031724537°, Start φ: 135.00000000000006°
#   End θ: 55.103695671095714°, End φ: 136.4739354020765°
#   Rotation θ: 0.368085353850347°, Rotation φ: 1.4739354020764495°
# Unit 47:
#   Start θ: 54.73763607959988°, Start φ: 135.00000000000006°
#   End θ: 57.24112681158494°, End φ: 127.18172444419565°
#   Rotation θ: 2.5034907319850603°, Rotation φ: -7.818275555804405°
# Unit 48:
#   Start θ: 125.26236392040013°, Start φ: 44.999999999999964°
#   End θ: 125.08809748606109°, End φ: 46.82171596017357°
#   Rotation θ: -0.17426643433904587°, Rotation φ: 1.8217159601736057°
# Unit 49:
#   Start θ: 54.734597455060495°, Start φ: 135.00214867230594°
#   End θ: 57.02442055066084°, End φ: 123.89308753839987°
#   Rotation θ: 2.2898230956003474°, Rotation φ: -11.109061133906067°
# Unit 50:
#   Start θ: 54.73662324273847°, Start φ: 135.00214867230594°
#   End θ: 59.568227641865164°, End φ: 144.42763750518168°
#   Rotation θ: 4.831604399126697°, Rotation φ: 9.425488832875743°
# Unit 51:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769408°
#   End θ: 117.87371164977876°, End φ: 40.86094141524422°
#   Rotation θ: -7.38966510748277°, Rotation φ: -4.136909912449859°
# Unit 52:
#   Start θ: 54.734597455060495°, Start φ: -44.99785132769408°
#   End θ: 51.278520310840065°, End φ: -46.000336664800386°
#   Rotation θ: -3.45607714422043°, Rotation φ: -1.0024853371063074°
# Unit 53:
#   Start θ: 54.73662324273847°, Start φ: -44.99785132769408°
#   End θ: 50.87321681950675°, End φ: -55.74325353182111°
#   Rotation θ: -3.863406423231716°, Rotation φ: -10.745402204127032°
# Unit 54:
#   Start θ: 125.26337675726153°, Start φ: -135.00214867230594°
#   End θ: 122.84472702678893°, End φ: -140.44860865815642°
#   Rotation θ: -2.4186497304725947°, Rotation φ: -5.446459985850481°
# Unit 55:
#   Start θ: 54.73459745506047°, Start φ: 135.00214867230596°
#   End θ: 51.837535844729636°, End φ: 132.0805714580239°
#   Rotation θ: -2.89706161033083°, Rotation φ: -2.9215772142820526°
# Unit 56:
#   Start θ: 54.73662324273844°, Start φ: 135.00214867230596°
#   End θ: 49.961864858573705°, End φ: 142.40828005561735°
#   Rotation θ: -4.774758384164734°, Rotation φ: 7.40613138331139°
# Unit 57:
#   Start θ: 125.26337675726158°, Start φ: 44.997851327694065°
#   End θ: 114.85314984339085°, End φ: 32.10716729972068°
#   Rotation θ: -10.41022691387073°, Rotation φ: -12.890684027973386°
# Unit 58:
#   Start θ: 54.73459745506047°, Start φ: -44.99785132769408°
#   End θ: 47.6065997740019°, End φ: -51.76136052316688°
#   Rotation θ: -7.127997681058567°, Rotation φ: -6.7635091954728°
# Unit 59:
#   Start θ: 54.73662324273844°, Start φ: -44.99785132769408°
#   End θ: 54.86196702683669°, End φ: -53.86072093783018°
#   Rotation θ: 0.12534378409824853°, Rotation φ: -8.862869610136102°
# Unit 60:
#   Start θ: 125.26337675726155°, Start φ: -135.00214867230594°
#   End θ: 128.76156831574326°, End φ: -149.37204975950488°
#   Rotation θ: 3.4981915584817074°, Rotation φ: -14.36990108719894°
# Unit 61:
#   Start θ: 54.73561031724537°, Start φ: -45.00000000000004°
#   End θ: 59.47512122795288°, End φ: -58.790085092397696°
#   Rotation θ: 4.739510910707516°, Rotation φ: -13.790085092397653°
# Unit 62:
#   Start θ: 54.73763607959988°, Start φ: -45.00000000000004°
#   End θ: 55.19421133170923°, End φ: -52.20833884460878°
#   Rotation θ: 0.4565752521093529°, Rotation φ: -7.20833884460874°
# Unit 63:
#   Start θ: 125.26236392040013°, Start φ: 45.00000000000004°
#   End θ: 123.67054786150814°, End φ: 37.72544145519021°
#   Rotation θ: -1.5918160588919932°, Rotation φ: -7.274558544809835°
# Unit 64:
#   Start θ: 125.2664154957558°, Start φ: 44.99999999999995°
#   End θ: 129.50925549281123°, End φ: 42.70270298776132°
#   Rotation θ: 4.242839997055441°, Rotation φ: -2.29729701223863°
# Unit 65:
#   Start θ: 125.26844120745872°, Start φ: 44.99999999999995°
#   End θ: 109.04370289627316°, End φ: 68.26542387717492°
#   Rotation θ: -16.22473831118556°, Rotation φ: 23.265423877174975°
# Unit 66:
#   Start θ: 125.26438968275468°, Start φ: 44.99999999999995°
#   End θ: 124.8914862078437°, End φ: 50.04936677436126°
#   Rotation θ: -0.3729034749109843°, Rotation φ: 5.04936677436131°
# Unit 67:
#   Start θ: 54.73358450424422°, Start φ: -44.999999999999964°
#   End θ: 57.88249077677772°, End φ: -42.116837439932695°
#   Rotation θ: 3.1489062725335017°, Rotation φ: 2.8831625600672695°
# Unit 68:
#   Start θ: 54.735610317245325°, Start φ: -44.999999999999964°
#   End θ: 70.11042385559352°, End φ: -35.80029357725135°
#   Rotation θ: 15.3748135383482°, Rotation φ: 9.199706422748612°
# Unit 69:
#   Start θ: 54.731558792541286°, Start φ: -44.999999999999964°
#   End θ: 56.41064030380702°, End φ: -69.97093703715473°
#   Rotation θ: 1.6790815112657356°, Rotation φ: -24.970937037154762°
# Unit 70:
#   Start θ: 54.734597455060495°, Start φ: -45.00214867230593°
#   End θ: 56.75944936046851°, End φ: -40.06216504164118°
#   Rotation θ: 2.0248519054080134°, Rotation φ: 4.939983630664749°
# Unit 71:
#   Start θ: 54.73662324273847°, Start φ: -45.00214867230593°
#   End θ: 56.601827445714235°, End φ: -56.7840555981554°
#   Rotation θ: 1.865204202975768°, Rotation φ: -11.78190692584947°
# Unit 72:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230593°
#   End θ: 122.25788763829397°, End φ: 44.89591428518041°
#   Rotation θ: -3.00548911896756°, Rotation φ: -0.10623438712551803°
# Unit 73:
#   Start θ: 54.73358450424422°, Start φ: 135.00000000000006°
#   End θ: 50.280400731013884°, End φ: 137.526004830016°
#   Rotation θ: -4.453183773230336°, Rotation φ: 2.5260048300159497°
# Unit 74:
#   Start θ: 54.735610317245325°, Start φ: 135.00000000000006°
#   End θ: 60.635799534579284°, End φ: 142.4941011457571°
#   Rotation θ: 5.90018921733396°, Rotation φ: 7.494101145757043°
# Unit 75:
#   Start θ: 125.26236384443783°, Start φ: 44.995702816544565°
#   End θ: 125.02724776438234°, End φ: 44.99999999999999°
#   Rotation θ: -0.23511608005549078°, Rotation φ: 0.004297183455427955°
# Unit 76:
#   Start θ: 125.2664154957558°, Start φ: -135.00000000000006°
#   End θ: 115.67745715212301°, End φ: -132.57096319874572°
#   Rotation θ: -9.588958343632783°, Rotation φ: 2.429036801254341°
# Unit 77:
#   Start θ: 125.26844120745872°, Start φ: -135.00000000000006°
#   End θ: 120.71810294330093°, End φ: -139.89287495786652°
#   Rotation θ: -4.550338264157787°, Rotation φ: -4.892874957866468°
# Unit 78:
#   Start θ: 125.26438968275468°, Start φ: -135.00000000000006°
#   End θ: 125.7811608248699°, End φ: -150.83114030588763°
#   Rotation θ: 0.5167711421152177°, Rotation φ: -15.831140305887573°
# Unit 79:
#   Start θ: 54.734597455060495°, Start φ: 134.99785132769406°
#   End θ: 34.28636770650871°, End φ: 165.45287049796306°
#   Rotation θ: -20.448229748551782°, Rotation φ: 30.455019170268997°
# Unit 80:
#   Start θ: 54.73662324273847°, Start φ: 134.99785132769406°
#   End θ: 59.3508432022519°, End φ: 136.51425356645447°
#   Rotation θ: 4.614219959513434°, Rotation φ: 1.5164022387604064°
# Unit 81:
#   Start θ: 125.26337675726153°, Start φ: -134.99785132769406°
#   End θ: 122.72839694182116°, End φ: -145.90502204523446°
#   Rotation θ: -2.5349798154403658°, Rotation φ: -10.907170717540396°
# Unit 82:
#   Start θ: 54.737636155562214°, Start φ: 135.00429718345544°
#   End θ: 66.90736100555159°, End φ: 121.34745551948151°
#   Rotation θ: 12.169724849989379°, Rotation φ: -13.656841663973921°
# Unit 83:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 124.61003055895786°, End φ: 37.26308791921943°
#   Rotation θ: -0.6543591237968229°, Rotation φ: -7.73691208078057°
# Unit 84:
#   Start θ: 125.26641549575585°, Start φ: 45.0°
#   End θ: 133.88757026556613°, End φ: 34.95146316516483°
#   Rotation θ: 8.621154769810275°, Rotation φ: -10.048536834835168°
# Unit 85:
#   Start θ: 54.735610317245346°, Start φ: -45.000000000000014°
#   End θ: 56.032530864385976°, End φ: -24.26013462591614°
#   Rotation θ: 1.2969205471406298°, Rotation φ: 20.739865374083873°
# Unit 86:
#   Start θ: 125.2623638444378°, Start φ: -135.00429718345544°
#   End θ: 125.11651013520476°, End φ: -125.53885703291341°
#   Rotation θ: -0.14585370923303742°, Rotation φ: 9.465440150542022°
# Unit 87:
#   Start θ: 54.73358450424416°, Start φ: -45.000000000000014°
#   End θ: 59.80472902808498°, End φ: -43.12612654391545°
#   Rotation θ: 5.071144523840815°, Rotation φ: 1.8738734560845671°
# Unit 88:
#   Start θ: 54.736623242738496°, Start φ: -45.00214867230598°
#   End θ: 40.14632867282112°, End φ: -17.82851617725988°
#   Rotation θ: -14.590294569917376°, Rotation φ: 27.1736324950461°
# Unit 89:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230598°
#   End θ: 122.4481495380976°, End φ: 58.301030707327996°
#   Rotation θ: -2.81522721916393°, Rotation φ: 13.298882035022018°
# Unit 90:
#   Start θ: 54.73459745506044°, Start φ: -45.00214867230598°
#   End θ: 62.07930396583862°, End φ: -39.032358311659756°
#   Rotation θ: 7.344706510778181°, Rotation φ: 5.969790360646222°
# Unit 91:
#   Start θ: 54.735610317245346°, Start φ: 135.00000000000003°
#   End θ: 53.56348037790752°, End φ: 130.246654699735°
#   Rotation θ: -1.1721299393378288°, Rotation φ: -4.753345300265039°
# Unit 92:
#   Start θ: 125.2623638444378°, Start φ: -134.99570281654456°
#   End θ: 118.19274713056444°, End φ: -148.07545558413136°
#   Rotation θ: -7.0696167138733585°, Rotation φ: -13.079752767586797°
# Unit 93:
#   Start θ: 54.73358450424416°, Start φ: 135.00000000000003°
#   End θ: 49.5553156490772°, End φ: 130.49248436141517°
#   Rotation θ: -5.178268855166962°, Rotation φ: -4.507515638584863°
# Unit 94:
#   Start θ: 54.73763615556222°, Start φ: 134.99570281654456°
#   End θ: 54.882171853876194°, End φ: 145.86818719360306°
#   Rotation θ: 0.14453569831397317°, Rotation φ: 10.872484377058498°
# Unit 95:
#   Start θ: 125.26438968275465°, Start φ: -135.0°
#   End θ: 123.52069491404345°, End φ: -133.8526890570616°
#   Rotation θ: -1.743694768711208°, Rotation φ: 1.1473109429383896°
# Unit 96:
#   Start θ: 125.26641549575585°, Start φ: -135.0°
#   End θ: 117.09414793312129°, End φ: -134.24207634775098°
#   Rotation θ: -8.17226756263456°, Rotation φ: 0.7579236522490191°
# Unit 97:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769404°
#   End θ: 54.941436966970336°, End φ: 132.31801499099421°
#   Rotation θ: 0.2048137242318333°, Rotation φ: -2.6798363366998217°
# Unit 98:
#   Start θ: 125.26337675726151°, Start φ: -134.99785132769404°
#   End θ: 116.14827048147502°, End φ: -126.52417854228628°
#   Rotation θ: -9.115106275786488°, Rotation φ: 8.473672785407757°
# Unit 99:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769404°
#   End θ: 43.21805807600063°, End φ: 143.58330176704257°
#   Rotation θ: -11.516539379059807°, Rotation φ: 8.585450439348534°
# Unit 100:
#   Start θ: 54.736623242738496°, Start φ: 135.00214867230596°
#   End θ: 54.771300771571596°, End φ: 145.13780385308513°
#   Rotation θ: 0.03467752883310027°, Rotation φ: 10.135655180779167°
# Unit 101:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769403°
#   End θ: 123.08658005724563°, End φ: 36.04776360051866°
#   Rotation θ: -2.176796700015899°, Rotation φ: -8.950087727175372°
# Unit 102:
#   Start θ: 54.73459745506044°, Start φ: 135.00214867230596°
#   End θ: 56.15985846269599°, End φ: 136.05267117504417°
#   Rotation θ: 1.4252610076355552°, Rotation φ: 1.050522502738204°
# Unit 103:
#   Start θ: 54.7366232427385°, Start φ: -44.99785132769403°
#   End θ: 53.5208122391967°, End φ: -26.90197269265857°
#   Rotation θ: -1.215811003541802°, Rotation φ: 18.095878635035458°
# Unit 104:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230596°
#   End θ: 120.86233563965635°, End φ: -132.4700669983848°
#   Rotation θ: -4.4010411176051605°, Rotation φ: 2.5320816739211693°
# Unit 105:
#   Start θ: 54.73459745506044°, Start φ: -44.99785132769403°
#   End θ: 59.87609986841257°, End φ: -18.198291049840808°
#   Rotation θ: 5.1415024133521285°, Rotation φ: 26.79956027785322°
# Unit 106:
#   Start θ: 54.737636079599945°, Start φ: 135.0°
#   End θ: 50.08656848336779°, End φ: 140.716683088266°
#   Rotation θ: -4.651067596232153°, Rotation φ: 5.716683088265995°
# Unit 107:
#   Start θ: 125.26236392040008°, Start φ: 45.0°
#   End θ: 126.81878133805273°, End φ: 53.11144463661524°
#   Rotation θ: 1.5564174176526535°, Rotation φ: 8.11144463661524°
# Unit 108:
#   Start θ: 54.735610317245346°, Start φ: 135.0°
#   End θ: 61.3548405129371°, End φ: 150.34659671928242°
#   Rotation θ: 6.619230195691756°, Rotation φ: 15.346596719282417°

# %%
df = pd.DataFrame({
    r'PS$_4$$^{3-}$ unit': list(rotation_data.keys()),
    r'$\theta$ ($^\circ$)': [data['rotation_theta'] for data in rotation_data.values()],
    r'$\phi$ ($^\circ$)': [data['rotation_phi'] for data in rotation_data.values()],
    r'Displacement of S (\AA)': [data['distance']*lattice_param for data in closest_sulfur_pairs.values()]
})

display(df)

readytosave=True
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    df.to_csv(f"{saveloc}/{cleaned_matname} displacements.csv")
# Out:
#      PS$_4$$^{3-}$ unit  $\theta$ ($^\circ$)  $\phi$ ($^\circ$)  \
# 0                     1            -4.238183          14.550813
# 1                     2             4.100057          -9.854103
# 2                     3             8.734720           5.096942
# 3                     4             0.246793           3.525026
# 4                     5             2.284186         -15.459373
# ..                  ...                  ...                ...
# 103                 104            -4.401041           2.532082
# 104                 105             5.141502          26.799560
# 105                 106            -4.651068           5.716683
# 106                 107             1.556417           8.111445
# 107                 108             6.619230          15.346597
#
#      Displacement of S (\AA)
# 0                   0.438166
# 1                   0.315222
# 2                   0.341345
# 3                   0.103563
# 4                   0.450246
# ..                       ...
# 103                 0.174492
# 104                 0.817585
# 105                 0.231596
# 106                 0.240506
# 107                 0.519239
#
# [108 rows x 4 columns]

# %%
import numpy as np

# Initialize sums for theta, phi rotations, and distance
total_theta_rotation = 0
total_phi_rotation = 0
total_distance = 0

# Initialize sums for squared differences
sum_squared_diff_theta = 0
sum_squared_diff_phi = 0
sum_squared_diff_distance = 0

# Count the number of units
num_units = len(rotation_data)

# Collect all theta, phi, and distance values
theta_values = []
phi_values = []
distance_values = []

# Sum up the rotations and collect values for all units
for unit, data in rotation_data.items():
    total_theta_rotation += data['rotation_theta']
    total_phi_rotation += data['rotation_phi']
    theta_values.append(data['rotation_theta'])
    phi_values.append(data['rotation_phi'])

for unit, data in closest_sulfur_pairs.items():
    total_distance += data['distance']
    distance_values.append(data['distance'])

# Calculate the average theta, phi rotations, and distance
average_theta_rotation = total_theta_rotation / num_units
average_phi_rotation = total_phi_rotation / num_units
average_distance = total_distance / num_units

# Calculate the squared differences from the mean for each unit
for unit, data in rotation_data.items():
    sum_squared_diff_theta += (data['rotation_theta'] - average_theta_rotation) ** 2
    sum_squared_diff_phi += (data['rotation_phi'] - average_phi_rotation) ** 2

for unit, data in closest_sulfur_pairs.items():
    sum_squared_diff_distance += (data['distance'] - average_distance) ** 2

# Calculate the variances using `num_units - 1` for the denominator
variance_theta = sum_squared_diff_theta / (num_units - 1)
variance_phi = sum_squared_diff_phi / (num_units - 1)
variance_distance = sum_squared_diff_distance / (num_units - 1)

# Calculate the standard deviations
std_dev_theta = variance_theta ** 0.5
std_dev_phi = variance_phi ** 0.5
std_dev_distance = variance_distance ** 0.5

# Convert average distance and standard deviation to angstroms
average_distance_angstrom = average_distance * lattice_param
std_dev_distance_angstrom = std_dev_distance * lattice_param

# Calculate the medians for theta, phi, and distance
median_theta_rotation = np.median(theta_values)
median_phi_rotation = np.median(phi_values)
median_distance = np.median(distance_values)
median_distance_angstrom = median_distance * lattice_param

# Print the average, median rotations, and their standard deviations
print(f"Average θ rotation: {average_theta_rotation}°, Standard Deviation: {std_dev_theta}°")
print(f"Median θ rotation: {median_theta_rotation}°")
print(f"Average φ rotation: {average_phi_rotation}°, Standard Deviation: {std_dev_phi}°")
print(f"Median φ rotation: {median_phi_rotation}°")
print(f"Average Displacement: {average_distance_angstrom} angstroms, Standard Deviation: {std_dev_distance_angstrom} angstroms")
print(f"Median Displacement: {median_distance_angstrom} angstroms")
# Out:
# Average θ rotation: -0.20275043712627933°, Standard Deviation: 6.102268945060832°
# Median θ rotation: 0.0800106564656744°
# Average φ rotation: 1.0929780989606672°, Standard Deviation: 9.983615079977344°
# Median φ rotation: 1.495168820418428°
# Average Displacement: 0.3025926541539731 angstroms, Standard Deviation: 0.1934659657804893 angstroms
# Median Displacement: 0.2650381967548869 angstroms

# %%
#generate a table for average displacements

attributes=[r'$\theta$ ($^\circ$)', r'$\phi$ ($^\circ$)', r'Displacement of S (\AA)']
averages=[average_theta_rotation, average_phi_rotation,average_distance_angstrom]
medians=[median_theta_rotation,median_phi_rotation,median_distance_angstrom]
std_devs=[std_dev_theta,std_dev_phi,std_dev_distance_angstrom]

collated={
    r'Attribute':attributes,
    r'Average':averages,
    r'Median':medians,
    r'Standard Deviation':std_devs,
}

collated=pd.DataFrame(collated)

display(collated)

readytosave=False
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    collated.to_csv(f"{saveloc}/{cleaned_matname} dispersities.csv")
# Out:
#                  Attribute   Average    Median  Standard Deviation
# 0      $\theta$ ($^\circ$) -0.202750  0.080011            6.102269
# 1        $\phi$ ($^\circ$)  1.092978  1.495169            9.983615
# 2  Displacement of S (\AA)  0.302593  0.265038            0.193466

# %%
# Initialize variables to store the maximum distance and the corresponding unit
max_distance = 0
max_unit = None
max_sulfur_pair = None

# Iterate through the closest_sulfur_pairs dictionary
for unit, data in closest_sulfur_pairs.items():
    # Extract the distance value
    distance = data['distance']
    
    # Check if this is the maximum distance encountered so far
    if distance > max_distance:
        max_distance = distance
        max_unit = unit
        max_sulfur_pair = (data['start_sulfur'], data['closest_end_sulfur'])

# Print the results
print(f"Maximum distance: {max_distance}")
print(f"Unit number: {max_unit}")
print(f"Starting sulfur: {max_sulfur_pair[0]}")
print(f"Ending sulfur: {max_sulfur_pair[1]}")
print(f"Maximum θ:{rotation_data[max_unit]['rotation_theta']}°")
print(f"Maximum φ:{rotation_data[max_unit]['rotation_phi']}°")
# Out:
# Maximum distance: 0.03478617397760217
# Unit number: 79
# Starting sulfur: (0.87667, 0.79, 0.29)
# Ending sulfur: 4
# Maximum θ:-20.448229748551782°
# Maximum φ:30.455019170268997°

# %%
readytosave=True

fig, axs=plt.subplots(1,1, figsize=(6,6))

max_theta = rotation_data[max_unit]['rotation_theta']
max_phi = rotation_data[max_unit]['rotation_phi']

if abs(max_phi)>abs(max_theta):
    lim=abs(max_phi)*1.05
else:
    lim=abs(max_theta)*1.05
    
lim=85


for unit, data in rotation_data.items():
    if unit!=max_unit:
        axs.scatter(data['rotation_phi'],data['rotation_theta'],edgecolor=datacolor,facecolors='white',linewidths=2, marker='o')
    else:
        axs.scatter(rotation_data[max_unit]['rotation_phi'],rotation_data[max_unit]['rotation_theta'], edgecolor='#cc0000',facecolors='white',linewidths=2, marker='o')
#axs.scatter(0,0,color="orange",edgecolor='black',marker='^',s=150)

axs.text(-lim+lim*0.1,lim*.45,fr'Max displacement:' '\n' fr'{max_distance*lattice_param:.2f} \AA' '\n' fr'$\theta$: {max_theta:.2f}$^\circ$' '\n' fr'$\phi$: {max_phi:.2f}$^\circ$',bbox=dict(
        facecolor='none',     # Transparent fill color for the box
       edgecolor="#cc0000",  # Match the box edge color with the marker
        linewidth=2,        # Box edge width
       boxstyle='round,pad=0.3'  # Rounded box with padding
  ))
    
axs.set_xlim([-lim,lim])
axs.set_ylim([-lim,lim])

axs.xaxis.set_major_locator(ticker.MaxNLocator(8))
axs.yaxis.set_major_locator(ticker.MaxNLocator(8))
axs.xaxis.set_minor_locator(AutoMinorLocator(2))
axs.yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(which='major', direction='in', length=6)
plt.tick_params(which='minor', direction='in', length=4)

axs.set_xlabel(r'$\phi$ ($^{\circ}$)')
axs.set_ylabel(r'$\theta$ ($^{\circ}$)')
axs.set_title(material)

plt.tight_layout()

if readytosave==True:
    png=''.join((saveloc,'/',cleaned_matname,'rotation summary','.png'))
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    plt.savefig(png,dpi=800,format='png')


plt.show()

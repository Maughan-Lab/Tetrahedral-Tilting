# %%
#import necessary packages
import pandas as pd
from datetime import datetime, timedelta, timezone
import os
from PyEIS import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import csv
import glob
import statistics
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress
import math
from colour import Color
import re
import matplotlib.ticker as ticker
from matplotlib.ticker import FormatStrFormatter
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.ticker import AutoMinorLocator
# %matplotlib widget
from matplotlib.pyplot import rc

allSized=20
rc('text',usetex=True)
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']},size=allSized)
rc('text.latex', preamble=r'\usepackage{sfmath}')
plt.rc('font',   size=     allSized,**{'family':"sans-serif"})     # controls default text sizes
plt.rc('axes',   titlesize=allSized)     # fontsize of the axes title
plt.rc('axes',   labelsize=allSized)    # fontsize of the x and y labels
plt.rc('xtick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('ytick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('legend', fontsize= allSized)    # legend fontsize
plt.rc('figure', titlesize=allSized)  # fontsize of the figure title

# %%
# Function to calculate Euclidean distance between two points
def calculate_distance(coord1, coord2):
    return math.sqrt((coord1[0] - coord2[0])**2 + (coord1[1] - coord2[1])**2 + (coord1[2] - coord2[2])**2)


def cartesian_to_spherical(x, y, z):
    r = np.sqrt(x**2 + y**2 + z**2)
    theta = np.arccos(z / r) if r != 0 else 0  # θ: angle from z-axis
    phi = np.arctan2(y, x)  # φ: angle from x-axis in the xy-plane
    return r, np.degrees(theta), np.degrees(phi)

# Function to calculate the Euclidean distance between two points in 3D space
def euclidean_distance(coord1, coord2):
    return np.linalg.norm(np.array(coord1) - np.array(coord2))

# %%
start_file='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Python Processed Str/Consolidated strs/3by3/Li6PS5Br_3by3_P1_dualLi_limited rotation_beqpdfgui_site disorder_Lioccref.txt'

end_file='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/PDF SA_ Joint Refinement working copy/MW LPSB/MW LPSB Validation Station/MW LPSB Replicate 1_ working copy/MW_LPSB_Refinement_1_Joint.inp'

material=r'MW Li$_6$PS$_5$Br Replicate'

datacolor='#5a47ff'

lattice_param=30.014960

start_lattice_param=30.024

#filter non-alphanumeric and space characters from the material name so that it's easier to deal with from a file management perspective
cleaned_matname = filter(lambda x: x.isalnum() or x.isspace(), material)

# filter returns a generator, so we need to re-join the string
cleaned_matname = "".join(cleaned_matname)

print(cleaned_matname)

saveloc='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/Paper Plotting/PS4 Rotations and cifs/rotation plots'
# Out:
# MW Li6PS5Br Replicate

# %%
start_coordinates={}

# Regular expression pattern to match the lines with start_coordinates
pattern = re.compile(r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.-]+)\s+y\s+([\d.-]+)\s+z\s+([\d.-]+)")

# Open the file and process each line
with open(start_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)

# Example: Accessing the start_coordinates for a specific thiophosphate unit
example_unit = 1
print(f"start_coordinates for P{example_unit}: {start_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"start_coordinates for S{example_unit}{i}: {start_coordinates[example_unit]['S'][i]}")
    
min_distance = float('inf')
closest_pair = None

# Iterate over all pairs of different thiophosphate units
for index1, unit1 in start_coordinates.items():
    for index2, unit2 in start_coordinates.items():
        if index1 != index2:
            # Iterate over all pairs of sulfur atoms between the two units
            for sulfur1 in unit1['S'].values():
                for sulfur2 in unit2['S'].values():
                    distance = euclidean_distance(sulfur1, sulfur2)
                    if distance < min_distance:
                        min_distance = distance
                        closest_pair = ((index1, sulfur1), (index2, sulfur2))
min_distance_angstroms=start_lattice_param*min_distance
# Output the closest pair and the minimum distance
print(f"The closest sulfur atoms are between units {closest_pair[0][0]} and {closest_pair[1][0]} with a distance of {min_distance_angstroms:.4f}")
print(f"Coordinates: {closest_pair[0][1]} and {closest_pair[1][1]}")

closest_distances_start = []

# Iterate over all thiophosphate units
for index1, unit1 in start_coordinates.items():
    # Iterate over all sulfur atoms within the current unit
    for sulfur1 in unit1['S'].values():
        min_distance = float('inf')
        
        # Compare sulfur1 to all sulfur atoms in different units
        for index2, unit2 in start_coordinates.items():
            if index1 != index2:
                for sulfur2 in unit2['S'].values():
                    distance = euclidean_distance(sulfur1, sulfur2)
                    if distance < min_distance:
                        min_distance = distance
        
        # Store the minimum distance found for this sulfur atom
        closest_distances_start.append(min_distance)
closest_distances_start=np.asarray(closest_distances_start)
print(len(closest_distances_start))

# Calculate the median of the closest distances
median_distance = np.median(closest_distances_start)*start_lattice_param
average_distance=np.mean(closest_distances_start)*start_lattice_param

truncatevalue=4
closest_distances_start_trunc=closest_distances_start[closest_distances_start*start_lattice_param<truncatevalue]

# Output the median distance
print(f"The median distance between each sulfur atom and its closest sulfur from a different unit is {median_distance:.4f}")
print(f"The mean distance between each sulfur atom and its closest sulfur from a different unit is {average_distance:.4f}")
fig=plt.figure(figsize=(6,6))
plt.hist(closest_distances_start_trunc*start_lattice_param,bins=10,color=datacolor,edgecolor='black')
plt.xlim(3.65,3.8)
plt.show()
# Out:
# start_coordinates for P1: (0.25, 0.25, 0.083333)
# start_coordinates for S11: (0.29, 0.21, 0.12333)
# start_coordinates for S12: (0.21, 0.29, 0.12333)
# start_coordinates for S13: (0.29, 0.29, 0.04333)
# start_coordinates for S14: (0.21, 0.21, 0.04333)
# The closest sulfur atoms are between units 5 and 59 with a distance of 3.6796
# Coordinates: (0.29, 0.54333, 0.45667) and (0.29, 0.45667, 0.54333)
# 432
# The median distance between each sulfur atom and its closest sulfur from a different unit is 3.6800
# The mean distance between each sulfur atom and its closest sulfur from a different unit is 3.8475
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Initialize the dictionary to store the end_coordinates
end_coordinates = {}

# Regular expression pattern to match the lines with end_coordinates, accounting for '_0.00000' or any number
pattern = re.compile(r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.-]+)_[\d.-]+\s+y\s+([\d.-]+)_[\d.-]+\s+z\s+([\d.-]+)_[\d.-]+")

# Open the file and process each line
with open(end_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)

            
# Example: Accessing the end_coordinates for a specific thiophosphate unit
example_unit = 4
print(f"end_coordinates for P{example_unit}: {end_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"end_coordinates for S{example_unit}{i}: {end_coordinates[example_unit]['S'][i]}")
    
    
min_distance = float('inf')
closest_pair = None

# Iterate over all pairs of different thiophosphate units
for index1, unit1 in end_coordinates.items():
    for index2, unit2 in end_coordinates.items():
        if index1 != index2:
            # Iterate over all pairs of sulfur atoms between the two units
            for sulfur1 in unit1['S'].values():
                for sulfur2 in unit2['S'].values():
                    distance = euclidean_distance(sulfur1, sulfur2)
                    if distance < min_distance:
                        min_distance = distance
                        closest_pair = ((index1, sulfur1), (index2, sulfur2))
min_distance_angstroms=lattice_param*min_distance
# Output the closest pair and the minimum distance
print(f"The closest sulfur atoms are between units {closest_pair[0][0]} and {closest_pair[1][0]} with a distance of {min_distance_angstroms:.4f}")
print(f"Coordinates: {closest_pair[0][1]} and {closest_pair[1][1]}")

closest_distances = []

# Iterate over all thiophosphate units
for index1, unit1 in end_coordinates.items():
    # Iterate over all sulfur atoms within the current unit
    for sulfur1 in unit1['S'].values():
        min_distance = float('inf')
        
        # Compare sulfur1 to all sulfur atoms in different units
        for index2, unit2 in end_coordinates.items():
            if index1 != index2:
                for sulfur2 in unit2['S'].values():
                    distance = euclidean_distance(sulfur1, sulfur2)
                    if distance < min_distance:
                        min_distance = distance
        
        # Store the minimum distance found for this sulfur atom
        closest_distances.append(min_distance)
    
closest_distances=np.asarray(closest_distances)
print(f'There are {len(closest_distances)} closest S-S distances')

# Calculate the median of the closest distances
median_distance = np.median(closest_distances)*lattice_param
average_distance=np.mean(closest_distances)*lattice_param

truncatevaluedown=0
truncatevalueup=100
closest_distances_trunc=closest_distances[closest_distances*lattice_param<truncatevalueup]
closest_distances_trunc=closest_distances_trunc[closest_distances_trunc*lattice_param>truncatevaluedown]
print(f"Length of closest_distances_trunc: {len(closest_distances_trunc)}")
median_distance_trunc=np.median(closest_distances_trunc)*lattice_param
average_distance_trunc=np.mean(closest_distances_trunc)*lattice_param
# Output the median distance
print(f"The median distance between each sulfur atom and its closest sulfur from a different unit is {median_distance:.4f}")
print(f"The mean distance between each sulfur atom and its closest sulfur from a different unit is {average_distance:.4f}")

print(f"The median distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is {median_distance_trunc:.4f}")
print(f"The mean distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is {average_distance_trunc:.4f}")

bin_width = 0.1
bins = np.arange(min(closest_distances_trunc*lattice_param), max(closest_distances_trunc*lattice_param) + bin_width, bin_width)
fig=plt.figure(figsize=(6,6))
plt.hist(closest_distances_trunc*lattice_param,bins=bins,color=datacolor,edgecolor='black')
plt.xlim(3,10)

plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(1))
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(6))
plt.gca().xaxis.set_minor_locator(AutoMinorLocator(2))
plt.gca().yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(which='major', direction='out', length=6)
plt.tick_params(which='minor', direction='out', length=4)

plt.xlabel(r'Distance (\AA)')
plt.ylabel(r'Frequency')
plt.title(material)
plt.show()
# Out:
# end_coordinates for P4: (0.25, 0.58333, 0.08333)
# end_coordinates for S41: (0.28857, 0.61311, 0.03569)
# end_coordinates for S42: (0.21475, 0.63094, 0.11703)
# end_coordinates for S43: (0.20679, 0.53981, 0.05366)
# end_coordinates for S44: (0.28994, 0.54947, 0.12704)
# The closest sulfur atoms are between units 29 and 56 with a distance of 3.2710
# Coordinates: (0.12956, 0.20783, 0.61037) and (0.21145, 0.13647, 0.60154)
# There are 432 closest S-S distances
# Length of closest_distances_trunc: 432
# The median distance between each sulfur atom and its closest sulfur from a different unit is 3.6577
# The mean distance between each sulfur atom and its closest sulfur from a different unit is 3.8315
# The median distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is 3.6577
# The mean distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is 3.8315
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from collections import defaultdict

closest_distances = []
paired_sulfurs = set()  # To track all paired sulfurs (avoiding double pairing)
sulfur_pairs = set()    # To track all unique sulfur pairs (avoid duplicates like (1,2) and (2,1))

# Dictionary to store each sulfur's nearest neighbor
nearest_neighbor = defaultdict(lambda: {'sulfur': None, 'distance': float('inf')})

# First pass: find the nearest neighbor for each sulfur
for index1, unit1 in end_coordinates.items():
    for sulfur1_idx, sulfur1 in unit1['S'].items():
        for index2, unit2 in end_coordinates.items():
            if index1 < index2:
                for sulfur2_idx, sulfur2 in unit2['S'].items():
                    distance = euclidean_distance(sulfur1, sulfur2)
                    
                    # Check if sulfur2 is the closest to sulfur1
                    if distance < nearest_neighbor[(index1, sulfur1_idx)]['distance']:
                        nearest_neighbor[(index1, sulfur1_idx)] = {'sulfur': (index2, sulfur2_idx), 'distance': distance}
                    
                    # Check if sulfur1 is the closest to sulfur2
                    if distance < nearest_neighbor[(index2, sulfur2_idx)]['distance']:
                        nearest_neighbor[(index2, sulfur2_idx)] = {'sulfur': (index1, sulfur1_idx), 'distance': distance}

# Second pass: check for mutual nearest neighbors and avoid double counting
for (index1, sulfur1_idx), nearest1 in nearest_neighbor.items():
    index2, sulfur2_idx = nearest1['sulfur']
    nearest2 = nearest_neighbor[(index2, sulfur2_idx)]
    
    # Create the pair in a sorted order (to avoid (1,2) and (2,1) being treated differently)
    pair = tuple(sorted([(index1, sulfur1_idx), (index2, sulfur2_idx)]))

    # Check if sulfur2's nearest neighbor is sulfur1 (mutual nearest neighbors)
    if nearest2['sulfur'] == (index1, sulfur1_idx):
        # If mutual nearest neighbors and pair not already counted, add the pair
        if pair not in sulfur_pairs:
            sulfur_pairs.add(pair)
            paired_sulfurs.add((index1, sulfur1_idx))
            paired_sulfurs.add((index2, sulfur2_idx))
            closest_distances.append(nearest1['distance'])
    else:
        # If not mutual nearest neighbors and sulfur1 not already paired, include sulfur1's nearest neighbor
        if (index1, sulfur1_idx) not in paired_sulfurs:
            closest_distances.append(nearest1['distance'])
            paired_sulfurs.add((index1, sulfur1_idx))
            sulfur_pairs.add(pair)

# After the pairing process, check that all sulfur atoms are paired
unpaired_sulfurs = set()
for index, unit in end_coordinates.items():
    for sulfur_idx in unit['S'].keys():
        if (index, sulfur_idx) not in paired_sulfurs:
            unpaired_sulfurs.add((index, sulfur_idx))

# Output unpaired sulfurs if there are any
if unpaired_sulfurs:
    print(f"Unpaired sulfur atoms: {unpaired_sulfurs}")
else:
    print("All sulfur atoms are paired.")

closest_distances = np.asarray(closest_distances)
print(f'There are {len(closest_distances)} closest S-S distances')

# Calculate the median and mean of the closest distances
median_distance = np.median(closest_distances) * lattice_param
average_distance = np.mean(closest_distances) * lattice_param

truncatevaluedown = 0
truncatevalueup = 100
closest_distances_trunc = closest_distances[closest_distances * lattice_param < truncatevalueup]
closest_distances_trunc = closest_distances_trunc[closest_distances_trunc * lattice_param > truncatevaluedown]

print(f"Length of closest_distances_trunc: {len(closest_distances_trunc)}")
median_distance_trunc = np.median(closest_distances_trunc) * lattice_param
average_distance_trunc = np.mean(closest_distances_trunc) * lattice_param

# Output results
print(f"The median distance between each sulfur atom and its closest sulfur from a different unit is {median_distance:.4f}")
print(f"The mean distance between each sulfur atom and its closest sulfur from a different unit is {average_distance:.4f}")
print(f"The median distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is {median_distance_trunc:.4f}")
print(f"The mean distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is {average_distance_trunc:.4f}")

# Plotting the truncated closest distances
bin_width = 0.1
bins = np.arange(min(closest_distances_trunc * lattice_param), max(closest_distances_trunc * lattice_param) + bin_width, bin_width)
fig = plt.figure(figsize=(6, 6))
plt.hist(closest_distances_trunc * lattice_param, bins=bins, color=datacolor, edgecolor='black')
plt.xlim(3, 7.5)

plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(1))
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(6))
plt.gca().xaxis.set_minor_locator(AutoMinorLocator(2))
plt.gca().yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(which='major', direction='out', length=6)
plt.tick_params(which='minor', direction='out', length=4)

plt.xlabel(r'Distance (\AA)')
plt.ylabel(r'Frequency')
plt.title(material)
plt.show()
# Out:
# All sulfur atoms are paired.
# There are 274 closest S-S distances
# Length of closest_distances_trunc: 274
# The median distance between each sulfur atom and its closest sulfur from a different unit is 3.6835
# The mean distance between each sulfur atom and its closest sulfur from a different unit is 3.9276
# The median distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is 3.6835
# The mean distance between each sulfur atom and its closest sulfur from a different unit in the truncated dataset is 3.9276
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Dictionary to store closest sulfur pairs
closest_sulfur_pairs = {}

# Find the closest sulfur atom for each S1 from start to end units
for unit_number, start_sulfurs in start_coordinates.items():
    if 'S' in start_sulfurs:
        start_sulfur1_coords = start_sulfurs['S'].get(1)
        if start_sulfur1_coords:
            min_distance = float('inf')
            closest_sulfur = None
            for sulfur_number, end_sulfur_coords in end_coordinates[unit_number]['S'].items():
                distance = calculate_distance(start_sulfur1_coords, end_sulfur_coords)
                if distance < min_distance:
                    min_distance = distance
                    closest_sulfur = sulfur_number
            closest_sulfur_pairs[unit_number] = {
                'start_sulfur': start_sulfur1_coords,
                'closest_end_sulfur': closest_sulfur,
                'end_sulfur_coords': end_coordinates[unit_number]['S'][closest_sulfur],
                'distance': min_distance
            }

# Example: Print out the closest sulfur atom pairs
for unit, data in closest_sulfur_pairs.items():
    print(f"Unit {unit}:")
    print(f"  Start S{unit}1 Coordinates: {data['start_sulfur']}")
    print(f"  Closest End S{unit}{data['closest_end_sulfur']} Coordinates: {data['end_sulfur_coords']}")
    print(f"  Distance: {data['distance']:.5f}")
# Out:
# Unit 1:
#   Start S11 Coordinates: (0.29, 0.21, 0.12333)
#   Closest End S14 Coordinates: (0.2899, 0.21958, 0.12947)
#   Distance: 0.01138
# Unit 2:
#   Start S21 Coordinates: (0.29, 0.29, 0.37667)
#   Closest End S23 Coordinates: (0.29235, 0.29109, 0.38256)
#   Distance: 0.00643
# Unit 3:
#   Start S31 Coordinates: (0.29, 0.29, 0.71)
#   Closest End S34 Coordinates: (0.29681, 0.27913, 0.70986)
#   Distance: 0.01283
# Unit 4:
#   Start S41 Coordinates: (0.21, 0.62333, 0.12333)
#   Closest End S42 Coordinates: (0.21475, 0.63094, 0.11703)
#   Distance: 0.01096
# Unit 5:
#   Start S51 Coordinates: (0.29, 0.62333, 0.37667)
#   Closest End S54 Coordinates: (0.28527, 0.623, 0.37392)
#   Distance: 0.00548
# Unit 6:
#   Start S61 Coordinates: (0.29, 0.62333, 0.71)
#   Closest End S62 Coordinates: (0.2909, 0.59873, 0.69764)
#   Distance: 0.02755
# Unit 7:
#   Start S71 Coordinates: (0.29, 0.87667, 0.12333)
#   Closest End S72 Coordinates: (0.28547, 0.87743, 0.12632)
#   Distance: 0.00548
# Unit 8:
#   Start S81 Coordinates: (0.21, 0.87667, 0.37667)
#   Closest End S81 Coordinates: (0.21641, 0.87213, 0.37745)
#   Distance: 0.00789
# Unit 9:
#   Start S91 Coordinates: (0.29, 0.87667, 0.79)
#   Closest End S94 Coordinates: (0.28857, 0.87648, 0.78928)
#   Distance: 0.00161
# Unit 10:
#   Start S101 Coordinates: (0.62333, 0.21, 0.12333)
#   Closest End S101 Coordinates: (0.62622, 0.21418, 0.1224)
#   Distance: 0.00517
# Unit 11:
#   Start S111 Coordinates: (0.62333, 0.29, 0.37667)
#   Closest End S113 Coordinates: (0.62567, 0.28855, 0.37964)
#   Distance: 0.00405
# Unit 12:
#   Start S121 Coordinates: (0.62333, 0.29, 0.71)
#   Closest End S123 Coordinates: (0.63079, 0.28246, 0.71345)
#   Distance: 0.01115
# Unit 13:
#   Start S131 Coordinates: (0.54333, 0.62333, 0.12333)
#   Closest End S132 Coordinates: (0.54034, 0.62209, 0.11937)
#   Distance: 0.00511
# Unit 14:
#   Start S141 Coordinates: (0.62333, 0.62333, 0.37667)
#   Closest End S141 Coordinates: (0.61918, 0.63016, 0.38245)
#   Distance: 0.00986
# Unit 15:
#   Start S151 Coordinates: (0.62333, 0.62333, 0.71)
#   Closest End S152 Coordinates: (0.6104, 0.63389, 0.71318)
#   Distance: 0.01699
# Unit 16:
#   Start S161 Coordinates: (0.62333, 0.87667, 0.12333)
#   Closest End S161 Coordinates: (0.6234, 0.88388, 0.1277)
#   Distance: 0.00843
# Unit 17:
#   Start S171 Coordinates: (0.62333, 0.95667, 0.37667)
#   Closest End S174 Coordinates: (0.62813, 0.95219, 0.37954)
#   Distance: 0.00717
# Unit 18:
#   Start S181 Coordinates: (0.62333, 0.87667, 0.79)
#   Closest End S184 Coordinates: (0.62092, 0.87626, 0.79009)
#   Distance: 0.00245
# Unit 19:
#   Start S191 Coordinates: (0.87667, 0.29, 0.12333)
#   Closest End S193 Coordinates: (0.86695, 0.28145, 0.1178)
#   Distance: 0.01408
# Unit 20:
#   Start S201 Coordinates: (0.87667, 0.21, 0.37667)
#   Closest End S201 Coordinates: (0.88294, 0.20838, 0.37452)
#   Distance: 0.00682
# Unit 21:
#   Start S211 Coordinates: (0.87667, 0.29, 0.79)
#   Closest End S211 Coordinates: (0.88844, 0.29529, 0.79241)
#   Distance: 0.01313
# Unit 22:
#   Start S221 Coordinates: (0.87667, 0.62333, 0.12333)
#   Closest End S221 Coordinates: (0.87357, 0.61804, 0.12316)
#   Distance: 0.00613
# Unit 23:
#   Start S231 Coordinates: (0.87667, 0.54333, 0.37667)
#   Closest End S232 Coordinates: (0.88579, 0.54199, 0.37212)
#   Distance: 0.01028
# Unit 24:
#   Start S241 Coordinates: (0.87667, 0.62333, 0.79)
#   Closest End S241 Coordinates: (0.8719, 0.61601, 0.78969)
#   Distance: 0.00874
# Unit 25:
#   Start S251 Coordinates: (0.95667, 0.87667, 0.12333)
#   Closest End S253 Coordinates: (0.9556, 0.88184, 0.12708)
#   Distance: 0.00648
# Unit 26:
#   Start S261 Coordinates: (0.87667, 0.87667, 0.37667)
#   Closest End S262 Coordinates: (0.88487, 0.8681, 0.38093)
#   Distance: 0.01260
# Unit 27:
#   Start S271 Coordinates: (0.87667, 0.87667, 0.71)
#   Closest End S274 Coordinates: (0.88042, 0.87276, 0.7125)
#   Distance: 0.00597
# Unit 28:
#   Start S281 Coordinates: (0.12333, 0.21, 0.29)
#   Closest End S282 Coordinates: (0.12473, 0.20854, 0.28487)
#   Distance: 0.00551
# Unit 29:
#   Start S291 Coordinates: (0.12333, 0.21, 0.62333)
#   Closest End S291 Coordinates: (0.12956, 0.20783, 0.61037)
#   Distance: 0.01454
# Unit 30:
#   Start S301 Coordinates: (0.12333, 0.29, 0.87667)
#   Closest End S301 Coordinates: (0.11756, 0.29436, 0.8778)
#   Distance: 0.00732
# Unit 31:
#   Start S311 Coordinates: (0.12333, 0.62333, 0.21)
#   Closest End S314 Coordinates: (0.13258, 0.61309, 0.21337)
#   Distance: 0.01420
# Unit 32:
#   Start S321 Coordinates: (0.12333, 0.62333, 0.54333)
#   Closest End S323 Coordinates: (0.12521, 0.62594, 0.55041)
#   Distance: 0.00778
# Unit 33:
#   Start S331 Coordinates: (0.12333, 0.62333, 0.87667)
#   Closest End S331 Coordinates: (0.12039, 0.62612, 0.87861)
#   Distance: 0.00449
# Unit 34:
#   Start S341 Coordinates: (0.12333, 0.87667, 0.29)
#   Closest End S343 Coordinates: (0.13165, 0.89248, 0.29163)
#   Distance: 0.01794
# Unit 35:
#   Start S351 Coordinates: (0.12333, 0.87667, 0.62333)
#   Closest End S354 Coordinates: (0.12531, 0.87512, 0.61744)
#   Distance: 0.00640
# Unit 36:
#   Start S361 Coordinates: (0.12333, 0.87667, 0.95667)
#   Closest End S364 Coordinates: (0.11826, 0.87028, 0.95246)
#   Distance: 0.00918
# Unit 37:
#   Start S371 Coordinates: (0.37667, 0.29, 0.29)
#   Closest End S372 Coordinates: (0.37285, 0.26553, 0.29991)
#   Distance: 0.02668
# Unit 38:
#   Start S381 Coordinates: (0.37667, 0.29, 0.62333)
#   Closest End S381 Coordinates: (0.36937, 0.28073, 0.62168)
#   Distance: 0.01191
# Unit 39:
#   Start S391 Coordinates: (0.37667, 0.21, 0.87667)
#   Closest End S391 Coordinates: (0.38506, 0.20919, 0.87208)
#   Distance: 0.00960
# Unit 40:
#   Start S401 Coordinates: (0.37667, 0.62333, 0.29)
#   Closest End S401 Coordinates: (0.37362, 0.62371, 0.28419)
#   Distance: 0.00657
# Unit 41:
#   Start S411 Coordinates: (0.37667, 0.62333, 0.62333)
#   Closest End S413 Coordinates: (0.37183, 0.61683, 0.62232)
#   Distance: 0.00817
# Unit 42:
#   Start S421 Coordinates: (0.37667, 0.62333, 0.95667)
#   Closest End S422 Coordinates: (0.37437, 0.62448, 0.95087)
#   Distance: 0.00634
# Unit 43:
#   Start S431 Coordinates: (0.37667, 0.87667, 0.21)
#   Closest End S432 Coordinates: (0.38073, 0.87493, 0.20976)
#   Distance: 0.00442
# Unit 44:
#   Start S441 Coordinates: (0.37667, 0.87667, 0.54333)
#   Closest End S441 Coordinates: (0.38126, 0.87609, 0.54147)
#   Distance: 0.00499
# Unit 45:
#   Start S451 Coordinates: (0.37667, 0.87667, 0.87667)
#   Closest End S454 Coordinates: (0.40277, 0.88734, 0.85667)
#   Distance: 0.03457
# Unit 46:
#   Start S461 Coordinates: (0.71, 0.29, 0.29)
#   Closest End S464 Coordinates: (0.717, 0.28655, 0.2972)
#   Distance: 0.01062
# Unit 47:
#   Start S471 Coordinates: (0.71, 0.29, 0.62333)
#   Closest End S474 Coordinates: (0.70572, 0.29063, 0.61559)
#   Distance: 0.00887
# Unit 48:
#   Start S481 Coordinates: (0.79, 0.29, 0.87667)
#   Closest End S482 Coordinates: (0.78863, 0.29283, 0.88026)
#   Distance: 0.00477
# Unit 49:
#   Start S491 Coordinates: (0.71, 0.62333, 0.29)
#   Closest End S492 Coordinates: (0.71406, 0.62478, 0.29054)
#   Distance: 0.00434
# Unit 50:
#   Start S501 Coordinates: (0.71, 0.62333, 0.62333)
#   Closest End S501 Coordinates: (0.71034, 0.62448, 0.62057)
#   Distance: 0.00301
# Unit 51:
#   Start S511 Coordinates: (0.79, 0.62333, 0.87667)
#   Closest End S514 Coordinates: (0.78864, 0.62781, 0.88231)
#   Distance: 0.00733
# Unit 52:
#   Start S521 Coordinates: (0.79, 0.87667, 0.29)
#   Closest End S523 Coordinates: (0.78723, 0.87026, 0.28336)
#   Distance: 0.00964
# Unit 53:
#   Start S531 Coordinates: (0.79, 0.87667, 0.62333)
#   Closest End S533 Coordinates: (0.79164, 0.8737, 0.61608)
#   Distance: 0.00800
# Unit 54:
#   Start S541 Coordinates: (0.71, 0.87667, 0.87667)
#   Closest End S542 Coordinates: (0.71703, 0.87805, 0.87112)
#   Distance: 0.00906
# Unit 55:
#   Start S551 Coordinates: (0.21, 0.12333, 0.29)
#   Closest End S552 Coordinates: (0.21059, 0.13701, 0.26475)
#   Distance: 0.02872
# Unit 56:
#   Start S561 Coordinates: (0.21, 0.12333, 0.62333)
#   Closest End S563 Coordinates: (0.21145, 0.13647, 0.60154)
#   Distance: 0.02549
# Unit 57:
#   Start S571 Coordinates: (0.29, 0.12333, 0.87667)
#   Closest End S572 Coordinates: (0.27748, 0.12166, 0.8675)
#   Distance: 0.01561
# Unit 58:
#   Start S581 Coordinates: (0.29, 0.37667, 0.29)
#   Closest End S584 Coordinates: (0.29003, 0.37386, 0.28474)
#   Distance: 0.00596
# Unit 59:
#   Start S591 Coordinates: (0.29, 0.37667, 0.62333)
#   Closest End S594 Coordinates: (0.29207, 0.37427, 0.61611)
#   Distance: 0.00789
# Unit 60:
#   Start S601 Coordinates: (0.21, 0.37667, 0.87667)
#   Closest End S602 Coordinates: (0.20093, 0.37145, 0.9029)
#   Distance: 0.02824
# Unit 61:
#   Start S611 Coordinates: (0.29, 0.71, 0.29)
#   Closest End S613 Coordinates: (0.2936, 0.71089, 0.28481)
#   Distance: 0.00638
# Unit 62:
#   Start S621 Coordinates: (0.29, 0.71, 0.62333)
#   Closest End S624 Coordinates: (0.29348, 0.71458, 0.62203)
#   Distance: 0.00590
# Unit 63:
#   Start S631 Coordinates: (0.29, 0.79, 0.87667)
#   Closest End S632 Coordinates: (0.2784, 0.78984, 0.86925)
#   Distance: 0.01377
# Unit 64:
#   Start S641 Coordinates: (0.62333, 0.12333, 0.21)
#   Closest End S643 Coordinates: (0.62704, 0.11621, 0.20937)
#   Distance: 0.00805
# Unit 65:
#   Start S651 Coordinates: (0.62333, 0.12333, 0.54333)
#   Closest End S653 Coordinates: (0.62807, 0.12124, 0.54864)
#   Distance: 0.00742
# Unit 66:
#   Start S661 Coordinates: (0.62333, 0.12333, 0.87667)
#   Closest End S664 Coordinates: (0.61463, 0.12349, 0.87139)
#   Distance: 0.01018
# Unit 67:
#   Start S671 Coordinates: (0.62333, 0.37667, 0.29)
#   Closest End S672 Coordinates: (0.63212, 0.38221, 0.28277)
#   Distance: 0.01266
# Unit 68:
#   Start S681 Coordinates: (0.62333, 0.37667, 0.62333)
#   Closest End S682 Coordinates: (0.63199, 0.3784, 0.6118)
#   Distance: 0.01452
# Unit 69:
#   Start S691 Coordinates: (0.62333, 0.37667, 0.95667)
#   Closest End S692 Coordinates: (0.62146, 0.36967, 0.94796)
#   Distance: 0.01133
# Unit 70:
#   Start S701 Coordinates: (0.62333, 0.71, 0.29)
#   Closest End S701 Coordinates: (0.6227, 0.71575, 0.29381)
#   Distance: 0.00693
# Unit 71:
#   Start S711 Coordinates: (0.62333, 0.71, 0.62333)
#   Closest End S714 Coordinates: (0.62802, 0.70694, 0.61146)
#   Distance: 0.01312
# Unit 72:
#   Start S721 Coordinates: (0.62333, 0.79, 0.87667)
#   Closest End S721 Coordinates: (0.61461, 0.79209, 0.87317)
#   Distance: 0.00963
# Unit 73:
#   Start S731 Coordinates: (0.87667, 0.12333, 0.29)
#   Closest End S731 Coordinates: (0.8819, 0.12606, 0.2901)
#   Distance: 0.00590
# Unit 74:
#   Start S741 Coordinates: (0.87667, 0.12333, 0.62333)
#   Closest End S743 Coordinates: (0.86961, 0.1161, 0.62012)
#   Distance: 0.01060
# Unit 75:
#   Start S751 Coordinates: (0.95667, 0.12333, 0.87667)
#   Closest End S752 Coordinates: (0.94816, 0.11923, 0.86807)
#   Distance: 0.01277
# Unit 76:
#   Start S761 Coordinates: (0.87667, 0.37667, 0.21)
#   Closest End S764 Coordinates: (0.87449, 0.38086, 0.21024)
#   Distance: 0.00473
# Unit 77:
#   Start S771 Coordinates: (0.87667, 0.37667, 0.54333)
#   Closest End S773 Coordinates: (0.87594, 0.37457, 0.54854)
#   Distance: 0.00566
# Unit 78:
#   Start S781 Coordinates: (0.87667, 0.37667, 0.87667)
#   Closest End S783 Coordinates: (0.87436, 0.37969, 0.87814)
#   Distance: 0.00408
# Unit 79:
#   Start S791 Coordinates: (0.87667, 0.79, 0.29)
#   Closest End S793 Coordinates: (0.87779, 0.78889, 0.29022)
#   Distance: 0.00159
# Unit 80:
#   Start S801 Coordinates: (0.87667, 0.79, 0.62333)
#   Closest End S801 Coordinates: (0.87923, 0.79174, 0.62204)
#   Distance: 0.00335
# Unit 81:
#   Start S811 Coordinates: (0.87667, 0.71, 0.87667)
#   Closest End S814 Coordinates: (0.87254, 0.71038, 0.88297)
#   Distance: 0.00754
# Unit 82:
#   Start S821 Coordinates: (0.04333, 0.12333, 0.12333)
#   Closest End S823 Coordinates: (0.0402, 0.12045, 0.12094)
#   Distance: 0.00488
# Unit 83:
#   Start S831 Coordinates: (0.12333, 0.12333, 0.37667)
#   Closest End S832 Coordinates: (0.11835, 0.12223, 0.37292)
#   Distance: 0.00633
# Unit 84:
#   Start S841 Coordinates: (0.12333, 0.12333, 0.71)
#   Closest End S844 Coordinates: (0.121, 0.12374, 0.70999)
#   Distance: 0.00237
# Unit 85:
#   Start S851 Coordinates: (0.12333, 0.37667, 0.12333)
#   Closest End S853 Coordinates: (0.11763, 0.37393, 0.12395)
#   Distance: 0.00635
# Unit 86:
#   Start S861 Coordinates: (0.04333, 0.37667, 0.37667)
#   Closest End S863 Coordinates: (0.04422, 0.38067, 0.37393)
#   Distance: 0.00493
# Unit 87:
#   Start S871 Coordinates: (0.12333, 0.37667, 0.79)
#   Closest End S873 Coordinates: (0.11781, 0.37741, 0.79385)
#   Distance: 0.00677
# Unit 88:
#   Start S881 Coordinates: (0.12333, 0.71, 0.12333)
#   Closest End S883 Coordinates: (0.12893, 0.70669, 0.10974)
#   Distance: 0.01507
# Unit 89:
#   Start S891 Coordinates: (0.12333, 0.79, 0.37667)
#   Closest End S891 Coordinates: (0.12935, 0.77825, 0.37499)
#   Distance: 0.01331
# Unit 90:
#   Start S901 Coordinates: (0.12333, 0.71, 0.79)
#   Closest End S901 Coordinates: (0.11817, 0.70771, 0.79063)
#   Distance: 0.00568
# Unit 91:
#   Start S911 Coordinates: (0.37667, 0.12333, 0.12333)
#   Closest End S912 Coordinates: (0.37587, 0.11461, 0.12816)
#   Distance: 0.01000
# Unit 92:
#   Start S921 Coordinates: (0.37667, 0.04333, 0.37667)
#   Closest End S921 Coordinates: (0.37242, 0.04481, 0.38187)
#   Distance: 0.00688
# Unit 93:
#   Start S931 Coordinates: (0.37667, 0.12333, 0.79)
#   Closest End S933 Coordinates: (0.38103, 0.11978, 0.79532)
#   Distance: 0.00774
# Unit 94:
#   Start S941 Coordinates: (0.37667, 0.45667, 0.12333)
#   Closest End S942 Coordinates: (0.38102, 0.46144, 0.1204)
#   Distance: 0.00709
# Unit 95:
#   Start S951 Coordinates: (0.37667, 0.37667, 0.37667)
#   Closest End S954 Coordinates: (0.37518, 0.36476, 0.40139)
#   Distance: 0.02748
# Unit 96:
#   Start S961 Coordinates: (0.37667, 0.37667, 0.71)
#   Closest End S964 Coordinates: (0.37912, 0.37043, 0.71676)
#   Distance: 0.00952
# Unit 97:
#   Start S971 Coordinates: (0.37667, 0.79, 0.12333)
#   Closest End S974 Coordinates: (0.37317, 0.78246, 0.12464)
#   Distance: 0.00842
# Unit 98:
#   Start S981 Coordinates: (0.37667, 0.71, 0.37667)
#   Closest End S981 Coordinates: (0.37648, 0.71454, 0.37448)
#   Distance: 0.00504
# Unit 99:
#   Start S991 Coordinates: (0.37667, 0.79, 0.79)
#   Closest End S994 Coordinates: (0.37869, 0.79158, 0.78845)
#   Distance: 0.00300
# Unit 100:
#   Start S1001 Coordinates: (0.71, 0.12333, 0.12333)
#   Closest End S1001 Coordinates: (0.70827, 0.12317, 0.11971)
#   Distance: 0.00402
# Unit 101:
#   Start S1011 Coordinates: (0.79, 0.12333, 0.37667)
#   Closest End S1011 Coordinates: (0.78726, 0.12261, 0.37521)
#   Distance: 0.00319
# Unit 102:
#   Start S1021 Coordinates: (0.71, 0.12333, 0.79)
#   Closest End S1024 Coordinates: (0.71843, 0.12775, 0.79102)
#   Distance: 0.00957
# Unit 103:
#   Start S1031 Coordinates: (0.79, 0.37667, 0.12333)
#   Closest End S1031 Coordinates: (0.78659, 0.38273, 0.12983)
#   Distance: 0.00952
# Unit 104:
#   Start S1041 Coordinates: (0.71, 0.37667, 0.37667)
#   Closest End S1041 Coordinates: (0.73284, 0.36908, 0.37091)
#   Distance: 0.02475
# Unit 105:
#   Start S1051 Coordinates: (0.79, 0.37667, 0.79)
#   Closest End S1054 Coordinates: (0.78693, 0.40046, 0.80501)
#   Distance: 0.02830
# Unit 106:
#   Start S1061 Coordinates: (0.71, 0.79, 0.12333)
#   Closest End S1062 Coordinates: (0.70495, 0.78563, 0.12008)
#   Distance: 0.00743
# Unit 107:
#   Start S1071 Coordinates: (0.79, 0.79, 0.37667)
#   Closest End S1072 Coordinates: (0.7987, 0.78421, 0.38334)
#   Distance: 0.01240
# Unit 108:
#   Start S1081 Coordinates: (0.71, 0.79, 0.79)
#   Closest End S1083 Coordinates: (0.71376, 0.79509, 0.78614)
#   Distance: 0.00741

# %%
# Dictionary to store rotation information
rotation_data = {}

# Calculate theta and phi for each thiophosphate unit
for unit, data in closest_sulfur_pairs.items():
    # Vector from P to starting S1
    start_p_coords = start_coordinates[unit]['P']
    start_s_coords = data['start_sulfur']
    start_vector = np.array([start_s_coords[0] - start_p_coords[0], 
                             start_s_coords[1] - start_p_coords[1], 
                             start_s_coords[2] - start_p_coords[2]])
    
    # Vector from P to ending Sx
    end_p_coords=end_coordinates[unit]['P']
    end_s_coords = data['end_sulfur_coords']
    end_vector = np.array([end_s_coords[0] - end_p_coords[0], 
                           end_s_coords[1] - end_p_coords[1], 
                           end_s_coords[2] - end_p_coords[2]])
    
    # Convert vectors to spherical coordinates
    start_r, start_theta, start_phi = cartesian_to_spherical(*start_vector)
    end_r, end_theta, end_phi = cartesian_to_spherical(*end_vector)
    
    # Store the rotation data
    rotation_data[unit] = {
        'start_theta': start_theta, 'start_phi': start_phi,  # Reference (0, 0)
        'end_theta': end_theta, 
        'end_phi': end_phi,
        'rotation_theta': end_theta-start_theta,  # Since start_theta is 0
        'rotation_phi': end_phi-start_phi  # Since start_phi is 0
    }

# Example: Print the rotational data for each thiophosphate unit
for unit, data in rotation_data.items():
    print(f"Unit {unit}:")
    print(f"  Start θ: {data['start_theta']}°, Start φ: {data['start_phi']}°")
    print(f"  End θ: {data['end_theta']}°, End φ: {data['end_phi']}°")
    print(f"  Rotation θ: {data['rotation_theta']}°, Rotation φ: {data['rotation_phi']}°")
# Out:
# Unit 1:
#   Start θ: 54.737636079599916°, Start φ: -45.00000000000002°
#   End θ: 47.39811659152129°, End φ: -37.32211516855512°
#   Rotation θ: -7.339519488078629°, Rotation φ: 7.677884831444899°
# Unit 2:
#   Start θ: 125.2623639204001°, Start φ: 45.0°
#   End θ: 120.03048864882747°, End φ: 44.13486103110152°
#   Rotation θ: -5.231875271572633°, Rotation φ: -0.8651389688984779°
# Unit 3:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 126.05639279771592°, End φ: 31.894125129192293°
#   Rotation θ: 0.7920031149612328°, Rotation φ: -13.105874870807707°
# Unit 4:
#   Start θ: 54.73662324273851°, Start φ: 135.00214867230594°
#   End θ: 60.365286282287926°, End φ: 126.51590209447087°
#   Rotation θ: 5.628663039549416°, Rotation φ: -8.486246577835061°
# Unit 5:
#   Start θ: 125.26337675726151°, Start φ: 44.997851327694114°
#   End θ: 128.84658443612602°, End φ: 48.36018599619486°
#   Rotation θ: 3.583207678864511°, Rotation φ: 3.3623346685007434°
# Unit 6:
#   Start θ: 125.26540254493958°, Start φ: 44.997851327694114°
#   End θ: 140.14933657521263°, End φ: 20.63276689241212°
#   Rotation θ: 14.883934030273053°, Rotation φ: -24.365084435281993°
# Unit 7:
#   Start θ: 54.7366232427385°, Start φ: -44.997851327694114°
#   End θ: 50.89786993673925°, End φ: -47.88879699969061°
#   Rotation θ: -3.838753305999255°, Rotation φ: -2.890945671996498°
# Unit 8:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230594°
#   End θ: 125.10880195138509°, End φ: -127.02190272728703°
#   Rotation θ: -0.1545748058764218°, Rotation φ: 7.980245945018908°
# Unit 9:
#   Start θ: 54.73459745506044°, Start φ: -44.997851327694114°
#   End θ: 54.80996247830561°, End φ: -46.17834022692801°
#   Rotation θ: 0.07536502324516903°, Rotation φ: -1.180488899233893°
# Unit 10:
#   Start θ: 54.73662324273851°, Start φ: -45.00214867230591°
#   End θ: 55.03986256450642°, End φ: -39.86727259982929°
#   Rotation θ: 0.30323932176791146°, Rotation φ: 5.134876072476615°
# Unit 11:
#   Start θ: 125.26337675726151°, Start φ: 45.00214867230589°
#   End θ: 122.89043839092649°, End φ: 42.317439592820406°
#   Rotation θ: -2.3729383663350205°, Rotation φ: -2.6847090794854864°
# Unit 12:
#   Start θ: 125.26540254493958°, Start φ: 45.00214867230589°
#   End θ: 122.44274458743875°, End φ: 34.36995658516566°
#   Rotation θ: -2.822657957500823°, Rotation φ: -10.632192087140233°
# Unit 13:
#   Start θ: 54.737636155562235°, Start φ: 135.0042971834554°
#   End θ: 58.09228693759577°, End φ: 137.96202078163375°
#   Rotation θ: 3.354650782033538°, Rotation φ: 2.9577235981783474°
# Unit 14:
#   Start θ: 125.26438968275463°, Start φ: 45.0°
#   End θ: 120.1234837781648°, End φ: 52.56468265756286°
#   Rotation θ: -5.140905904589829°, Rotation φ: 7.564682657562862°
# Unit 15:
#   Start θ: 125.2664154957558°, Start φ: 45.0°
#   End θ: 122.70108168202268°, End φ: 61.835248462439274°
#   Rotation θ: -2.565333813733119°, Rotation φ: 16.835248462439274°
# Unit 16:
#   Start θ: 54.735610317245396°, Start φ: -45.0°
#   End θ: 49.40490451781243°, End φ: -39.29407847575685°
#   Rotation θ: -5.3307057994329625°, Rotation φ: 5.705921524243152°
# Unit 17:
#   Start θ: 125.26236384443777°, Start φ: 45.00429718345539°
#   End θ: 123.00116694096417°, End φ: 38.40939123185115°
#   Rotation θ: -2.2611969034736035°, Rotation φ: -6.59490595160424°
# Unit 18:
#   Start θ: 54.733584504244206°, Start φ: -45.0°
#   End θ: 54.005535451622976°, End φ: -47.07056096819466°
#   Rotation θ: -0.7280490526212304°, Rotation φ: -2.0705609681946626°
# Unit 19:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769412°
#   End θ: 59.633638177055666°, End φ: 147.6849184719989°
#   Rotation θ: 4.897014934317163°, Rotation φ: 12.687067144304791°
# Unit 20:
#   Start θ: 125.26337675726151°, Start φ: -134.9978513276941°
#   End θ: 128.19547774289487°, End φ: -129.02226578712927°
#   Rotation θ: 2.9321009856333546°, Rotation φ: 5.975585540564822°
# Unit 21:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769412°
#   End θ: 51.526724471516076°, End φ: 121.93596415947854°
#   Rotation θ: -3.2078729835443625°, Rotation φ: -13.061887168215577°
# Unit 22:
#   Start θ: 54.735610317245396°, Start φ: 135.0°
#   End θ: 54.25566671694706°, End φ: 141.15424063934705°
#   Rotation θ: -0.47994360029833416°, Rotation φ: 6.1542406393470515°
# Unit 23:
#   Start θ: 125.26236384443777°, Start φ: -134.99570281654462°
#   End θ: 130.80635670235742°, End φ: -126.75885945246601°
#   Rotation θ: 5.543992857919648°, Rotation φ: 8.23684336407861°
# Unit 24:
#   Start θ: 54.733584504244206°, Start φ: 135.0°
#   End θ: 54.39522753923067°, End φ: 143.87230913446194°
#   Rotation θ: -0.3383569650135385°, Rotation φ: 8.872309134461943°
# Unit 25:
#   Start θ: 54.737636155562235°, Start φ: -44.995702816544615°
#   End θ: 50.05269405755957°, End φ: -41.81844900192778°
#   Rotation θ: -4.684942098002665°, Rotation φ: 3.177253814616833°
# Unit 26:
#   Start θ: 125.26438968275463°, Start φ: -135.0°
#   End θ: 121.61778512451865°, End φ: -123.21377704805889°
#   Rotation θ: -3.6466045582359783°, Rotation φ: 11.786222951941113°
# Unit 27:
#   Start θ: 125.2664154957558°, Start φ: -135.0°
#   End θ: 123.36847296726177°, End φ: -129.54145399114415°
#   Rotation θ: -1.8979425284940277°, Rotation φ: 5.458546008855848°
# Unit 28:
#   Start θ: 54.73459745506047°, Start φ: -45.002148672305964°
#   End θ: 59.241270565746355°, End φ: -45.04148860934029°
#   Rotation θ: 4.506673110685888°, Rotation φ: -0.03933993703432748°
# Unit 29:
#   Start θ: 54.73662324273844°, Start φ: -45.002148672305964°
#   End θ: 66.62950147888765°, End φ: -42.37039013207714°
#   Rotation θ: 11.892878236149208°, Rotation φ: 2.631758540228823°
# Unit 30:
#   Start θ: 125.26337675726158°, Start φ: 45.002148672305935°
#   End θ: 124.74981316213659°, End φ: 52.34474550540719°
#   Rotation θ: -0.5135635951249924°, Rotation φ: 7.342596833101254°
# Unit 31:
#   Start θ: 125.2664154957558°, Start φ: 45.00000000000005°
#   End θ: 122.47941159401428°, End φ: 31.14305606447207°
#   Rotation θ: -2.787003901741514°, Rotation φ: -13.85694393552798°
# Unit 32:
#   Start θ: 125.26844120745872°, Start φ: 45.00000000000005°
#   End θ: 118.85485936832865°, End φ: 45.49502755722819°
#   Rotation θ: -6.4135818391300745°, Rotation φ: 0.4950275572281413°
# Unit 33:
#   Start θ: 125.26438968275468°, Start φ: 45.00000000000005°
#   End θ: 123.91479957658272°, End φ: 49.104483700272134°
#   Rotation θ: -1.3495901061719593°, Rotation φ: 4.104483700272084°
# Unit 34:
#   Start θ: 54.73358450424422°, Start φ: -45.00000000000005°
#   End θ: 52.389324077161284°, End φ: -26.59350227770053°
#   Rotation θ: -2.3442604270829364°, Rotation φ: 18.40649772229952°
# Unit 35:
#   Start θ: 54.735610317245325°, Start φ: -45.00000000000005°
#   End θ: 59.99376658617694°, End φ: -44.7050524654307°
#   Rotation θ: 5.258156268931614°, Rotation φ: 0.29494753456935285°
# Unit 36:
#   Start θ: 54.731558792541286°, Start φ: -45.00000000000005°
#   End θ: 58.35347449313033°, End φ: -53.02156906316034°
#   Rotation θ: 3.6219157005890423°, Rotation φ: -8.021569063160293°
# Unit 37:
#   Start θ: 54.73459745506047°, Start φ: 134.99785132769406°
#   End θ: 42.96851125401704°, End φ: 160.48545034762313°
#   Rotation θ: -11.766086201043429°, Rotation φ: 25.487599019929064°
# Unit 38:
#   Start θ: 54.73662324273844°, Start φ: 134.99785132769406°
#   End θ: 55.788462867616616°, End φ: 146.98890751764807°
#   Rotation θ: 1.051839624878177°, Rotation φ: 11.991056189954008°
# Unit 39:
#   Start θ: 125.26337675726155°, Start φ: -134.99785132769406°
#   End θ: 130.82073642921537°, End φ: -127.76011188060978°
#   Rotation θ: 5.557359671953819°, Rotation φ: 7.23773944708428°
# Unit 40:
#   Start θ: 54.73358450424422°, Start φ: 134.99999999999997°
#   End θ: 59.91823038202329°, End φ: 136.83300415797626°
#   Rotation θ: 5.184645877779069°, Rotation φ: 1.8330041579762906°
# Unit 41:
#   Start θ: 54.735610317245325°, Start φ: 134.99999999999997°
#   End θ: 55.13904279130043°, End φ: 143.23656190914727°
#   Rotation θ: 0.4034324740551085°, Rotation φ: 8.236561909147298°
# Unit 42:
#   Start θ: 54.731558792541286°, Start φ: 134.99999999999997°
#   End θ: 59.90655838203514°, End φ: 135.789526373826°
#   Rotation θ: 5.174999589493858°, Rotation φ: 0.7895263738260212°
# Unit 43:
#   Start θ: 125.2664154957558°, Start φ: -134.99999999999997°
#   End θ: 126.15041071646232°, End φ: -130.72991714691966°
#   Rotation θ: 0.8839952207065238°, Rotation φ: 4.270082853080311°
# Unit 44:
#   Start θ: 125.26844120745872°, Start φ: -134.99999999999997°
#   End θ: 127.85576881996562°, End φ: -131.10786420543175°
#   Rotation θ: 2.587327612506897°, Rotation φ: 3.892135794568219°
# Unit 45:
#   Start θ: 125.26438968275468°, Start φ: -134.99999999999997°
#   End θ: 151.5888048077195°, End φ: -115.35709150278109°
#   Rotation θ: 26.324415124964816°, Rotation φ: 19.642908497218883°
# Unit 46:
#   Start θ: 54.73561031724537°, Start φ: 135.00000000000006°
#   End θ: 46.213717284979964°, End φ: 132.07802082504813°
#   Rotation θ: -8.521893032265403°, Rotation φ: -2.921979174951929°
# Unit 47:
#   Start θ: 54.73763607959988°, Start φ: 135.00000000000006°
#   End θ: 61.772704795359154°, End φ: 137.46144063222889°
#   Rotation θ: 7.035068715759273°, Rotation φ: 2.461440632228829°
# Unit 48:
#   Start θ: 125.26236392040013°, Start φ: 44.999999999999964°
#   End θ: 122.2629670146917°, End φ: 47.951502301327906°
#   Rotation θ: -2.999396905708437°, Rotation φ: 2.951502301327942°
# Unit 49:
#   Start θ: 54.734597455060495°, Start φ: 135.00214867230594°
#   End θ: 53.53739669974415°, End φ: 130.9275368832359°
#   Rotation θ: -1.197200755316345°, Rotation φ: -4.0746117890700475°
# Unit 50:
#   Start θ: 54.73662324273847°, Start φ: 135.00214867230594°
#   End θ: 56.91145219378338°, End φ: 133.94368223096942°
#   Rotation θ: 2.1748289510449155°, Rotation φ: -1.0584664413365203°
# Unit 51:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769408°
#   End θ: 120.24934779369165°, End φ: 49.01898925328534°
#   Rotation θ: -5.014028963569871°, Rotation φ: 4.021137925591262°
# Unit 52:
#   Start θ: 54.734597455060495°, Start φ: -44.99785132769408°
#   End θ: 60.72086181992627°, End φ: -51.26349061433452°
#   Rotation θ: 5.986264364865775°, Rotation φ: -6.265639286640443°
# Unit 53:
#   Start θ: 54.73662324273847°, Start φ: -44.99785132769408°
#   End θ: 61.30669476949306°, End φ: -45.900568623679895°
#   Rotation θ: 6.570071526754596°, Rotation φ: -0.9027172959858163°
# Unit 54:
#   Start θ: 125.26337675726153°, Start φ: -135.00214867230594°
#   End θ: 131.8927768186586°, End φ: -130.48747670913554°
#   Rotation θ: 6.629400061397078°, Rotation φ: 4.5146719631704°
# Unit 55:
#   Start θ: 54.73459745506047°, Start φ: 135.00214867230596°
#   End θ: 77.51100366132005°, End φ: 126.2848281779274°
#   Rotation θ: 22.77640620625958°, Rotation φ: -8.71732049437857°
# Unit 56:
#   Start θ: 54.73662324273844°, Start φ: 135.00214867230596°
#   End θ: 74.49711493258535°, End φ: 125.95871652715596°
#   Rotation θ: 19.76049168984691°, Rotation φ: -9.043432145150007°
# Unit 57:
#   Start θ: 125.26337675726158°, Start φ: 44.997851327694065°
#   End θ: 136.19358621795482°, End φ: 54.36205363706117°
#   Rotation θ: 10.930209460693234°, Rotation φ: 9.364202309367109°
# Unit 58:
#   Start θ: 54.73459745506047°, Start φ: -44.99785132769408°
#   End θ: 59.343308770164036°, End φ: -46.922048692606744°
#   Rotation θ: 4.6087113151035695°, Rotation φ: -1.924197364912665°
# Unit 59:
#   Start θ: 54.73662324273844°, Start φ: -44.99785132769408°
#   End θ: 61.24179532327489°, End φ: -45.22383699595552°
#   Rotation θ: 6.505172080536454°, Rotation φ: -0.22598566826144406°
# Unit 60:
#   Start θ: 125.26337675726155°, Start φ: -135.00214867230594°
#   End θ: 101.65978280214526°, End φ: -137.33817249321257°
#   Rotation θ: -23.603593955116295°, Rotation φ: -2.3360238209066324°
# Unit 61:
#   Start θ: 54.73561031724537°, Start φ: -45.00000000000004°
#   End θ: 59.276040691518276°, End φ: -41.89268788790092°
#   Rotation θ: 4.540430374272908°, Rotation φ: 3.107312112099123°
# Unit 62:
#   Start θ: 54.73763607959988°, Start φ: -45.00000000000004°
#   End θ: 55.391514951076175°, End φ: -39.16720442168343°
#   Rotation θ: 0.6538788714762944°, Rotation φ: 5.832795578316613°
# Unit 63:
#   Start θ: 125.26236392040013°, Start φ: 45.00000000000004°
#   End θ: 134.10428114910292°, End φ: 54.51677550802797°
#   Rotation θ: 8.841917228702783°, Rotation φ: 9.516775508027926°
# Unit 64:
#   Start θ: 125.2664154957558°, Start φ: 44.99999999999995°
#   End θ: 126.60615973576117°, End φ: 36.951605042591524°
#   Rotation θ: 1.3397442400053734°, Rotation φ: -8.048394957408426°
# Unit 65:
#   Start θ: 125.26844120745872°, Start φ: 44.99999999999995°
#   End θ: 120.60684899564107°, End φ: 40.27594662684163°
#   Rotation θ: -4.6615922118176485°, Rotation φ: -4.72405337315832°
# Unit 66:
#   Start θ: 125.26438968275468°, Start φ: 44.99999999999995°
#   End θ: 131.64652699298378°, End φ: 52.06777388316127°
#   Rotation θ: 6.382137310229098°, Rotation φ: 7.067773883161323°
# Unit 67:
#   Start θ: 54.73358450424422°, Start φ: -44.999999999999964°
#   End θ: 61.250220345188744°, End φ: -35.23326581468578°
#   Rotation θ: 6.516635840944524°, Rotation φ: 9.766734185314185°
# Unit 68:
#   Start θ: 54.735610317245325°, Start φ: -44.999999999999964°
#   End θ: 65.3028350816039°, End φ: -38.18425755527563°
#   Rotation θ: 10.567224764358578°, Rotation φ: 6.815742444724336°
# Unit 69:
#   Start θ: 54.731558792541286°, Start φ: -44.999999999999964°
#   End θ: 62.66089236867836°, End φ: -50.94838887370989°
#   Rotation θ: 7.929333576137076°, Rotation φ: -5.9483888737099235°
# Unit 70:
#   Start θ: 54.734597455060495°, Start φ: -45.00214867230593°
#   End θ: 49.98498232147564°, End φ: -41.021695135725224°
#   Rotation θ: -4.749615133584854°, Rotation φ: 3.980453536580704°
# Unit 71:
#   Start θ: 54.73662324273847°, Start φ: -45.00214867230593°
#   End θ: 65.61635556357112°, End φ: -43.93582471560399°
#   Rotation θ: 10.879732320832652°, Rotation φ: 1.066323956701936°
# Unit 72:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230593°
#   End θ: 129.6760959136552°, End φ: 53.38139802136492°
#   Rotation θ: 4.412719156393663°, Rotation φ: 8.379249349058995°
# Unit 73:
#   Start θ: 54.73358450424422°, Start φ: 135.00000000000006°
#   End θ: 53.94867488114285°, End φ: 129.13573253883638°
#   Rotation θ: -0.7849096231013704°, Rotation φ: -5.864267461163678°
# Unit 74:
#   Start θ: 54.735610317245325°, Start φ: 135.00000000000006°
#   End θ: 57.31784268269119°, End φ: 145.14876544470272°
#   Rotation θ: 2.5822323654458685°, Rotation φ: 10.148765444702661°
# Unit 75:
#   Start θ: 125.26236384443783°, Start φ: 44.995702816544565°
#   End θ: 135.5031416180719°, End φ: 48.744095980332894°
#   Rotation θ: 10.240777773634079°, Rotation φ: 3.7483931637883288°
# Unit 76:
#   Start θ: 125.2664154957558°, Start φ: -135.00000000000006°
#   End θ: 125.70048822814242°, End φ: -139.66939029445174°
#   Rotation θ: 0.4340727323866247°, Rotation φ: -4.669390294451688°
# Unit 77:
#   Start θ: 125.26844120745872°, Start φ: -135.00000000000006°
#   End θ: 120.70660019838526°, End φ: -134.05241988201735°
#   Rotation θ: -4.561841009073461°, Rotation φ: 0.9475801179827101°
# Unit 78:
#   Start θ: 125.26438968275468°, Start φ: -135.00000000000006°
#   End θ: 124.43735068842669°, End φ: -138.8457278381337°
#   Rotation θ: -0.8270389943279923°, Rotation φ: -3.845727838133655°
# Unit 79:
#   Start θ: 54.734597455060495°, Start φ: 134.99785132769406°
#   End θ: 53.81889069617755°, End φ: 134.99263266308384°
#   Rotation θ: -0.9157067588829477°, Rotation φ: -0.005218664610225687°
# Unit 80:
#   Start θ: 54.73662324273847°, Start φ: 134.99785132769406°
#   End θ: 55.37988555857256°, End φ: 131.89151201454706°
#   Rotation θ: 0.6432623158340931°, Rotation φ: -3.1063393131470036°
# Unit 81:
#   Start θ: 125.26337675726153°, Start φ: -134.99785132769406°
#   End θ: 119.60694162507257°, End φ: -138.08244319018527°
#   Rotation θ: -5.65643513218896°, Rotation φ: -3.0845918624912088°
# Unit 82:
#   Start θ: 54.737636155562214°, Start φ: 135.00429718345544°
#   End θ: 56.53788606837022°, End φ: 139.28294101891143°
#   Rotation θ: 1.800249912808006°, Rotation φ: 4.278643835455995°
# Unit 83:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 129.89090870474323°, End φ: 48.004650979554995°
#   Rotation θ: 4.626519021988543°, Rotation φ: 3.004650979554995°
# Unit 84:
#   Start θ: 125.26641549575585°, Start φ: 45.0°
#   End θ: 125.91318280461552°, End φ: 47.00981097309831°
#   Rotation θ: 0.6467673088596655°, Rotation φ: 2.009810973098311°
# Unit 85:
#   Start θ: 54.735610317245346°, Start φ: -45.000000000000014°
#   End θ: 53.453365213100525°, End φ: -51.25201934205369°
#   Rotation θ: -1.2822451041448204°, Rotation φ: -6.2520193420536785°
# Unit 86:
#   Start θ: 125.2623638444378°, Start φ: -135.00429718345544°
#   End θ: 128.80081079206724°, End φ: -137.371031104589°
#   Rotation θ: 3.5384469476294385°, Rotation φ: -2.366733921133573°
# Unit 87:
#   Start θ: 54.73358450424416°, Start φ: -45.000000000000014°
#   End θ: 49.99627082888676°, End φ: -48.70885801625563°
#   Rotation θ: -4.737313675357406°, Rotation φ: -3.7088580162556184°
# Unit 88:
#   Start θ: 54.736623242738496°, Start φ: -45.00214867230598°
#   End θ: 67.22044410694676°, End φ: -43.524594166066606°
#   Rotation θ: 12.483820864208262°, Rotation φ: 1.4775545062393718°
# Unit 89:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230598°
#   End θ: 127.66328310890898°, End φ: 31.544246552446648°
#   Rotation θ: 2.3999063516474592°, Rotation φ: -13.45790211985933°
# Unit 90:
#   Start θ: 54.73459745506044°, Start φ: -45.00214867230598°
#   End θ: 53.44238251468511°, End φ: -50.51709416192131°
#   Rotation θ: -1.292214940375331°, Rotation φ: -5.514945489615329°
# Unit 91:
#   Start θ: 54.735610317245346°, Start φ: 135.00000000000003°
#   End θ: 48.91175275640317°, End φ: 142.5238204386386°
#   Rotation θ: -5.823857560842178°, Rotation φ: 7.52382043863858°
# Unit 92:
#   Start θ: 125.2623638444378°, Start φ: -134.99570281654456°
#   End θ: 120.67537306693923°, End φ: -138.96015284730544°
#   Rotation θ: -4.5869907774985705°, Rotation φ: -3.9644500307608723°
# Unit 93:
#   Start θ: 54.73358450424416°, Start φ: 135.00000000000003°
#   End θ: 48.362858703504564°, End φ: 134.35625428582463°
#   Rotation θ: -6.370725800739599°, Rotation φ: -0.6437457141753953°
# Unit 94:
#   Start θ: 54.73763615556222°, Start φ: 134.99570281654456°
#   End θ: 57.06737822337916°, End φ: 128.53003498168056°
#   Rotation θ: 2.3297420678169374°, Rotation φ: -6.465667834864007°
# Unit 95:
#   Start θ: 125.26438968275465°, Start φ: -135.0°
#   End θ: 102.94923844448745°, End φ: -128.63422437266783°
#   Rotation θ: -22.315151238267205°, Rotation φ: 6.3657756273321695°
# Unit 96:
#   Start θ: 125.26641549575585°, Start φ: -135.0°
#   End θ: 119.16300129564833°, End φ: -129.07892826869255°
#   Rotation θ: -6.1034142001075224°, Rotation φ: 5.92107173130745°
# Unit 97:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769404°
#   End θ: 52.72496014802158°, End φ: 143.26944622593638°
#   Rotation θ: -2.0116630947169227°, Rotation φ: 8.271594898242341°
# Unit 98:
#   Start θ: 125.26337675726151°, Start φ: -134.99785132769404°
#   End θ: 128.208747591707°, End φ: -138.57774893425028°
#   Rotation θ: 2.945370834445498°, Rotation φ: -3.5798976065562442°
# Unit 99:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769404°
#   End θ: 55.676034409518714°, End φ: 132.4091980148049°
#   Rotation θ: 0.9414369544582755°, Rotation φ: -2.588653312889136°
# Unit 100:
#   Start θ: 54.736623242738496°, Start φ: 135.00214867230596°
#   End θ: 57.7658549878221°, End φ: 136.32732194145956°
#   Rotation θ: 3.0292317450836066°, Rotation φ: 1.325173269153595°
# Unit 101:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769403°
#   End θ: 127.44420990471293°, End φ: 46.51176659479473°
#   Rotation θ: 2.180833147451409°, Rotation φ: 1.5139152671006997°
# Unit 102:
#   Start θ: 54.73459745506044°, Start φ: 135.00214867230596°
#   End θ: 53.03058684369469°, End φ: 125.4020132163521°
#   Rotation θ: -1.7040106113657458°, Rotation φ: -9.600135455953861°
# Unit 103:
#   Start θ: 54.7366232427385°, Start φ: -44.99785132769403°
#   End θ: 47.02422361734354°, End φ: -42.84825708242042°
#   Rotation θ: -7.712399625394966°, Rotation φ: 2.1495942452736116°
# Unit 104:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230596°
#   End θ: 132.13059438580822°, End φ: -109.82828743807086°
#   Rotation θ: 6.867217628546712°, Rotation φ: 25.173861234235105°
# Unit 105:
#   Start θ: 54.73459745506044°, Start φ: -44.99785132769403°
#   End θ: 36.24728514853749°, End φ: -23.698521464516837°
#   Rotation θ: -18.487312306522945°, Rotation φ: 21.299329863177192°
# Unit 106:
#   Start θ: 54.737636079599945°, Start φ: 135.0°
#   End θ: 57.38757004141202°, End φ: 141.65956290595395°
#   Rotation θ: 2.6499339618120743°, Rotation φ: 6.659562905953948°
# Unit 107:
#   Start θ: 125.26236392040008°, Start φ: 45.0°
#   End θ: 119.25007177226964°, End φ: 35.08666261033441°
#   Rotation θ: -6.012292148130442°, Rotation φ: -9.913337389665593°
# Unit 108:
#   Start θ: 54.735610317245346°, Start φ: 135.0°
#   End θ: 58.005511606449176°, End φ: 128.78974095646717°
#   Rotation θ: 3.2699012892038297°, Rotation φ: -6.2102590435328295°

# %%
df = pd.DataFrame({
    r'PS$_4$$^{3-}$ unit': list(rotation_data.keys()),
    r'$\theta$ ($^\circ$)': [data['rotation_theta'] for data in rotation_data.values()],
    r'$\phi$ ($^\circ$)': [data['rotation_phi'] for data in rotation_data.values()],
    r'Displacement of S (\AA)': [data['distance']*lattice_param for data in closest_sulfur_pairs.values()]
})

display(df)

readytosave=True
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    df.to_csv(f"{saveloc}/{cleaned_matname} displacements.csv")
# Out:
#      PS$_4$$^{3-}$ unit  $\theta$ ($^\circ$)  $\phi$ ($^\circ$)  \
# 0                     1            -7.339519           7.677885
# 1                     2            -5.231875          -0.865139
# 2                     3             0.792003         -13.105875
# 3                     4             5.628663          -8.486247
# 4                     5             3.583208           3.362335
# ..                  ...                  ...                ...
# 103                 104             6.867218          25.173861
# 104                 105           -18.487312          21.299330
# 105                 106             2.649934           6.659563
# 106                 107            -6.012292          -9.913337
# 107                 108             3.269901          -6.210259
#
#      Displacement of S (\AA)
# 0                   0.341546
# 1                   0.193131
# 2                   0.385026
# 3                   0.329023
# 4                   0.164520
# ..                       ...
# 103                 0.742803
# 104                 0.849317
# 105                 0.222924
# 106                 0.372117
# 107                 0.222486
#
# [108 rows x 4 columns]

# %%
import numpy as np

# Initialize sums for theta, phi rotations, and distance
total_theta_rotation = 0
total_phi_rotation = 0
total_distance = 0

# Initialize sums for squared differences
sum_squared_diff_theta = 0
sum_squared_diff_phi = 0
sum_squared_diff_distance = 0

# Count the number of units
num_units = len(rotation_data)

# Collect all theta, phi, and distance values
theta_values = []
phi_values = []
distance_values = []

# Sum up the rotations and collect values for all units
for unit, data in rotation_data.items():
    total_theta_rotation += data['rotation_theta']
    total_phi_rotation += data['rotation_phi']
    theta_values.append(data['rotation_theta'])
    phi_values.append(data['rotation_phi'])

for unit, data in closest_sulfur_pairs.items():
    total_distance += data['distance']
    distance_values.append(data['distance'])

# Calculate the average theta, phi rotations, and distance
average_theta_rotation = total_theta_rotation / num_units
average_phi_rotation = total_phi_rotation / num_units
average_distance = total_distance / num_units

# Calculate the squared differences from the mean for each unit
for unit, data in rotation_data.items():
    sum_squared_diff_theta += (data['rotation_theta'] - average_theta_rotation) ** 2
    sum_squared_diff_phi += (data['rotation_phi'] - average_phi_rotation) ** 2

for unit, data in closest_sulfur_pairs.items():
    sum_squared_diff_distance += (data['distance'] - average_distance) ** 2

# Calculate the variances using `num_units - 1` for the denominator
variance_theta = sum_squared_diff_theta / (num_units - 1)
variance_phi = sum_squared_diff_phi / (num_units - 1)
variance_distance = sum_squared_diff_distance / (num_units - 1)

# Calculate the standard deviations
std_dev_theta = variance_theta ** 0.5
std_dev_phi = variance_phi ** 0.5
std_dev_distance = variance_distance ** 0.5

# Convert average distance and standard deviation to angstroms
average_distance_angstrom = average_distance * lattice_param
std_dev_distance_angstrom = std_dev_distance * lattice_param

# Calculate the medians for theta, phi, and distance
median_theta_rotation = np.median(theta_values)
median_phi_rotation = np.median(phi_values)
median_distance = np.median(distance_values)
median_distance_angstrom = median_distance * lattice_param

# Print the average, median rotations, and their standard deviations
print(f"Average θ rotation: {average_theta_rotation}°, Standard Deviation: {std_dev_theta}°")
print(f"Median θ rotation: {median_theta_rotation}°")
print(f"Average φ rotation: {average_phi_rotation}°, Standard Deviation: {std_dev_phi}°")
print(f"Median φ rotation: {median_phi_rotation}°")
print(f"Average Displacement: {average_distance_angstrom} angstroms, Standard Deviation: {std_dev_distance_angstrom} angstroms")
print(f"Median Displacement: {median_distance_angstrom} angstroms")
# Out:
# Average θ rotation: 0.9624334123020287°, Standard Deviation: 7.290862397316109°
# Median θ rotation: 0.65032309016798°
# Average φ rotation: 1.5555452561465473°, Standard Deviation: 8.148494087711946°
# Median φ rotation: 1.6734597125384951°
# Average Displacement: 0.29346693836828525 angstroms, Standard Deviation: 0.19612283412845963 angstroms
# Median Displacement: 0.2350387040466878 angstroms

# %%
#generate a table for average displacements

attributes=[r'$\theta$ ($^\circ$)', r'$\phi$ ($^\circ$)', r'Displacement of S (\AA)']
averages=[average_theta_rotation, average_phi_rotation,average_distance_angstrom]
medians=[median_theta_rotation,median_phi_rotation,median_distance_angstrom]
std_devs=[std_dev_theta,std_dev_phi,std_dev_distance_angstrom]

collated={
    r'Attribute':attributes,
    r'Average':averages,
    r'Median':medians,
    r'Standard Deviation':std_devs,
}

collated=pd.DataFrame(collated)

display(collated)

readytosave=False
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    collated.to_csv(f"{saveloc}/{cleaned_matname} dispersities.csv")
# Out:
#                  Attribute   Average    Median  Standard Deviation
# 0      $\theta$ ($^\circ$)  0.962433  0.650323            7.290862
# 1        $\phi$ ($^\circ$)  1.555545  1.673460            8.148494
# 2  Displacement of S (\AA)  0.293467  0.235039            0.196123

# %%
# Initialize variables to store the maximum distance and the corresponding unit
max_distance = 0
max_unit = None
max_sulfur_pair = None

# Iterate through the closest_sulfur_pairs dictionary
for unit, data in closest_sulfur_pairs.items():
    # Extract the distance value
    distance = data['distance']
    
    # Check if this is the maximum distance encountered so far
    if distance > max_distance:
        max_distance = distance
        max_unit = unit
        max_sulfur_pair = (data['start_sulfur'], data['closest_end_sulfur'])
# Print the results
print(f"Maximum distance: {max_distance}")
print(f"Unit number: {max_unit}")
print(f"Starting sulfur: {max_sulfur_pair[0]}")
print(f"Ending sulfur: {max_sulfur_pair[1]}")
print(f"Maximum θ:{rotation_data[max_unit]['rotation_theta']}°")
print(f"Maximum φ:{rotation_data[max_unit]['rotation_phi']}°")
# Out:
# Maximum distance: 0.03456962394935759
# Unit number: 45
# Starting sulfur: (0.37667, 0.87667, 0.87667)
# Ending sulfur: 4
# Maximum θ:26.324415124964816°
# Maximum φ:19.642908497218883°

# %%
readytosave=True

fig, axs=plt.subplots(1,1, figsize=(6,6))

max_theta = rotation_data[max_unit]['rotation_theta']
max_phi = rotation_data[max_unit]['rotation_phi']

if abs(max_phi)>abs(max_theta):
    lim=abs(max_phi)*1.05
else:
    lim=abs(max_theta)*1.05
    
lim=85


for unit, data in rotation_data.items():
    if unit!=max_unit:
        axs.scatter(data['rotation_phi'],data['rotation_theta'],edgecolor=datacolor,facecolors='white',linewidths=2, marker='o')
    else:
        axs.scatter(rotation_data[max_unit]['rotation_phi'],rotation_data[max_unit]['rotation_theta'], edgecolor='#cc0000',facecolors='white',linewidths=2, marker='o')
#axs.scatter(0,0,color="orange",edgecolor='black',marker='^',s=150)

axs.text(-lim+lim*0.1,lim*.45,fr'Max displacement:' '\n' fr'{max_distance*lattice_param:.2f} \AA' '\n' fr'$\theta$: {max_theta:.2f}$^\circ$' '\n' fr'$\phi$: {max_phi:.2f}$^\circ$',bbox=dict(
        facecolor='none',     # Transparent fill color for the box
       edgecolor="#cc0000",  # Match the box edge color with the marker
        linewidth=2,        # Box edge width
       boxstyle='round,pad=0.3'  # Rounded box with padding
  ))
    
axs.set_xlim([-lim,lim])
axs.set_ylim([-lim,lim])

axs.xaxis.set_major_locator(ticker.MaxNLocator(8))
axs.yaxis.set_major_locator(ticker.MaxNLocator(8))
axs.xaxis.set_minor_locator(AutoMinorLocator(2))
axs.yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(which='major', direction='in', length=6)
plt.tick_params(which='minor', direction='in', length=4)

axs.set_xlabel(r'$\phi$ ($^{\circ}$)')
axs.set_ylabel(r'$\theta$ ($^{\circ}$)')
axs.set_title(material)

plt.tight_layout()

if readytosave==True:
    png=''.join((saveloc,'/',cleaned_matname,'rotation summary','.png'))
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    plt.savefig(png,dpi=800,format='png')


plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

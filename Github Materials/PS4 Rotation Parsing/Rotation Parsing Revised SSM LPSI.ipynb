# %%
#import necessary packages
import pandas as pd
from datetime import datetime, timedelta, timezone
import os
from PyEIS import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import csv
import glob
import statistics
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress
import math
from colour import Color
import re
import matplotlib.ticker as ticker
from matplotlib.ticker import FormatStrFormatter
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.ticker import AutoMinorLocator

from matplotlib.pyplot import rc

allSized=20
rc('text',usetex=True)
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']},size=allSized)
rc('text.latex', preamble=r'\usepackage{sfmath}')
plt.rc('font',   size=     allSized,**{'family':"sans-serif"})     # controls default text sizes
plt.rc('axes',   titlesize=allSized)     # fontsize of the axes title
plt.rc('axes',   labelsize=allSized)    # fontsize of the x and y labels
plt.rc('xtick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('ytick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('legend', fontsize= allSized)    # legend fontsize
plt.rc('figure', titlesize=allSized)  # fontsize of the figure title

# %%
# Function to calculate Euclidean distance between two points
def calculate_distance(coord1, coord2):
    return math.sqrt((coord1[0] - coord2[0])**2 + (coord1[1] - coord2[1])**2 + (coord1[2] - coord2[2])**2)


def cartesian_to_spherical(x, y, z):
    r = np.sqrt(x**2 + y**2 + z**2)
    theta = np.arccos(z / r) if r != 0 else 0  # θ: angle from z-axis
    phi = np.arctan2(y, x)  # φ: angle from x-axis in the xy-plane
    return r, np.degrees(theta), np.degrees(phi)

# %%
start_file="C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Python Processed Str/Consolidated strs/3by3/Li6PS5Br_3by3_P1_dualLi_limited rotation_beqpdfgui_site disorder_Lioccref.txt"

end_file="C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/PDF SA_ Joint Refinement working copy/SSM LPSI/Joint Refinements/7_15_2024_I_SSM_3by3_Joint_Lioccref.inp"

material=r'SSM Li$_6$PS$_5$I'

datacolor='#f6f'

lattice_param=30.429854

#filter non-alphanumeric and space characters from the material name so that it's easier to deal with from a file management perspective
cleaned_matname = filter(lambda x: x.isalnum() or x.isspace(), material)

# filter returns a generator, so we need to re-join the string
cleaned_matname = "".join(cleaned_matname)

print(cleaned_matname)

saveloc='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/Paper Plotting/PS4 Rotations and cifs/rotation plots'
# Out:
# SSM Li6PS5I

# %%
start_coordinates={}

# Regular expression pattern to match the lines with start_coordinates
pattern = re.compile(r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.-]+)\s+y\s+([\d.-]+)\s+z\s+([\d.-]+)")

# Open the file and process each line
with open(start_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)

# Example: Accessing the start_coordinates for a specific thiophosphate unit
example_unit = 1
print(f"start_coordinates for P{example_unit}: {start_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"start_coordinates for S{example_unit}{i}: {start_coordinates[example_unit]['S'][i]}")
# Out:
# start_coordinates for P1: (0.25, 0.25, 0.083333)
# start_coordinates for S11: (0.29, 0.21, 0.12333)
# start_coordinates for S12: (0.21, 0.29, 0.12333)
# start_coordinates for S13: (0.29, 0.29, 0.04333)
# start_coordinates for S14: (0.21, 0.21, 0.04333)

# %%
# Initialize the dictionary to store the end_coordinates
end_coordinates = {}

# Regular expression pattern to match the lines with end_coordinates, accounting for '_0.00000' or any number
pattern = re.compile(
    r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+\s+y\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+\s+z\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+"
)
# Open the file and process each line
with open(end_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)


# Example: Accessing the end_coordinates for a specific thiophosphate unit
example_unit = 50
print(f"end_coordinates for P{example_unit}: {end_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"end_coordinates for S{example_unit}{i}: {end_coordinates[example_unit]['S'][i]}")
# Out:
# end_coordinates for P50: (0.75, 0.58333, 0.58333)
# end_coordinates for S501: (0.78765, 0.62454, 0.54602)
# end_coordinates for S502: (0.78986, 0.54306, 0.61935)
# end_coordinates for S503: (0.71148, 0.61954, 0.62473)
# end_coordinates for S504: (0.71101, 0.54619, 0.54324)

# %%
# Dictionary to store closest sulfur pairs
closest_sulfur_pairs = {}

# Find the closest sulfur atom for each S1 from start to end units
for unit_number, start_sulfurs in start_coordinates.items():
    if 'S' in start_sulfurs:
        start_sulfur1_coords = start_sulfurs['S'].get(1)
        if start_sulfur1_coords:
            min_distance = float('inf')
            closest_sulfur = None
            for sulfur_number, end_sulfur_coords in end_coordinates[unit_number]['S'].items():
                distance = calculate_distance(start_sulfur1_coords, end_sulfur_coords)
                if distance < min_distance:
                    min_distance = distance
                    closest_sulfur = sulfur_number
            closest_sulfur_pairs[unit_number] = {
                'start_sulfur': start_sulfur1_coords,
                'closest_end_sulfur': closest_sulfur,
                'end_sulfur_coords': end_coordinates[unit_number]['S'][closest_sulfur],
                'distance': min_distance
            }

# Example: Print out the closest sulfur atom pairs
for unit, data in closest_sulfur_pairs.items():
    print(f"Unit {unit}:")
    print(f"  Start S{unit}1 Coordinates: {data['start_sulfur']}")
    print(f"  Closest End S{unit}{data['closest_end_sulfur']} Coordinates: {data['end_sulfur_coords']}")
    print(f"  Distance: {data['distance']:.5f}")
# Out:
# Unit 1:
#   Start S11 Coordinates: (0.29, 0.21, 0.12333)
#   Closest End S13 Coordinates: (0.28641, 0.20948, 0.12258)
#   Distance: 0.00370
# Unit 2:
#   Start S21 Coordinates: (0.29, 0.29, 0.37667)
#   Closest End S21 Coordinates: (0.2906, 0.28934, 0.38044)
#   Distance: 0.00387
# Unit 3:
#   Start S31 Coordinates: (0.29, 0.29, 0.71)
#   Closest End S33 Coordinates: (0.28757, 0.2919, 0.71339)
#   Distance: 0.00458
# Unit 4:
#   Start S41 Coordinates: (0.21, 0.62333, 0.12333)
#   Closest End S42 Coordinates: (0.21171, 0.62014, 0.12441)
#   Distance: 0.00378
# Unit 5:
#   Start S51 Coordinates: (0.29, 0.62333, 0.37667)
#   Closest End S51 Coordinates: (0.28587, 0.62644, 0.37975)
#   Distance: 0.00602
# Unit 6:
#   Start S61 Coordinates: (0.29, 0.62333, 0.71)
#   Closest End S64 Coordinates: (0.27129, 0.64053, 0.72202)
#   Distance: 0.02811
# Unit 7:
#   Start S71 Coordinates: (0.29, 0.87667, 0.12333)
#   Closest End S74 Coordinates: (0.29122, 0.88463, 0.12555)
#   Distance: 0.00835
# Unit 8:
#   Start S81 Coordinates: (0.21, 0.87667, 0.37667)
#   Closest End S83 Coordinates: (0.21184, 0.87955, 0.37575)
#   Distance: 0.00354
# Unit 9:
#   Start S91 Coordinates: (0.29, 0.87667, 0.79)
#   Closest End S92 Coordinates: (0.28672, 0.88003, 0.79263)
#   Distance: 0.00538
# Unit 10:
#   Start S101 Coordinates: (0.62333, 0.21, 0.12333)
#   Closest End S104 Coordinates: (0.62414, 0.21222, 0.12096)
#   Distance: 0.00335
# Unit 11:
#   Start S111 Coordinates: (0.62333, 0.29, 0.37667)
#   Closest End S112 Coordinates: (0.62797, 0.28441, 0.38018)
#   Distance: 0.00807
# Unit 12:
#   Start S121 Coordinates: (0.62333, 0.29, 0.71)
#   Closest End S124 Coordinates: (0.62052, 0.28668, 0.70782)
#   Distance: 0.00487
# Unit 13:
#   Start S131 Coordinates: (0.54333, 0.62333, 0.12333)
#   Closest End S132 Coordinates: (0.54617, 0.62205, 0.12368)
#   Distance: 0.00313
# Unit 14:
#   Start S141 Coordinates: (0.62333, 0.62333, 0.37667)
#   Closest End S144 Coordinates: (0.62616, 0.62217, 0.38253)
#   Distance: 0.00661
# Unit 15:
#   Start S151 Coordinates: (0.62333, 0.62333, 0.71)
#   Closest End S154 Coordinates: (0.62114, 0.62697, 0.71574)
#   Distance: 0.00714
# Unit 16:
#   Start S161 Coordinates: (0.62333, 0.87667, 0.12333)
#   Closest End S161 Coordinates: (0.62378, 0.87677, 0.11911)
#   Distance: 0.00425
# Unit 17:
#   Start S171 Coordinates: (0.62333, 0.95667, 0.37667)
#   Closest End S171 Coordinates: (0.62213, 0.97144, 0.41486)
#   Distance: 0.04096
# Unit 18:
#   Start S181 Coordinates: (0.62333, 0.87667, 0.79)
#   Closest End S181 Coordinates: (0.61955, 0.87649, 0.78978)
#   Distance: 0.00379
# Unit 19:
#   Start S191 Coordinates: (0.87667, 0.29, 0.12333)
#   Closest End S194 Coordinates: (0.87612, 0.28781, 0.12121)
#   Distance: 0.00310
# Unit 20:
#   Start S201 Coordinates: (0.87667, 0.21, 0.37667)
#   Closest End S202 Coordinates: (0.87785, 0.21244, 0.37679)
#   Distance: 0.00271
# Unit 21:
#   Start S211 Coordinates: (0.87667, 0.29, 0.79)
#   Closest End S213 Coordinates: (0.87836, 0.28876, 0.78922)
#   Distance: 0.00224
# Unit 22:
#   Start S221 Coordinates: (0.87667, 0.62333, 0.12333)
#   Closest End S224 Coordinates: (0.87576, 0.62125, 0.12071)
#   Distance: 0.00347
# Unit 23:
#   Start S231 Coordinates: (0.87667, 0.54333, 0.37667)
#   Closest End S231 Coordinates: (0.87662, 0.54585, 0.37795)
#   Distance: 0.00283
# Unit 24:
#   Start S241 Coordinates: (0.87667, 0.62333, 0.79)
#   Closest End S242 Coordinates: (0.8781, 0.61263, 0.7965)
#   Distance: 0.01260
# Unit 25:
#   Start S251 Coordinates: (0.95667, 0.87667, 0.12333)
#   Closest End S251 Coordinates: (0.9217, 0.85645, 0.1126)
#   Distance: 0.04180
# Unit 26:
#   Start S261 Coordinates: (0.87667, 0.87667, 0.37667)
#   Closest End S263 Coordinates: (0.87565, 0.88424, 0.37455)
#   Distance: 0.00793
# Unit 27:
#   Start S271 Coordinates: (0.87667, 0.87667, 0.71)
#   Closest End S273 Coordinates: (0.87608, 0.88167, 0.70956)
#   Distance: 0.00505
# Unit 28:
#   Start S281 Coordinates: (0.12333, 0.21, 0.29)
#   Closest End S282 Coordinates: (0.12203, 0.21284, 0.29037)
#   Distance: 0.00315
# Unit 29:
#   Start S291 Coordinates: (0.12333, 0.21, 0.62333)
#   Closest End S292 Coordinates: (0.12334, 0.21294, 0.6225)
#   Distance: 0.00305
# Unit 30:
#   Start S301 Coordinates: (0.12333, 0.29, 0.87667)
#   Closest End S304 Coordinates: (0.12418, 0.29167, 0.88346)
#   Distance: 0.00704
# Unit 31:
#   Start S311 Coordinates: (0.12333, 0.62333, 0.21)
#   Closest End S313 Coordinates: (0.11919, 0.62698, 0.21371)
#   Distance: 0.00665
# Unit 32:
#   Start S321 Coordinates: (0.12333, 0.62333, 0.54333)
#   Closest End S323 Coordinates: (0.11296, 0.63007, 0.54531)
#   Distance: 0.01253
# Unit 33:
#   Start S331 Coordinates: (0.12333, 0.62333, 0.87667)
#   Closest End S333 Coordinates: (0.12475, 0.62807, 0.88854)
#   Distance: 0.01286
# Unit 34:
#   Start S341 Coordinates: (0.12333, 0.87667, 0.29)
#   Closest End S341 Coordinates: (0.12323, 0.87935, 0.28903)
#   Distance: 0.00285
# Unit 35:
#   Start S351 Coordinates: (0.12333, 0.87667, 0.62333)
#   Closest End S351 Coordinates: (0.12103, 0.87855, 0.62375)
#   Distance: 0.00300
# Unit 36:
#   Start S361 Coordinates: (0.12333, 0.87667, 0.95667)
#   Closest End S362 Coordinates: (0.1187, 0.87873, 0.9593)
#   Distance: 0.00571
# Unit 37:
#   Start S371 Coordinates: (0.37667, 0.29, 0.29)
#   Closest End S371 Coordinates: (0.37401, 0.29046, 0.28242)
#   Distance: 0.00805
# Unit 38:
#   Start S381 Coordinates: (0.37667, 0.29, 0.62333)
#   Closest End S384 Coordinates: (0.37591, 0.28825, 0.62054)
#   Distance: 0.00338
# Unit 39:
#   Start S391 Coordinates: (0.37667, 0.21, 0.87667)
#   Closest End S391 Coordinates: (0.3838, 0.21672, 0.8685)
#   Distance: 0.01276
# Unit 40:
#   Start S401 Coordinates: (0.37667, 0.62333, 0.29)
#   Closest End S402 Coordinates: (0.37723, 0.62233, 0.28784)
#   Distance: 0.00245
# Unit 41:
#   Start S411 Coordinates: (0.37667, 0.62333, 0.62333)
#   Closest End S412 Coordinates: (0.377, 0.61824, 0.62476)
#   Distance: 0.00530
# Unit 42:
#   Start S421 Coordinates: (0.37667, 0.62333, 0.95667)
#   Closest End S424 Coordinates: (0.38222, 0.60882, 0.96835)
#   Distance: 0.01944
# Unit 43:
#   Start S431 Coordinates: (0.37667, 0.87667, 0.21)
#   Closest End S434 Coordinates: (0.35471, 0.89168, 0.2567)
#   Distance: 0.05374
# Unit 44:
#   Start S441 Coordinates: (0.37667, 0.87667, 0.54333)
#   Closest End S441 Coordinates: (0.39995, 0.91093, 0.51856)
#   Distance: 0.04826
# Unit 45:
#   Start S451 Coordinates: (0.37667, 0.87667, 0.87667)
#   Closest End S451 Coordinates: (0.38059, 0.87825, 0.87506)
#   Distance: 0.00452
# Unit 46:
#   Start S461 Coordinates: (0.71, 0.29, 0.29)
#   Closest End S462 Coordinates: (0.70854, 0.28325, 0.29103)
#   Distance: 0.00698
# Unit 47:
#   Start S471 Coordinates: (0.71, 0.29, 0.62333)
#   Closest End S471 Coordinates: (0.69689, 0.26515, 0.62152)
#   Distance: 0.02815
# Unit 48:
#   Start S481 Coordinates: (0.79, 0.29, 0.87667)
#   Closest End S483 Coordinates: (0.78619, 0.2972, 0.88551)
#   Distance: 0.01202
# Unit 49:
#   Start S491 Coordinates: (0.71, 0.62333, 0.29)
#   Closest End S494 Coordinates: (0.7063, 0.6183, 0.28709)
#   Distance: 0.00689
# Unit 50:
#   Start S501 Coordinates: (0.71, 0.62333, 0.62333)
#   Closest End S503 Coordinates: (0.71148, 0.61954, 0.62473)
#   Distance: 0.00430
# Unit 51:
#   Start S511 Coordinates: (0.79, 0.62333, 0.87667)
#   Closest End S514 Coordinates: (0.78894, 0.62394, 0.88002)
#   Distance: 0.00357
# Unit 52:
#   Start S521 Coordinates: (0.79, 0.87667, 0.29)
#   Closest End S522 Coordinates: (0.79045, 0.88022, 0.28929)
#   Distance: 0.00365
# Unit 53:
#   Start S531 Coordinates: (0.79, 0.87667, 0.62333)
#   Closest End S534 Coordinates: (0.78261, 0.87795, 0.62744)
#   Distance: 0.00855
# Unit 54:
#   Start S541 Coordinates: (0.71, 0.87667, 0.87667)
#   Closest End S541 Coordinates: (0.71436, 0.87642, 0.87645)
#   Distance: 0.00437
# Unit 55:
#   Start S551 Coordinates: (0.21, 0.12333, 0.29)
#   Closest End S552 Coordinates: (0.21608, 0.10741, 0.3027)
#   Distance: 0.02125
# Unit 56:
#   Start S561 Coordinates: (0.21, 0.12333, 0.62333)
#   Closest End S563 Coordinates: (0.21909, 0.11993, 0.63038)
#   Distance: 0.01200
# Unit 57:
#   Start S571 Coordinates: (0.29, 0.12333, 0.87667)
#   Closest End S571 Coordinates: (0.28851, 0.12202, 0.87758)
#   Distance: 0.00218
# Unit 58:
#   Start S581 Coordinates: (0.29, 0.37667, 0.29)
#   Closest End S582 Coordinates: (0.29294, 0.38126, 0.28756)
#   Distance: 0.00597
# Unit 59:
#   Start S591 Coordinates: (0.29, 0.37667, 0.62333)
#   Closest End S592 Coordinates: (0.28589, 0.37532, 0.62219)
#   Distance: 0.00447
# Unit 60:
#   Start S601 Coordinates: (0.21, 0.37667, 0.87667)
#   Closest End S603 Coordinates: (0.21521, 0.37723, 0.87493)
#   Distance: 0.00552
# Unit 61:
#   Start S611 Coordinates: (0.29, 0.71, 0.29)
#   Closest End S612 Coordinates: (0.29228, 0.714, 0.28773)
#   Distance: 0.00513
# Unit 62:
#   Start S621 Coordinates: (0.29, 0.71, 0.62333)
#   Closest End S622 Coordinates: (0.29631, 0.71874, 0.62056)
#   Distance: 0.01113
# Unit 63:
#   Start S631 Coordinates: (0.29, 0.79, 0.87667)
#   Closest End S634 Coordinates: (0.28124, 0.79029, 0.87298)
#   Distance: 0.00951
# Unit 64:
#   Start S641 Coordinates: (0.62333, 0.12333, 0.21)
#   Closest End S643 Coordinates: (0.61738, 0.12627, 0.21121)
#   Distance: 0.00675
# Unit 65:
#   Start S651 Coordinates: (0.62333, 0.12333, 0.54333)
#   Closest End S651 Coordinates: (0.61727, 0.12367, 0.54175)
#   Distance: 0.00627
# Unit 66:
#   Start S661 Coordinates: (0.62333, 0.12333, 0.87667)
#   Closest End S664 Coordinates: (0.61548, 0.12501, 0.87498)
#   Distance: 0.00820
# Unit 67:
#   Start S671 Coordinates: (0.62333, 0.37667, 0.29)
#   Closest End S672 Coordinates: (0.62597, 0.38317, 0.28959)
#   Distance: 0.00703
# Unit 68:
#   Start S681 Coordinates: (0.62333, 0.37667, 0.62333)
#   Closest End S684 Coordinates: (0.63682, 0.39175, 0.61536)
#   Distance: 0.02175
# Unit 69:
#   Start S691 Coordinates: (0.62333, 0.37667, 0.95667)
#   Closest End S692 Coordinates: (0.62392, 0.37965, 0.95526)
#   Distance: 0.00335
# Unit 70:
#   Start S701 Coordinates: (0.62333, 0.71, 0.29)
#   Closest End S702 Coordinates: (0.62146, 0.70902, 0.28708)
#   Distance: 0.00360
# Unit 71:
#   Start S711 Coordinates: (0.62333, 0.71, 0.62333)
#   Closest End S714 Coordinates: (0.62305, 0.71169, 0.62158)
#   Distance: 0.00245
# Unit 72:
#   Start S721 Coordinates: (0.62333, 0.79, 0.87667)
#   Closest End S722 Coordinates: (0.61526, 0.79249, 0.87564)
#   Distance: 0.00851
# Unit 73:
#   Start S731 Coordinates: (0.87667, 0.12333, 0.29)
#   Closest End S733 Coordinates: (0.87928, 0.11934, 0.29259)
#   Distance: 0.00543
# Unit 74:
#   Start S741 Coordinates: (0.87667, 0.12333, 0.62333)
#   Closest End S743 Coordinates: (0.88903, 0.13413, 0.61744)
#   Distance: 0.01744
# Unit 75:
#   Start S751 Coordinates: (0.95667, 0.12333, 0.87667)
#   Closest End S754 Coordinates: (0.95624, 0.12006, 0.87676)
#   Distance: 0.00330
# Unit 76:
#   Start S761 Coordinates: (0.87667, 0.37667, 0.21)
#   Closest End S763 Coordinates: (0.88075, 0.37318, 0.21358)
#   Distance: 0.00645
# Unit 77:
#   Start S771 Coordinates: (0.87667, 0.37667, 0.54333)
#   Closest End S773 Coordinates: (0.87466, 0.37478, 0.55189)
#   Distance: 0.00899
# Unit 78:
#   Start S781 Coordinates: (0.87667, 0.37667, 0.87667)
#   Closest End S783 Coordinates: (0.88208, 0.37997, 0.87234)
#   Distance: 0.00768
# Unit 79:
#   Start S791 Coordinates: (0.87667, 0.79, 0.29)
#   Closest End S792 Coordinates: (0.88095, 0.79125, 0.28913)
#   Distance: 0.00454
# Unit 80:
#   Start S801 Coordinates: (0.87667, 0.79, 0.62333)
#   Closest End S802 Coordinates: (0.88177, 0.79044, 0.62402)
#   Distance: 0.00517
# Unit 81:
#   Start S811 Coordinates: (0.87667, 0.71, 0.87667)
#   Closest End S814 Coordinates: (0.87653, 0.70903, 0.88176)
#   Distance: 0.00518
# Unit 82:
#   Start S821 Coordinates: (0.04333, 0.12333, 0.12333)
#   Closest End S824 Coordinates: (0.04811, 0.12904, 0.11766)
#   Distance: 0.00936
# Unit 83:
#   Start S831 Coordinates: (0.12333, 0.12333, 0.37667)
#   Closest End S833 Coordinates: (0.12293, 0.11971, 0.37645)
#   Distance: 0.00365
# Unit 84:
#   Start S841 Coordinates: (0.12333, 0.12333, 0.71)
#   Closest End S843 Coordinates: (0.12571, 0.11825, 0.71137)
#   Distance: 0.00577
# Unit 85:
#   Start S851 Coordinates: (0.12333, 0.37667, 0.12333)
#   Closest End S854 Coordinates: (0.12049, 0.37925, 0.12489)
#   Distance: 0.00414
# Unit 86:
#   Start S861 Coordinates: (0.04333, 0.37667, 0.37667)
#   Closest End S862 Coordinates: (0.04562, 0.37149, 0.38435)
#   Distance: 0.00954
# Unit 87:
#   Start S871 Coordinates: (0.12333, 0.37667, 0.79)
#   Closest End S873 Coordinates: (0.12409, 0.38133, 0.78998)
#   Distance: 0.00472
# Unit 88:
#   Start S881 Coordinates: (0.12333, 0.71, 0.12333)
#   Closest End S881 Coordinates: (0.12742, 0.72913, 0.12947)
#   Distance: 0.02050
# Unit 89:
#   Start S891 Coordinates: (0.12333, 0.79, 0.37667)
#   Closest End S891 Coordinates: (0.12285, 0.78707, 0.37702)
#   Distance: 0.00299
# Unit 90:
#   Start S901 Coordinates: (0.12333, 0.71, 0.79)
#   Closest End S902 Coordinates: (0.12521, 0.71443, 0.78859)
#   Distance: 0.00501
# Unit 91:
#   Start S911 Coordinates: (0.37667, 0.12333, 0.12333)
#   Closest End S914 Coordinates: (0.38386, 0.12821, 0.12098)
#   Distance: 0.00900
# Unit 92:
#   Start S921 Coordinates: (0.37667, 0.04333, 0.37667)
#   Closest End S923 Coordinates: (0.37585, 0.048, 0.37675)
#   Distance: 0.00474
# Unit 93:
#   Start S931 Coordinates: (0.37667, 0.12333, 0.79)
#   Closest End S931 Coordinates: (0.38024, 0.12288, 0.79021)
#   Distance: 0.00360
# Unit 94:
#   Start S941 Coordinates: (0.37667, 0.45667, 0.12333)
#   Closest End S942 Coordinates: (0.38631, 0.46309, 0.12117)
#   Distance: 0.01178
# Unit 95:
#   Start S951 Coordinates: (0.37667, 0.37667, 0.37667)
#   Closest End S952 Coordinates: (0.37928, 0.37605, 0.37845)
#   Distance: 0.00322
# Unit 96:
#   Start S961 Coordinates: (0.37667, 0.37667, 0.71)
#   Closest End S964 Coordinates: (0.37048, 0.38316, 0.71461)
#   Distance: 0.01008
# Unit 97:
#   Start S971 Coordinates: (0.37667, 0.79, 0.12333)
#   Closest End S972 Coordinates: (0.37798, 0.79087, 0.11995)
#   Distance: 0.00373
# Unit 98:
#   Start S981 Coordinates: (0.37667, 0.71, 0.37667)
#   Closest End S984 Coordinates: (0.37949, 0.70954, 0.37808)
#   Distance: 0.00319
# Unit 99:
#   Start S991 Coordinates: (0.37667, 0.79, 0.79)
#   Closest End S991 Coordinates: (0.37488, 0.78948, 0.78468)
#   Distance: 0.00564
# Unit 100:
#   Start S1001 Coordinates: (0.71, 0.12333, 0.12333)
#   Closest End S1002 Coordinates: (0.71104, 0.12036, 0.12357)
#   Distance: 0.00316
# Unit 101:
#   Start S1011 Coordinates: (0.79, 0.12333, 0.37667)
#   Closest End S1014 Coordinates: (0.78476, 0.12392, 0.37602)
#   Distance: 0.00531
# Unit 102:
#   Start S1021 Coordinates: (0.71, 0.12333, 0.79)
#   Closest End S1022 Coordinates: (0.71321, 0.12467, 0.78803)
#   Distance: 0.00400
# Unit 103:
#   Start S1031 Coordinates: (0.79, 0.37667, 0.12333)
#   Closest End S1034 Coordinates: (0.78057, 0.39108, 0.13735)
#   Distance: 0.02221
# Unit 104:
#   Start S1041 Coordinates: (0.71, 0.37667, 0.37667)
#   Closest End S1043 Coordinates: (0.71316, 0.3669, 0.3907)
#   Distance: 0.01739
# Unit 105:
#   Start S1051 Coordinates: (0.79, 0.37667, 0.79)
#   Closest End S1051 Coordinates: (0.79206, 0.3816, 0.78884)
#   Distance: 0.00547
# Unit 106:
#   Start S1061 Coordinates: (0.71, 0.79, 0.12333)
#   Closest End S1062 Coordinates: (0.71264, 0.79291, 0.11898)
#   Distance: 0.00586
# Unit 107:
#   Start S1071 Coordinates: (0.79, 0.79, 0.37667)
#   Closest End S1071 Coordinates: (0.79299, 0.78498, 0.37878)
#   Distance: 0.00621
# Unit 108:
#   Start S1081 Coordinates: (0.71, 0.79, 0.79)
#   Closest End S1081 Coordinates: (0.71198, 0.78782, 0.7904)
#   Distance: 0.00297

# %%
# Dictionary to store rotation information
rotation_data = {}

# Calculate theta and phi for each thiophosphate unit
for unit, data in closest_sulfur_pairs.items():
    # Vector from P to starting S1
    start_p_coords = start_coordinates[unit]['P']
    start_s_coords = data['start_sulfur']
    start_vector = np.array([start_s_coords[0] - start_p_coords[0], 
                             start_s_coords[1] - start_p_coords[1], 
                             start_s_coords[2] - start_p_coords[2]])
    
    # Vector from P to ending Sx
    end_p_coords=end_coordinates[unit]['P']
    end_s_coords = data['end_sulfur_coords']
    end_vector = np.array([end_s_coords[0] - end_p_coords[0], 
                           end_s_coords[1] - end_p_coords[1], 
                           end_s_coords[2] - end_p_coords[2]])
    
    # Convert vectors to spherical coordinates
    start_r, start_theta, start_phi = cartesian_to_spherical(*start_vector)
    end_r, end_theta, end_phi = cartesian_to_spherical(*end_vector)
    
    # Store the rotation data
    rotation_data[unit] = {
        'start_theta': start_theta, 'start_phi': start_phi,  # Reference (0, 0)
        'end_theta': end_theta, 
        'end_phi': end_phi,
        'rotation_theta': end_theta-start_theta,  # Since start_theta is 0
        'rotation_phi': end_phi-start_phi  # Since start_phi is 0
    }

# Example: Print the rotational data for each thiophosphate unit
for unit, data in rotation_data.items():
    print(f"Unit {unit}:")
    print(f"  Start θ: {data['start_theta']}°, Start φ: {data['start_phi']}°")
    print(f"  End θ: {data['end_theta']}°, End φ: {data['end_phi']}°")
    print(f"  Rotation θ: {data['rotation_theta']}°, Rotation φ: {data['rotation_phi']}°")
# Out:
# Unit 1:
#   Start θ: 54.737636079599916°, Start φ: -45.00000000000002°
#   End θ: 54.22687266379328°, End φ: -48.05813065960915°
#   Rotation θ: -0.5107634158066361°, Rotation φ: -3.0581306596091267°
# Unit 2:
#   Start θ: 125.2623639204001°, Start φ: 45.0°
#   End θ: 122.65431049523218°, End φ: 44.09698893318948°
#   Rotation θ: -2.608053425167924°, Rotation φ: -0.9030110668105209°
# Unit 3:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 123.04523938145711°, End φ: 48.11873232197922°
#   Rotation θ: -2.2191503012975744°, Rotation φ: 3.1187323219792233°
# Unit 4:
#   Start θ: 54.73662324273851°, Start φ: 135.00214867230594°
#   End θ: 52.28054739575791°, End φ: 136.1289850686507°
#   Rotation θ: -2.456075846980603°, Rotation φ: 1.1268363963447712°
# Unit 5:
#   Start θ: 125.26337675726151°, Start φ: 44.997851327694114°
#   End θ: 123.35803732759742°, End φ: 50.23759596707557°
#   Rotation θ: -1.905339429664096°, Rotation φ: 5.239744639381456°
# Unit 6:
#   Start θ: 125.26540254493958°, Start φ: 44.997851327694114°
#   End θ: 114.62841521890434°, End φ: 69.58459268957239°
#   Rotation θ: -10.63698732603524°, Rotation φ: 24.586741361878275°
# Unit 7:
#   Start θ: 54.7366232427385°, Start φ: -44.997851327694114°
#   End θ: 51.037806560419156°, End φ: -37.85765804548381°
#   Rotation θ: -3.6988166823193467°, Rotation φ: 7.140193282210305°
# Unit 8:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230594°
#   End θ: 127.54774063213354°, End φ: -135.7914960179198°
#   Rotation θ: 2.284363874872028°, Rotation φ: -0.7893473456138622°
# Unit 9:
#   Start θ: 54.73459745506044°, Start φ: -44.997851327694114°
#   End θ: 50.58633596523711°, End φ: -44.93751825866882°
#   Rotation θ: -4.1482614898233265°, Rotation φ: 0.06033306902529745°
# Unit 10:
#   Start θ: 54.73662324273851°, Start φ: -45.00214867230591°
#   End θ: 55.91604066381959°, End φ: -42.79208207784081°
#   Rotation θ: 1.1794174210810766°, Rotation φ: 2.210066594465097°
# Unit 11:
#   Start θ: 125.26337675726151°, Start φ: 45.00214867230589°
#   End θ: 122.91948648761893°, End φ: 37.626233638669774°
#   Rotation θ: -2.3438902696425856°, Rotation φ: -7.375915033636119°
# Unit 12:
#   Start θ: 125.26540254493958°, Start φ: 45.00214867230589°
#   End θ: 128.92091294259438°, End φ: 44.60443504413823°
#   Rotation θ: 3.6555103976548082°, Rotation φ: -0.397713628167665°
# Unit 13:
#   Start θ: 54.737636155562235°, Start φ: 135.0042971834554°
#   End θ: 53.061801583568545°, End φ: 133.82223475903422°
#   Rotation θ: -1.6758345719936898°, Rotation φ: -1.18206242442119°
# Unit 14:
#   Start θ: 125.26438968275463°, Start φ: 45.0°
#   End θ: 120.56060207446048°, End φ: 42.203030046552094°
#   Rotation θ: -4.703787608294149°, Rotation φ: -2.796969953447906°
# Unit 15:
#   Start θ: 125.2664154957558°, Start φ: 45.0°
#   End θ: 120.6822328768047°, End φ: 49.09411518979383°
#   Rotation θ: -4.58418261895109°, Rotation φ: 4.094115189793833°
# Unit 16:
#   Start θ: 54.735610317245396°, Start φ: -45.0°
#   End θ: 57.79985682210764°, End φ: -44.60781348384382°
#   Rotation θ: 3.064246504862247°, Rotation φ: 0.3921865161561797°
# Unit 17:
#   Start θ: 125.26236384443777°, Start φ: 45.00429718345539°
#   End θ: 91.5446826708243°, End φ: 54.685593915823596°
#   Rotation θ: -33.71768117361347°, Rotation φ: 9.681296732368203°
# Unit 18:
#   Start θ: 54.733584504244206°, Start φ: -45.0°
#   End θ: 53.67048417765079°, End φ: -47.96712597860931°
#   Rotation θ: -1.063100326593414°, Rotation φ: -2.9671259786093103°
# Unit 19:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769412°
#   End θ: 55.65804483172494°, End φ: 137.00263527080585°
#   Rotation θ: 0.9214215889864406°, Rotation φ: 2.0047839431117325°
# Unit 20:
#   Start θ: 125.26337675726151°, Start φ: -134.9978513276941°
#   End θ: 126.43835992294325°, End φ: -135.94509209971866°
#   Rotation θ: 1.1749831656817378°, Rotation φ: -0.9472407720245712°
# Unit 21:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769412°
#   End θ: 54.25879055976321°, End φ: 134.66546246546656°
#   Rotation θ: -0.4758068952972252°, Rotation φ: -0.33238886222756037°
# Unit 22:
#   Start θ: 54.735610317245396°, Start φ: 135.0°
#   End θ: 56.173291068936436°, End φ: 137.17217172378875°
#   Rotation θ: 1.4376807516910404°, Rotation φ: 2.1721717237887503°
# Unit 23:
#   Start θ: 125.26236384443777°, Start φ: -134.99570281654462°
#   End θ: 125.21819979773856°, End φ: -136.89857158595493°
#   Rotation θ: -0.04416404669920837°, Rotation φ: -1.9028687694103041°
# Unit 24:
#   Start θ: 54.733584504244206°, Start φ: 135.0°
#   End θ: 46.16879462951089°, End φ: 142.77759746386576°
#   Rotation θ: -8.564789874733314°, Rotation φ: 7.77759746386576°
# Unit 25:
#   Start θ: 54.737636155562235°, Start φ: -44.995702816544615°
#   End θ: 64.15610284756862°, End φ: -85.22533489339457°
#   Rotation θ: 9.418466692006383°, Rotation φ: -40.22963207684996°
# Unit 26:
#   Start θ: 125.26438968275463°, Start φ: -135.0°
#   End θ: 128.85119502993908°, End φ: -141.67045764915943°
#   Rotation θ: 3.586805347184452°, Rotation φ: -6.670457649159431°
# Unit 27:
#   Start θ: 125.2664154957558°, Start φ: -135.0°
#   End θ: 127.03571087291513°, End φ: -139.2294146933104°
#   Rotation θ: 1.769295377159338°, Rotation φ: -4.229414693310389°
# Unit 28:
#   Start θ: 54.73459745506047°, Start φ: -45.002148672305964°
#   End θ: 53.04076167427087°, End φ: -43.83702369545486°
#   Rotation θ: -1.6938357807895983°, Rotation φ: 1.1651249768511036°
# Unit 29:
#   Start θ: 54.73662324273844°, Start φ: -45.002148672305964°
#   End θ: 54.31284884725022°, End φ: -42.807965798319124°
#   Rotation θ: -0.42377439548821627°, Rotation φ: 2.19418287398684°
# Unit 30:
#   Start θ: 125.26337675726158°, Start φ: 45.002148672305935°
#   End θ: 119.64503386459019°, End φ: 45.56932856135343°
#   Rotation θ: -5.618342892671393°, Rotation φ: 0.5671798890474946°
# Unit 31:
#   Start θ: 125.2664154957558°, Start φ: 45.00000000000005°
#   End θ: 122.71670111823474°, End φ: 50.59570058512743°
#   Rotation θ: -2.549714377521056°, Rotation φ: 5.595700585127382°
# Unit 32:
#   Start θ: 125.26844120745872°, Start φ: 45.00000000000005°
#   End θ: 124.48985052059106°, End φ: 57.62806576852978°
#   Rotation θ: -0.7785906868676591°, Rotation φ: 12.62806576852973°
# Unit 33:
#   Start θ: 125.26438968275468°, Start φ: 45.00000000000005°
#   End θ: 114.76755979149974°, End φ: 47.20668436922322°
#   Rotation θ: -10.496829891254947°, Rotation φ: 2.2066843692231686°
# Unit 34:
#   Start θ: 54.73358450424422°, Start φ: -45.00000000000005°
#   End θ: 54.457984031221194°, End φ: -43.08640063304782°
#   Rotation θ: -0.2756004730230259°, Rotation φ: 1.9135993669522264°
# Unit 35:
#   Start θ: 54.735610317245325°, Start φ: -45.00000000000005°
#   End θ: 52.98690803963147°, End φ: -45.317383029020185°
#   Rotation θ: -1.7487022776138517°, Rotation φ: -0.31738302902013515°
# Unit 36:
#   Start θ: 54.731558792541286°, Start φ: -45.00000000000005°
#   End θ: 50.584416618371016°, End φ: -47.00777350958136°
#   Rotation θ: -4.14714217417027°, Rotation φ: -2.0077735095813125°
# Unit 37:
#   Start θ: 54.73459745506047°, Start φ: 134.99785132769406°
#   End θ: 61.12745464522657°, End φ: 136.5161368224289°
#   Rotation θ: 6.392857190166104°, Rotation φ: 1.5182854947348403°
# Unit 38:
#   Start θ: 54.73662324273844°, Start φ: 134.99785132769406°
#   End θ: 56.34859725821394°, End φ: 136.81956786079118°
#   Rotation θ: 1.6119740154755036°, Rotation φ: 1.821716533097117°
# Unit 39:
#   Start θ: 125.26337675726155°, Start φ: -134.99785132769406°
#   End θ: 135.84115054908398°, End φ: -134.64488331373218°
#   Rotation θ: 10.577773791822423°, Rotation φ: 0.3529680139618847°
# Unit 40:
#   Start θ: 54.73358450424422°, Start φ: 134.99999999999997°
#   End θ: 55.697577847451306°, End φ: 135.32139059888925°
#   Rotation θ: 0.9639933432070862°, Rotation φ: 0.32139059888928045°
# Unit 41:
#   Start θ: 54.735610317245325°, Start φ: 134.99999999999997°
#   End θ: 51.9029944365426°, End φ: 138.6518971935563°
#   Rotation θ: -2.8326158807027255°, Rotation φ: 3.651897193556323°
# Unit 42:
#   Start θ: 54.731558792541286°, Start φ: 134.99999999999997°
#   End θ: 39.66673507916792°, End φ: 143.5017830204727°
#   Rotation θ: -15.064823713373364°, Rotation φ: 8.501783020472715°
# Unit 43:
#   Start θ: 125.2664154957558°, Start φ: -134.99999999999997°
#   End θ: 84.27325246114678°, End φ: -158.0345611299365°
#   Rotation θ: -40.99316303460901°, Rotation φ: -23.03456112993652°
# Unit 44:
#   Start θ: 125.26844120745872°, Start φ: -134.99999999999997°
#   End θ: 164.73393627575498°, End φ: -161.05258023247993°
#   Rotation θ: 39.46549506829626°, Rotation φ: -26.052580232479954°
# Unit 45:
#   Start θ: 125.26438968275468°, Start φ: -134.99999999999997°
#   End θ: 128.29046230399334°, End φ: -133.20096563066753°
#   Rotation θ: 3.0260726212386544°, Rotation φ: 1.7990343693324462°
# Unit 46:
#   Start θ: 54.73561031724537°, Start φ: 135.00000000000006°
#   End θ: 52.33097361126655°, End φ: 141.2711607196572°
#   Rotation θ: -2.4046367059788167°, Rotation φ: 6.271160719657132°
# Unit 47:
#   Start θ: 54.73763607959988°, Start φ: 135.00000000000006°
#   End θ: 55.33653060816831°, End φ: 164.0788294377913°
#   Rotation θ: 0.5988945285684295°, Rotation φ: 29.078829437791256°
# Unit 48:
#   Start θ: 125.26236392040013°, Start φ: 44.999999999999964°
#   End θ: 117.64990106467894°, End φ: 52.52127211343077°
#   Rotation θ: -7.612462855721191°, Rotation φ: 7.521272113430804°
# Unit 49:
#   Start θ: 54.734597455060495°, Start φ: 135.00214867230594°
#   End θ: 56.46829135826223°, End φ: 141.3321980270722°
#   Rotation θ: 1.7336939032017327°, Rotation φ: 6.33004935476626°
# Unit 50:
#   Start θ: 54.73662324273847°, Start φ: 135.00214867230594°
#   End θ: 51.93577664422243°, End φ: 136.77052214633025°
#   Rotation θ: -2.8008465985160385°, Rotation φ: 1.7683734740243153°
# Unit 51:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769408°
#   End θ: 123.08054445719037°, End φ: 46.20263858229748°
#   Rotation θ: -2.182832300071155°, Rotation φ: 1.2047872546034029°
# Unit 52:
#   Start θ: 54.734597455060495°, Start φ: -44.99785132769408°
#   End θ: 54.18657010220545°, End φ: -42.02240886130401°
#   Rotation θ: -0.5480273528550441°, Rotation φ: 2.9754424663900707°
# Unit 53:
#   Start θ: 54.73662324273847°, Start φ: -44.99785132769408°
#   End θ: 48.9327518842798°, End φ: -49.89590287451414°
#   Rotation θ: -5.8038713584586645°, Rotation φ: -4.898051546820064°
# Unit 54:
#   Start θ: 125.26337675726153°, Start φ: -135.00214867230594°
#   End θ: 126.80098798725712°, End φ: -131.52379270063076°
#   Rotation θ: 1.5376112299955906°, Rotation φ: 3.478355971675171°
# Unit 55:
#   Start θ: 54.73459745506047°, Start φ: 135.00214867230596°
#   End θ: 38.285452822732196°, End φ: 144.62884200156702°
#   Rotation θ: -16.44914463232827°, Rotation φ: 9.626693329261059°
# Unit 56:
#   Start θ: 54.73662324273844°, Start φ: 135.00214867230596°
#   End θ: 45.51651073026353°, End φ: 130.18227986315972°
#   Rotation θ: -9.220112512474905°, Rotation φ: -4.819868809146243°
# Unit 57:
#   Start θ: 125.26337675726158°, Start φ: 44.997851327694065°
#   End θ: 125.6057337931578°, End φ: 45.13359095367218°
#   Rotation θ: 0.3423570358962138°, Rotation φ: 0.13573962597811828°
# Unit 58:
#   Start θ: 54.73459745506047°, Start φ: -44.99785132769408°
#   End θ: 55.98668720651122°, End φ: -39.5103229611672°
#   Rotation θ: 1.2520897514507539°, Rotation φ: 5.487528366526881°
# Unit 59:
#   Start θ: 54.73662324273844°, Start φ: -44.99785132769408°
#   End θ: 54.635534307696155°, End φ: -49.04344179669166°
#   Rotation θ: -0.10108893504228433°, Rotation φ: -4.045590468997581°
# Unit 60:
#   Start θ: 125.26337675726155°, Start φ: -135.00214867230594°
#   End θ: 128.43782014975196°, End φ: -131.41549650869155°
#   Rotation θ: 3.174443392490403°, Rotation φ: 3.5866521636143887°
# Unit 61:
#   Start θ: 54.73561031724537°, Start φ: -45.00000000000004°
#   End θ: 55.80582767324112°, End φ: -40.41327885455806°
#   Rotation θ: 1.0702173559957515°, Rotation φ: 4.5867211454419845°
# Unit 62:
#   Start θ: 54.73763607959988°, Start φ: -45.00000000000004°
#   End θ: 56.32323567298163°, End φ: -34.01998745483013°
#   Rotation θ: 1.585599593381751°, Rotation φ: 10.980012545169913°
# Unit 63:
#   Start θ: 125.26236392040013°, Start φ: 45.00000000000004°
#   End θ: 130.59524347602598°, End φ: 52.21076922776899°
#   Rotation θ: 5.332879555625851°, Rotation φ: 7.2107692277689495°
# Unit 64:
#   Start θ: 125.2664154957558°, Start φ: 44.99999999999995°
#   End θ: 125.29171610530037°, End φ: 51.58674658501191°
#   Rotation θ: 0.025300609544572694°, Rotation φ: 6.586746585011959°
# Unit 65:
#   Start θ: 125.26844120745872°, Start φ: 44.99999999999995°
#   End θ: 128.26346554605428°, End φ: 49.92446973515054°
#   Rotation θ: 2.995024338595556°, Rotation φ: 4.924469735150588°
# Unit 66:
#   Start θ: 125.26438968275468°, Start φ: 44.99999999999995°
#   End θ: 128.37926278269384°, End φ: 52.355087972713015°
#   Rotation θ: 3.1148730999391603°, Rotation φ: 7.355087972713065°
# Unit 67:
#   Start θ: 54.73358450424422°, Start φ: -44.999999999999964°
#   End θ: 53.866912615527674°, End φ: -38.154852764342486°
#   Rotation θ: -0.8666718887165459°, Rotation φ: 6.845147235657478°
# Unit 68:
#   Start θ: 54.735610317245325°, Start φ: -44.999999999999964°
#   End θ: 61.50738332599505°, End φ: -24.979939438758844°
#   Rotation θ: 6.771773008749726°, Rotation φ: 20.02006056124112°
# Unit 69:
#   Start θ: 54.731558792541286°, Start φ: -44.999999999999964°
#   End θ: 54.914020149003036°, End φ: -42.366294968085846°
#   Rotation θ: 0.18246135646175077°, Rotation φ: 2.6337050319141184°
# Unit 70:
#   Start θ: 54.734597455060495°, Start φ: -45.00214867230593°
#   End θ: 56.4782107348787°, End φ: -47.063233256390546°
#   Rotation θ: 1.7436132798182058°, Rotation φ: -2.061084584084618°
# Unit 71:
#   Start θ: 54.73662324273847°, Start φ: -45.00214867230593°
#   End θ: 55.27305597569587°, End φ: -43.96477947113254°
#   Rotation θ: 0.536432732957401°, Rotation φ: 1.0373692011733908°
# Unit 72:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230593°
#   End θ: 127.66691249368432°, End φ: 53.0762022952555°
#   Rotation θ: 2.4035357364227963°, Rotation φ: 8.07405362294957°
# Unit 73:
#   Start θ: 54.73358450424422°, Start φ: 135.00000000000006°
#   End θ: 50.63298178624936°, End φ: 136.07709620351474°
#   Rotation θ: -4.10060271799486°, Rotation φ: 1.0770962035146852°
# Unit 74:
#   Start θ: 54.735610317245325°, Start φ: 135.00000000000006°
#   End θ: 59.467651625094426°, End φ: 118.55036806673814°
#   Rotation θ: 4.7320413078491015°, Rotation φ: -16.449631933261912°
# Unit 75:
#   Start θ: 125.26236384443783°, Start φ: 44.995702816544565°
#   End θ: 126.47241689487552°, End φ: 42.86834954167475°
#   Rotation θ: 1.2100530504376934°, Rotation φ: -2.1273532748698116°
# Unit 76:
#   Start θ: 125.2664154957558°, Start φ: -135.00000000000006°
#   End θ: 122.84940232476694°, End φ: -129.5545606346286°
#   Rotation θ: -2.4170131709888523°, Rotation φ: 5.44543936537147°
# Unit 77:
#   Start θ: 125.26844120745872°, Start φ: -135.00000000000006°
#   End θ: 117.92136587978473°, End φ: -135.08194861565212°
#   Rotation θ: -7.347075327673991°, Rotation φ: -0.08194861565206679°
# Unit 78:
#   Start θ: 125.26438968275468°, Start φ: -135.00000000000006°
#   End θ: 131.31580461701276°, End φ: -133.30468772690017°
#   Rotation θ: 6.0514149342580765°, Rotation φ: 1.695312273099887°
# Unit 79:
#   Start θ: 54.734597455060495°, Start φ: 134.99785132769406°
#   End θ: 54.355340848961625°, End φ: 130.89057852862962°
#   Rotation θ: -0.37925660609887046°, Rotation φ: -4.107272799064447°
# Unit 80:
#   Start θ: 54.73662324273847°, Start φ: 134.99785132769406°
#   End θ: 52.70206796863703°, End φ: 130.79442052583252°
#   Rotation θ: -2.034555274101436°, Rotation φ: -4.203430801861543°
# Unit 81:
#   Start θ: 125.26337675726153°, Start φ: -134.99785132769406°
#   End θ: 121.32678906741197°, End φ: -134.41371178422747°
#   Rotation θ: -3.93658768984956°, Rotation φ: 0.5841395434665912°
# Unit 82:
#   Start θ: 54.737636155562214°, Start φ: 135.00429718345544°
#   End θ: 59.25058117503001°, End φ: 127.61460154149107°
#   Rotation θ: 4.512945019467793°, Rotation φ: -7.389695641964366°
# Unit 83:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 126.79437035600257°, End φ: 42.57328141998022°
#   Rotation θ: 1.5299806732478913°, Rotation φ: -2.426718580019781°
# Unit 84:
#   Start θ: 125.26641549575585°, Start φ: 45.0°
#   End θ: 125.1253336274784°, End φ: 39.48762072040319°
#   Rotation θ: -0.14108186827745328°, Rotation φ: -5.512379279596807°
# Unit 85:
#   Start θ: 54.735610317245346°, Start φ: -45.000000000000014°
#   End θ: 51.7593694528727°, End φ: -45.199743125823645°
#   Rotation θ: -2.976240864372649°, Rotation φ: -0.1997431258236304°
# Unit 86:
#   Start θ: 125.2623638444378°, Start φ: -135.00429718345544°
#   End θ: 118.77543698358092°, End φ: -129.85044735449102°
#   Rotation θ: -6.486926860856883°, Rotation φ: 5.153849828964411°
# Unit 87:
#   Start θ: 54.73358450424416°, Start φ: -45.000000000000014°
#   End θ: 53.458006913970536°, End φ: -40.926154639419146°
#   Rotation θ: -1.2755775902736275°, Rotation φ: 4.073845360580869°
# Unit 88:
#   Start θ: 54.736623242738496°, Start φ: -45.00214867230598°
#   End θ: 46.59313035495899°, End φ: -25.330532653664445°
#   Rotation θ: -8.143492887779509°, Rotation φ: 19.671616018641533°
# Unit 89:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230598°
#   End θ: 126.19488200042814°, End φ: 43.167818135093526°
#   Rotation θ: 0.9315052431666118°, Rotation φ: -1.8343305372124519°
# Unit 90:
#   Start θ: 54.73459745506044°, Start φ: -45.00214867230598°
#   End θ: 54.91906778432688°, End φ: -40.34229026000154°
#   Rotation θ: 0.18447032926643914°, Rotation φ: 4.6598584123044375°
# Unit 91:
#   Start θ: 54.735610317245346°, Start φ: 135.00000000000003°
#   End θ: 55.892987065580925°, End φ: 126.16906679558161°
#   Rotation θ: 1.1573767483355795°, Rotation φ: -8.830933204418415°
# Unit 92:
#   Start θ: 125.2623638444378°, Start φ: -134.99570281654456°
#   End θ: 126.48114176533115°, End φ: -139.12357905799306°
#   Rotation θ: 1.218777920893345°, Rotation φ: -4.12787624144849°
# Unit 93:
#   Start θ: 54.73358450424416°, Start φ: 135.00000000000003°
#   End θ: 53.21095657479507°, End φ: 132.64855940205862°
#   Rotation θ: -1.5226279294490936°, Rotation φ: -2.351440597941405°
# Unit 94:
#   Start θ: 54.73763615556222°, Start φ: 134.99570281654456°
#   End θ: 55.69771830213099°, End φ: 123.18582725939297°
#   Rotation θ: 0.9600821465687659°, Rotation φ: -11.8098755571516°
# Unit 95:
#   Start θ: 125.26438968275465°, Start φ: -135.0°
#   End θ: 124.69418378519262°, End φ: -132.6290255139508°
#   Rotation θ: -0.5702058975620332°, Rotation φ: 2.3709744860491924°
# Unit 96:
#   Start θ: 125.26641549575585°, Start φ: -135.0°
#   End θ: 121.80586068109398°, End φ: -144.0398015063083°
#   Rotation θ: -3.460554814661876°, Rotation φ: -9.039801506308294°
# Unit 97:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769404°
#   End θ: 56.94826128150978°, End φ: 133.43044803966382°
#   Rotation θ: 2.2116380387712766°, Rotation φ: -1.5674032880302207°
# Unit 98:
#   Start θ: 125.26337675726151°, Start φ: -134.99785132769404°
#   End θ: 125.08001871757115°, End φ: -132.5809057987323°
#   Rotation θ: -0.18335803969036135°, Rotation φ: 2.4169455289617474°
# Unit 99:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769404°
#   End θ: 58.900037188137794°, End φ: 136.62812384316626°
#   Rotation θ: 4.165439733077356°, Rotation φ: 1.6302725154722282°
# Unit 100:
#   Start θ: 54.736623242738496°, Start φ: 135.00214867230596°
#   End θ: 53.17978558955855°, End φ: 136.4548899391345°
#   Rotation θ: -1.5568376531799473°, Rotation φ: 1.4527412668285251°
# Unit 101:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769403°
#   End θ: 127.25915516822451°, End φ: 49.42428953704735°
#   Rotation θ: 1.9957784109629841°, Rotation φ: 4.426438209353321°
# Unit 102:
#   Start θ: 54.73459745506044°, Start φ: 135.00214867230596°
#   End θ: 55.502833607345565°, End φ: 131.66707178271034°
#   Rotation θ: 0.7682361522851266°, Rotation φ: -3.3350768895956264°
# Unit 103:
#   Start θ: 54.7366232427385°, Start φ: -44.99785132769403°
#   End θ: 36.427450012209576°, End φ: -39.93253908260045°
#   Rotation θ: -18.309173230528927°, Rotation φ: 5.06531224509358°
# Unit 104:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230596°
#   End θ: 112.75336328411365°, End φ: -126.50902783748505°
#   Rotation θ: -12.510013473147865°, Rotation φ: 8.493120834820914°
# Unit 105:
#   Start θ: 54.73459745506044°, Start φ: -44.99785132769403°
#   End θ: 54.654116129316506°, End φ: -39.821646221116914°
#   Rotation θ: -0.08048132574393208°, Rotation φ: 5.176205106577115°
# Unit 106:
#   Start θ: 54.737636079599945°, Start φ: 135.0°
#   End θ: 57.92902292951112°, End φ: 131.04477017437776°
#   Rotation θ: 3.1913868499111757°, Rotation φ: -3.95522982562224°
# Unit 107:
#   Start θ: 125.26236392040008°, Start φ: 45.0°
#   End θ: 124.35837326618763°, End φ: 39.134477113076585°
#   Rotation θ: -0.9039906542124498°, Rotation φ: -5.865522886923415°
# Unit 108:
#   Start θ: 54.735610317245346°, Start φ: 135.0°
#   End θ: 53.00747435020078°, End φ: 135.15109611469745°
#   Rotation θ: -1.7281359670445653°, Rotation φ: 0.15109611469745232°

# %%
df = pd.DataFrame({
    r'PS$_4$$^{3-}$ unit': list(rotation_data.keys()),
    r'$\theta$ ($^\circ$)': [data['rotation_theta'] for data in rotation_data.values()],
    r'$\phi$ ($^\circ$)': [data['rotation_phi'] for data in rotation_data.values()],
    r'Displacement of S (\AA)': [data['distance']*lattice_param for data in closest_sulfur_pairs.values()]
})

display(df)

readytosave=True
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    df.to_csv(f"{saveloc}/{cleaned_matname} displacements.csv")
# Out:
#      PS$_4$$^{3-}$ unit  $\theta$ ($^\circ$)  $\phi$ ($^\circ$)  \
# 0                     1            -0.510763          -3.058131
# 1                     2            -2.608053          -0.903011
# 2                     3            -2.219150           3.118732
# 3                     4            -2.456076           1.126836
# 4                     5            -1.905339           5.239745
# ..                  ...                  ...                ...
# 103                 104           -12.510013           8.493121
# 104                 105            -0.080481           5.176205
# 105                 106             3.191387          -3.955230
# 106                 107            -0.903991          -5.865523
# 107                 108            -1.728136           0.151096
#
#      Displacement of S (\AA)
# 0                   0.112718
# 1                   0.117888
# 2                   0.139470
# 3                   0.114937
# 4                   0.183125
# ..                       ...
# 103                 0.529059
# 104                 0.166377
# 105                 0.178372
# 106                 0.189039
# 107                 0.090438
#
# [108 rows x 4 columns]

# %%
import numpy as np

# Initialize sums for theta, phi rotations, and distance
total_theta_rotation = 0
total_phi_rotation = 0
total_distance = 0

# Initialize sums for squared differences
sum_squared_diff_theta = 0
sum_squared_diff_phi = 0
sum_squared_diff_distance = 0

# Count the number of units
num_units = len(rotation_data)

# Collect all theta, phi, and distance values
theta_values = []
phi_values = []
distance_values = []

# Sum up the rotations and collect values for all units
for unit, data in rotation_data.items():
    total_theta_rotation += data['rotation_theta']
    total_phi_rotation += data['rotation_phi']
    theta_values.append(data['rotation_theta'])
    phi_values.append(data['rotation_phi'])

for unit, data in closest_sulfur_pairs.items():
    total_distance += data['distance']
    distance_values.append(data['distance'])

# Calculate the average theta, phi rotations, and distance
average_theta_rotation = total_theta_rotation / num_units
average_phi_rotation = total_phi_rotation / num_units
average_distance = total_distance / num_units

# Calculate the squared differences from the mean for each unit
for unit, data in rotation_data.items():
    sum_squared_diff_theta += (data['rotation_theta'] - average_theta_rotation) ** 2
    sum_squared_diff_phi += (data['rotation_phi'] - average_phi_rotation) ** 2

for unit, data in closest_sulfur_pairs.items():
    sum_squared_diff_distance += (data['distance'] - average_distance) ** 2

# Calculate the variances using `num_units - 1` for the denominator
variance_theta = sum_squared_diff_theta / (num_units - 1)
variance_phi = sum_squared_diff_phi / (num_units - 1)
variance_distance = sum_squared_diff_distance / (num_units - 1)

# Calculate the standard deviations
std_dev_theta = variance_theta ** 0.5
std_dev_phi = variance_phi ** 0.5
std_dev_distance = variance_distance ** 0.5

# Convert average distance and standard deviation to angstroms
average_distance_angstrom = average_distance * lattice_param
std_dev_distance_angstrom = std_dev_distance * lattice_param

# Calculate the medians for theta, phi, and distance
median_theta_rotation = np.median(theta_values)
median_phi_rotation = np.median(phi_values)
median_distance = np.median(distance_values)
median_distance_angstrom = median_distance * lattice_param

# Print the average, median rotations, and their standard deviations
print(f"Average θ rotation: {average_theta_rotation}°, Standard Deviation: {std_dev_theta}°")
print(f"Median θ rotation: {median_theta_rotation}°")
print(f"Average φ rotation: {average_phi_rotation}°, Standard Deviation: {std_dev_phi}°")
print(f"Median φ rotation: {median_phi_rotation}°")
print(f"Average Displacement: {average_distance_angstrom} angstroms, Standard Deviation: {std_dev_distance_angstrom} angstroms")
print(f"Median Displacement: {median_distance_angstrom} angstroms")
# Out:
# Average θ rotation: -1.2988983485710113°, Standard Deviation: 7.876491935834706°
# Median θ rotation: -0.3274285395609482°
# Average φ rotation: 1.0080635734602732°, Standard Deviation: 8.391211499281221°
# Median φ rotation: 1.328764260715964°
# Average Displacement: 0.2611782484332423 angstroms, Standard Deviation: 0.2782862597473488 angstroms
# Median Displacement: 0.16574291502891395 angstroms

# %%
#generate a table for average displacements

attributes=[r'$\theta$ ($^\circ$)', r'$\phi$ ($^\circ$)', r'Displacement of S (\AA)']
averages=[average_theta_rotation, average_phi_rotation,average_distance_angstrom]
medians=[median_theta_rotation,median_phi_rotation,median_distance_angstrom]
std_devs=[std_dev_theta,std_dev_phi,std_dev_distance_angstrom]

collated={
    r'Attribute':attributes,
    r'Average':averages,
    r'Median':medians,
    r'Standard Deviation':std_devs,
}

collated=pd.DataFrame(collated)

display(collated)

readytosave=True
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    collated.to_csv(f"{saveloc}/{cleaned_matname} dispersities.csv")
# Out:
#                  Attribute   Average    Median  Standard Deviation
# 0      $\theta$ ($^\circ$) -1.298898 -0.327429            7.876492
# 1        $\phi$ ($^\circ$)  1.008064  1.328764            8.391211
# 2  Displacement of S (\AA)  0.261178  0.165743            0.278286

# %%
# Initialize variables to store the maximum distance and the corresponding unit
max_distance = 0
max_unit = None
max_sulfur_pair = None

# Iterate through the closest_sulfur_pairs dictionary
for unit, data in closest_sulfur_pairs.items():
    # Extract the distance value
    distance = data['distance']
    
    # Check if this is the maximum distance encountered so far
    if distance > max_distance:
        max_distance = distance
        max_unit = unit
        max_sulfur_pair = (data['start_sulfur'], data['closest_end_sulfur'])

# Print the results
print(f"Maximum distance: {max_distance}")
print(f"Unit number: {max_unit}")
print(f"Starting sulfur: {max_sulfur_pair[0]}")
print(f"Ending sulfur: {max_sulfur_pair[1]}")
print(f"Maximum θ:{rotation_data[max_unit]['rotation_theta']}°")
print(f"Maximum φ:{rotation_data[max_unit]['rotation_phi']}°")
# Out:
# Maximum distance: 0.053744131772687526
# Unit number: 43
# Starting sulfur: (0.37667, 0.87667, 0.21)
# Ending sulfur: 4
# Maximum θ:-40.99316303460901°
# Maximum φ:-23.03456112993652°

# %%
readytosave=True

fig, axs=plt.subplots(1,1, figsize=(6,6))

max_theta = rotation_data[max_unit]['rotation_theta']
max_phi = rotation_data[max_unit]['rotation_phi']

if abs(max_phi)>abs(max_theta):
    lim=abs(max_phi)*1.05
else:
    lim=abs(max_theta)*1.05
    
lim=85


for unit, data in rotation_data.items():
    if unit!=max_unit:
        axs.scatter(data['rotation_phi'],data['rotation_theta'],edgecolor=datacolor,facecolors='white',linewidths=2, marker='o')
    else:
        axs.scatter(rotation_data[max_unit]['rotation_phi'],rotation_data[max_unit]['rotation_theta'], edgecolor='#cc0000',facecolors='white',linewidths=2, marker='o')
#axs.scatter(0,0,color="orange",edgecolor='black',marker='^',s=150)

axs.text(-lim+lim*.9,lim*.45,fr'Max displacement:' '\n' fr'{max_distance*lattice_param:.2f} \AA' '\n' fr'$\theta$: {max_theta:.2f}$^\circ$' '\n' fr'$\phi$: {max_phi:.2f}$^\circ$',bbox=dict(
        facecolor='none',     # Transparent fill color for the box
       edgecolor="#cc0000",  # Match the box edge color with the marker
        linewidth=2,        # Box edge width
       boxstyle='round,pad=0.3'  # Rounded box with padding
  ))
    
axs.set_xlim([-lim,lim])
axs.set_ylim([-lim,lim])

axs.xaxis.set_major_locator(ticker.MaxNLocator(8))
axs.yaxis.set_major_locator(ticker.MaxNLocator(8))
axs.xaxis.set_minor_locator(AutoMinorLocator(2))
axs.yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(which='major', direction='in', length=6)
plt.tick_params(which='minor', direction='in', length=4)

axs.set_xlabel(r'$\phi$ ($^{\circ}$)')
axs.set_ylabel(r'$\theta$ ($^{\circ}$)')
axs.set_title(material)

plt.tight_layout()

if readytosave==True:
    png=''.join((saveloc,'/',cleaned_matname,'rotation summary','.png'))
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    plt.savefig(png,dpi=800,format='png')


plt.show()

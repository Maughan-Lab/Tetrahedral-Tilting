# %% [markdown]
# ## import necessary packages
# import pandas as pd
# from datetime import datetime, timedelta, timezone
# import os
# from PyEIS import *
# import numpy as np
# import matplotlib.pyplot as plt
# from matplotlib import rcParams
# import csv
# import glob
# import statistics
# from sklearn.linear_model import LinearRegression
# from scipy.stats import linregress
# import math
# from colour import Color
# import re
# import matplotlib.ticker as ticker
# from matplotlib.ticker import FormatStrFormatter
# from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
# from matplotlib.ticker import AutoMinorLocator
#
# from matplotlib.pyplot import rc
#
# allSized=20
# rc('text',usetex=True)
# rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']},size=allSized)
# rc('text.latex', preamble=r'\usepackage{sfmath}')
# plt.rc('font',   size=     allSized,**{'family':"sans-serif"})     # controls default text sizes
# plt.rc('axes',   titlesize=allSized)     # fontsize of the axes title
# plt.rc('axes',   labelsize=allSized)    # fontsize of the x and y labels
# plt.rc('xtick',  labelsize=allSized)    # fontsize of the tick labels
# plt.rc('ytick',  labelsize=allSized)    # fontsize of the tick labels
# plt.rc('legend', fontsize= allSized)    # legend fontsize
# plt.rc('figure', titlesize=allSized)  # fontsize of the figure title

# %%
# Function to calculate Euclidean distance between two points
def calculate_distance(coord1, coord2):
    return math.sqrt((coord1[0] - coord2[0])**2 + (coord1[1] - coord2[1])**2 + (coord1[2] - coord2[2])**2)


def cartesian_to_spherical(x, y, z):
    r = np.sqrt(x**2 + y**2 + z**2)
    theta = np.arccos(z / r) if r != 0 else 0  # θ: angle from z-axis
    phi = np.arctan2(y, x)  # φ: angle from x-axis in the xy-plane
    return r, np.degrees(theta), np.degrees(phi)

# %%
start_file='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Python Processed Str/Consolidated strs/3by3/Li6PS5Br_3by3_P1_dualLi_limited rotation_beqpdfgui_site disorder_Lioccref.txt'

end_file="C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/PDF SA_ Joint Refinement working copy/SSM LPSB/6_25_2024_LPSB_SSM/6_19_2024_Br_SSM_3by3_100k_Joint_Lorchdamping_Lioccref.inp"

material=r'SSM Li$_6$PS$_5$Br'

datacolor='#9752ff'

lattice_param=29.969297

#filter non-alphanumeric and space characters from the material name so that it's easier to deal with from a file management perspective
cleaned_matname = filter(lambda x: x.isalnum() or x.isspace(), material)

# filter returns a generator, so we need to re-join the string
cleaned_matname = "".join(cleaned_matname)

print(cleaned_matname)

saveloc='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/Paper Plotting/PS4 Rotations and cifs/rotation plots'
# Out:
# SSM Li6PS5Br

# %%
start_coordinates={}

# Regular expression pattern to match the lines with start_coordinates
pattern = re.compile(r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.-]+)\s+y\s+([\d.-]+)\s+z\s+([\d.-]+)")

# Open the file and process each line
with open(start_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)

# Example: Accessing the start_coordinates for a specific thiophosphate unit
example_unit = 1
print(f"start_coordinates for P{example_unit}: {start_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"start_coordinates for S{example_unit}{i}: {start_coordinates[example_unit]['S'][i]}")
# Out:
# start_coordinates for P1: (0.25, 0.25, 0.083333)
# start_coordinates for S11: (0.29, 0.21, 0.12333)
# start_coordinates for S12: (0.21, 0.29, 0.12333)
# start_coordinates for S13: (0.29, 0.29, 0.04333)
# start_coordinates for S14: (0.21, 0.21, 0.04333)

# %%
# Initialize the dictionary to store the end_coordinates
end_coordinates = {}

# Regular expression pattern to match the lines with end_coordinates, accounting for '_0.00000' or any number
pattern = re.compile(r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.-]+)_[\d.-]+\s+y\s+([\d.-]+)_[\d.-]+\s+z\s+([\d.-]+)_[\d.-]+")

# Open the file and process each line
with open(end_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)

# Example: Accessing the end_coordinates for a specific thiophosphate unit
example_unit = 4
print(f"end_coordinates for P{example_unit}: {end_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"end_coordinates for S{example_unit}{i}: {end_coordinates[example_unit]['S'][i]}")
# Out:
# end_coordinates for P4: (0.25, 0.58333, 0.08333)
# end_coordinates for S41: (0.20918, 0.54628, 0.04326)
# end_coordinates for S42: (0.29748, 0.61399, 0.04525)
# end_coordinates for S43: (0.21313, 0.63046, 0.11595)
# end_coordinates for S44: (0.28021, 0.54261, 0.12887)

# %%
# Dictionary to store closest sulfur pairs
closest_sulfur_pairs = {}

# Find the closest sulfur atom for each S1 from start to end units
for unit_number, start_sulfurs in start_coordinates.items():
    if 'S' in start_sulfurs:
        start_sulfur1_coords = start_sulfurs['S'].get(1)
        if start_sulfur1_coords:
            min_distance = float('inf')
            closest_sulfur = None
            for sulfur_number, end_sulfur_coords in end_coordinates[unit_number]['S'].items():
                distance = calculate_distance(start_sulfur1_coords, end_sulfur_coords)
                if distance < min_distance:
                    min_distance = distance
                    closest_sulfur = sulfur_number
            closest_sulfur_pairs[unit_number] = {
                'start_sulfur': start_sulfur1_coords,
                'closest_end_sulfur': closest_sulfur,
                'end_sulfur_coords': end_coordinates[unit_number]['S'][closest_sulfur],
                'distance': min_distance
            }

# Example: Print out the closest sulfur atom pairs
for unit, data in closest_sulfur_pairs.items():
    print(f"Unit {unit}:")
    print(f"  Start S{unit}1 Coordinates: {data['start_sulfur']}")
    print(f"  Closest End S{unit}{data['closest_end_sulfur']} Coordinates: {data['end_sulfur_coords']}")
    print(f"  Distance: {data['distance']:.5f}")
# Out:
# Unit 1:
#   Start S11 Coordinates: (0.29, 0.21, 0.12333)
#   Closest End S14 Coordinates: (0.29147, 0.21287, 0.12265)
#   Distance: 0.00330
# Unit 2:
#   Start S21 Coordinates: (0.29, 0.29, 0.37667)
#   Closest End S23 Coordinates: (0.28679, 0.29176, 0.37733)
#   Distance: 0.00372
# Unit 3:
#   Start S31 Coordinates: (0.29, 0.29, 0.71)
#   Closest End S34 Coordinates: (0.28472, 0.29443, 0.71173)
#   Distance: 0.00711
# Unit 4:
#   Start S41 Coordinates: (0.21, 0.62333, 0.12333)
#   Closest End S43 Coordinates: (0.21313, 0.63046, 0.11595)
#   Distance: 0.01073
# Unit 5:
#   Start S51 Coordinates: (0.29, 0.62333, 0.37667)
#   Closest End S53 Coordinates: (0.29154, 0.62107, 0.378)
#   Distance: 0.00304
# Unit 6:
#   Start S61 Coordinates: (0.29, 0.62333, 0.71)
#   Closest End S63 Coordinates: (0.2848, 0.62301, 0.70688)
#   Distance: 0.00607
# Unit 7:
#   Start S71 Coordinates: (0.29, 0.87667, 0.12333)
#   Closest End S72 Coordinates: (0.29134, 0.88093, 0.12406)
#   Distance: 0.00453
# Unit 8:
#   Start S81 Coordinates: (0.21, 0.87667, 0.37667)
#   Closest End S84 Coordinates: (0.22003, 0.87495, 0.37195)
#   Distance: 0.01122
# Unit 9:
#   Start S91 Coordinates: (0.29, 0.87667, 0.79)
#   Closest End S94 Coordinates: (0.28567, 0.87265, 0.78778)
#   Distance: 0.00631
# Unit 10:
#   Start S101 Coordinates: (0.62333, 0.21, 0.12333)
#   Closest End S101 Coordinates: (0.62448, 0.21689, 0.12641)
#   Distance: 0.00763
# Unit 11:
#   Start S111 Coordinates: (0.62333, 0.29, 0.37667)
#   Closest End S111 Coordinates: (0.61442, 0.29008, 0.37115)
#   Distance: 0.01048
# Unit 12:
#   Start S121 Coordinates: (0.62333, 0.29, 0.71)
#   Closest End S122 Coordinates: (0.6209, 0.28798, 0.70768)
#   Distance: 0.00392
# Unit 13:
#   Start S131 Coordinates: (0.54333, 0.62333, 0.12333)
#   Closest End S132 Coordinates: (0.55198, 0.62955, 0.12239)
#   Distance: 0.01070
# Unit 14:
#   Start S141 Coordinates: (0.62333, 0.62333, 0.37667)
#   Closest End S143 Coordinates: (0.62083, 0.62646, 0.37954)
#   Distance: 0.00493
# Unit 15:
#   Start S151 Coordinates: (0.62333, 0.62333, 0.71)
#   Closest End S152 Coordinates: (0.62259, 0.625, 0.71302)
#   Distance: 0.00353
# Unit 16:
#   Start S161 Coordinates: (0.62333, 0.87667, 0.12333)
#   Closest End S161 Coordinates: (0.62297, 0.87626, 0.1213)
#   Distance: 0.00210
# Unit 17:
#   Start S171 Coordinates: (0.62333, 0.95667, 0.37667)
#   Closest End S171 Coordinates: (0.62698, 0.96892, 0.41976)
#   Distance: 0.04495
# Unit 18:
#   Start S181 Coordinates: (0.62333, 0.87667, 0.79)
#   Closest End S183 Coordinates: (0.61838, 0.87243, 0.78806)
#   Distance: 0.00680
# Unit 19:
#   Start S191 Coordinates: (0.87667, 0.29, 0.12333)
#   Closest End S194 Coordinates: (0.87916, 0.2834, 0.12928)
#   Distance: 0.00923
# Unit 20:
#   Start S201 Coordinates: (0.87667, 0.21, 0.37667)
#   Closest End S204 Coordinates: (0.88506, 0.18997, 0.42223)
#   Distance: 0.05047
# Unit 21:
#   Start S211 Coordinates: (0.87667, 0.29, 0.79)
#   Closest End S212 Coordinates: (0.87087, 0.26534, 0.79798)
#   Distance: 0.02656
# Unit 22:
#   Start S221 Coordinates: (0.87667, 0.62333, 0.12333)
#   Closest End S221 Coordinates: (0.89235, 0.62662, 0.12991)
#   Distance: 0.01732
# Unit 23:
#   Start S231 Coordinates: (0.87667, 0.54333, 0.37667)
#   Closest End S231 Coordinates: (0.87633, 0.54593, 0.37656)
#   Distance: 0.00262
# Unit 24:
#   Start S241 Coordinates: (0.87667, 0.62333, 0.79)
#   Closest End S243 Coordinates: (0.87592, 0.61838, 0.79178)
#   Distance: 0.00531
# Unit 25:
#   Start S251 Coordinates: (0.95667, 0.87667, 0.12333)
#   Closest End S252 Coordinates: (0.96086, 0.87542, 0.11464)
#   Distance: 0.00973
# Unit 26:
#   Start S261 Coordinates: (0.87667, 0.87667, 0.37667)
#   Closest End S262 Coordinates: (0.87239, 0.87427, 0.38707)
#   Distance: 0.01150
# Unit 27:
#   Start S271 Coordinates: (0.87667, 0.87667, 0.71)
#   Closest End S274 Coordinates: (0.88197, 0.86281, 0.77321)
#   Distance: 0.06493
# Unit 28:
#   Start S281 Coordinates: (0.12333, 0.21, 0.29)
#   Closest End S284 Coordinates: (0.123, 0.20865, 0.28685)
#   Distance: 0.00344
# Unit 29:
#   Start S291 Coordinates: (0.12333, 0.21, 0.62333)
#   Closest End S291 Coordinates: (0.11547, 0.20711, 0.62543)
#   Distance: 0.00863
# Unit 30:
#   Start S301 Coordinates: (0.12333, 0.29, 0.87667)
#   Closest End S302 Coordinates: (0.12513, 0.28944, 0.88009)
#   Distance: 0.00391
# Unit 31:
#   Start S311 Coordinates: (0.12333, 0.62333, 0.21)
#   Closest End S313 Coordinates: (0.12488, 0.62393, 0.21441)
#   Distance: 0.00471
# Unit 32:
#   Start S321 Coordinates: (0.12333, 0.62333, 0.54333)
#   Closest End S323 Coordinates: (0.12189, 0.62507, 0.54575)
#   Distance: 0.00331
# Unit 33:
#   Start S331 Coordinates: (0.12333, 0.62333, 0.87667)
#   Closest End S334 Coordinates: (0.12446, 0.62915, 0.88748)
#   Distance: 0.01233
# Unit 34:
#   Start S341 Coordinates: (0.12333, 0.87667, 0.29)
#   Closest End S343 Coordinates: (0.10593, 0.88736, 0.30721)
#   Distance: 0.02671
# Unit 35:
#   Start S351 Coordinates: (0.12333, 0.87667, 0.62333)
#   Closest End S351 Coordinates: (0.11432, 0.87723, 0.62948)
#   Distance: 0.01092
# Unit 36:
#   Start S361 Coordinates: (0.12333, 0.87667, 0.95667)
#   Closest End S361 Coordinates: (0.11714, 0.87858, 0.96186)
#   Distance: 0.00830
# Unit 37:
#   Start S371 Coordinates: (0.37667, 0.29, 0.29)
#   Closest End S371 Coordinates: (0.3689, 0.28434, 0.2844)
#   Distance: 0.01113
# Unit 38:
#   Start S381 Coordinates: (0.37667, 0.29, 0.62333)
#   Closest End S383 Coordinates: (0.37916, 0.29098, 0.62276)
#   Distance: 0.00274
# Unit 39:
#   Start S391 Coordinates: (0.37667, 0.21, 0.87667)
#   Closest End S393 Coordinates: (0.37779, 0.21732, 0.87125)
#   Distance: 0.00918
# Unit 40:
#   Start S401 Coordinates: (0.37667, 0.62333, 0.29)
#   Closest End S404 Coordinates: (0.3734, 0.62057, 0.28718)
#   Distance: 0.00512
# Unit 41:
#   Start S411 Coordinates: (0.37667, 0.62333, 0.62333)
#   Closest End S414 Coordinates: (0.37281, 0.60988, 0.62818)
#   Distance: 0.01481
# Unit 42:
#   Start S421 Coordinates: (0.37667, 0.62333, 0.95667)
#   Closest End S421 Coordinates: (0.36437, 0.61819, 0.94303)
#   Distance: 0.01907
# Unit 43:
#   Start S431 Coordinates: (0.37667, 0.87667, 0.21)
#   Closest End S433 Coordinates: (0.38251, 0.87594, 0.20739)
#   Distance: 0.00644
# Unit 44:
#   Start S441 Coordinates: (0.37667, 0.87667, 0.54333)
#   Closest End S442 Coordinates: (0.38169, 0.87885, 0.53871)
#   Distance: 0.00716
# Unit 45:
#   Start S451 Coordinates: (0.37667, 0.87667, 0.87667)
#   Closest End S451 Coordinates: (0.37697, 0.87802, 0.87698)
#   Distance: 0.00142
# Unit 46:
#   Start S461 Coordinates: (0.71, 0.29, 0.29)
#   Closest End S462 Coordinates: (0.70747, 0.29229, 0.28235)
#   Distance: 0.00838
# Unit 47:
#   Start S471 Coordinates: (0.71, 0.29, 0.62333)
#   Closest End S474 Coordinates: (0.71324, 0.29183, 0.62262)
#   Distance: 0.00379
# Unit 48:
#   Start S481 Coordinates: (0.79, 0.29, 0.87667)
#   Closest End S484 Coordinates: (0.79261, 0.28594, 0.87747)
#   Distance: 0.00489
# Unit 49:
#   Start S491 Coordinates: (0.71, 0.62333, 0.29)
#   Closest End S491 Coordinates: (0.71263, 0.62937, 0.2836)
#   Distance: 0.00918
# Unit 50:
#   Start S501 Coordinates: (0.71, 0.62333, 0.62333)
#   Closest End S501 Coordinates: (0.70707, 0.62162, 0.61974)
#   Distance: 0.00494
# Unit 51:
#   Start S511 Coordinates: (0.79, 0.62333, 0.87667)
#   Closest End S514 Coordinates: (0.79786, 0.6269, 0.89557)
#   Distance: 0.02078
# Unit 52:
#   Start S521 Coordinates: (0.79, 0.87667, 0.29)
#   Closest End S522 Coordinates: (0.78238, 0.8788, 0.29639)
#   Distance: 0.01017
# Unit 53:
#   Start S531 Coordinates: (0.79, 0.87667, 0.62333)
#   Closest End S534 Coordinates: (0.78474, 0.87914, 0.62826)
#   Distance: 0.00762
# Unit 54:
#   Start S541 Coordinates: (0.71, 0.87667, 0.87667)
#   Closest End S541 Coordinates: (0.71482, 0.87586, 0.87506)
#   Distance: 0.00515
# Unit 55:
#   Start S551 Coordinates: (0.21, 0.12333, 0.29)
#   Closest End S552 Coordinates: (0.21099, 0.12474, 0.28739)
#   Distance: 0.00313
# Unit 56:
#   Start S561 Coordinates: (0.21, 0.12333, 0.62333)
#   Closest End S561 Coordinates: (0.2135, 0.1248, 0.62311)
#   Distance: 0.00380
# Unit 57:
#   Start S571 Coordinates: (0.29, 0.12333, 0.87667)
#   Closest End S571 Coordinates: (0.28304, 0.11917, 0.86915)
#   Distance: 0.01106
# Unit 58:
#   Start S581 Coordinates: (0.29, 0.37667, 0.29)
#   Closest End S584 Coordinates: (0.29234, 0.3749, 0.28312)
#   Distance: 0.00748
# Unit 59:
#   Start S591 Coordinates: (0.29, 0.37667, 0.62333)
#   Closest End S594 Coordinates: (0.28876, 0.37363, 0.6191)
#   Distance: 0.00535
# Unit 60:
#   Start S601 Coordinates: (0.21, 0.37667, 0.87667)
#   Closest End S602 Coordinates: (0.19047, 0.40046, 0.88791)
#   Distance: 0.03277
# Unit 61:
#   Start S611 Coordinates: (0.29, 0.71, 0.29)
#   Closest End S612 Coordinates: (0.29268, 0.70641, 0.2802)
#   Distance: 0.01078
# Unit 62:
#   Start S621 Coordinates: (0.29, 0.71, 0.62333)
#   Closest End S624 Coordinates: (0.29512, 0.7133, 0.61871)
#   Distance: 0.00765
# Unit 63:
#   Start S631 Coordinates: (0.29, 0.79, 0.87667)
#   Closest End S632 Coordinates: (0.27669, 0.78846, 0.86725)
#   Distance: 0.01638
# Unit 64:
#   Start S641 Coordinates: (0.62333, 0.12333, 0.21)
#   Closest End S644 Coordinates: (0.5946, 0.12799, 0.19987)
#   Distance: 0.03082
# Unit 65:
#   Start S651 Coordinates: (0.62333, 0.12333, 0.54333)
#   Closest End S654 Coordinates: (0.62219, 0.12619, 0.54746)
#   Distance: 0.00515
# Unit 66:
#   Start S661 Coordinates: (0.62333, 0.12333, 0.87667)
#   Closest End S663 Coordinates: (0.61224, 0.14082, 0.89444)
#   Distance: 0.02729
# Unit 67:
#   Start S671 Coordinates: (0.62333, 0.37667, 0.29)
#   Closest End S674 Coordinates: (0.62917, 0.38529, 0.28935)
#   Distance: 0.01043
# Unit 68:
#   Start S681 Coordinates: (0.62333, 0.37667, 0.62333)
#   Closest End S684 Coordinates: (0.62321, 0.3818, 0.62609)
#   Distance: 0.00583
# Unit 69:
#   Start S691 Coordinates: (0.62333, 0.37667, 0.95667)
#   Closest End S693 Coordinates: (0.62381, 0.37887, 0.95625)
#   Distance: 0.00229
# Unit 70:
#   Start S701 Coordinates: (0.62333, 0.71, 0.29)
#   Closest End S702 Coordinates: (0.62765, 0.71094, 0.28383)
#   Distance: 0.00759
# Unit 71:
#   Start S711 Coordinates: (0.62333, 0.71, 0.62333)
#   Closest End S711 Coordinates: (0.62803, 0.71437, 0.62029)
#   Distance: 0.00710
# Unit 72:
#   Start S721 Coordinates: (0.62333, 0.79, 0.87667)
#   Closest End S721 Coordinates: (0.61236, 0.79154, 0.87122)
#   Distance: 0.01235
# Unit 73:
#   Start S731 Coordinates: (0.87667, 0.12333, 0.29)
#   Closest End S732 Coordinates: (0.87259, 0.11516, 0.29097)
#   Distance: 0.00918
# Unit 74:
#   Start S741 Coordinates: (0.87667, 0.12333, 0.62333)
#   Closest End S742 Coordinates: (0.87163, 0.09765, 0.63233)
#   Distance: 0.02767
# Unit 75:
#   Start S751 Coordinates: (0.95667, 0.12333, 0.87667)
#   Closest End S752 Coordinates: (0.94971, 0.1289, 0.87838)
#   Distance: 0.00908
# Unit 76:
#   Start S761 Coordinates: (0.87667, 0.37667, 0.21)
#   Closest End S761 Coordinates: (0.86923, 0.37003, 0.23557)
#   Distance: 0.02745
# Unit 77:
#   Start S771 Coordinates: (0.87667, 0.37667, 0.54333)
#   Closest End S772 Coordinates: (0.87215, 0.37501, 0.55305)
#   Distance: 0.01085
# Unit 78:
#   Start S781 Coordinates: (0.87667, 0.37667, 0.87667)
#   Closest End S783 Coordinates: (0.87913, 0.363, 0.89809)
#   Distance: 0.02553
# Unit 79:
#   Start S791 Coordinates: (0.87667, 0.79, 0.29)
#   Closest End S791 Coordinates: (0.88483, 0.79363, 0.29143)
#   Distance: 0.00904
# Unit 80:
#   Start S801 Coordinates: (0.87667, 0.79, 0.62333)
#   Closest End S804 Coordinates: (0.87817, 0.78829, 0.62439)
#   Distance: 0.00251
# Unit 81:
#   Start S811 Coordinates: (0.87667, 0.71, 0.87667)
#   Closest End S812 Coordinates: (0.87134, 0.71314, 0.88172)
#   Distance: 0.00799
# Unit 82:
#   Start S821 Coordinates: (0.04333, 0.12333, 0.12333)
#   Closest End S822 Coordinates: (0.04816, 0.12436, 0.12473)
#   Distance: 0.00513
# Unit 83:
#   Start S831 Coordinates: (0.12333, 0.12333, 0.37667)
#   Closest End S833 Coordinates: (0.12682, 0.11796, 0.37738)
#   Distance: 0.00644
# Unit 84:
#   Start S841 Coordinates: (0.12333, 0.12333, 0.71)
#   Closest End S841 Coordinates: (0.12858, 0.11661, 0.71154)
#   Distance: 0.00867
# Unit 85:
#   Start S851 Coordinates: (0.12333, 0.37667, 0.12333)
#   Closest End S851 Coordinates: (0.12269, 0.37488, 0.11993)
#   Distance: 0.00390
# Unit 86:
#   Start S861 Coordinates: (0.04333, 0.37667, 0.37667)
#   Closest End S862 Coordinates: (0.04106, 0.38483, 0.37384)
#   Distance: 0.00893
# Unit 87:
#   Start S871 Coordinates: (0.12333, 0.37667, 0.79)
#   Closest End S873 Coordinates: (0.10952, 0.35834, 0.77338)
#   Distance: 0.02834
# Unit 88:
#   Start S881 Coordinates: (0.12333, 0.71, 0.12333)
#   Closest End S883 Coordinates: (0.12418, 0.70937, 0.11959)
#   Distance: 0.00389
# Unit 89:
#   Start S891 Coordinates: (0.12333, 0.79, 0.37667)
#   Closest End S894 Coordinates: (0.12356, 0.79057, 0.37965)
#   Distance: 0.00304
# Unit 90:
#   Start S901 Coordinates: (0.12333, 0.71, 0.79)
#   Closest End S901 Coordinates: (0.12397, 0.71706, 0.79356)
#   Distance: 0.00793
# Unit 91:
#   Start S911 Coordinates: (0.37667, 0.12333, 0.12333)
#   Closest End S913 Coordinates: (0.38256, 0.12793, 0.12183)
#   Distance: 0.00762
# Unit 92:
#   Start S921 Coordinates: (0.37667, 0.04333, 0.37667)
#   Closest End S921 Coordinates: (0.38344, 0.03833, 0.37788)
#   Distance: 0.00850
# Unit 93:
#   Start S931 Coordinates: (0.37667, 0.12333, 0.79)
#   Closest End S932 Coordinates: (0.37767, 0.12546, 0.78673)
#   Distance: 0.00403
# Unit 94:
#   Start S941 Coordinates: (0.37667, 0.45667, 0.12333)
#   Closest End S941 Coordinates: (0.37937, 0.4524, 0.12779)
#   Distance: 0.00674
# Unit 95:
#   Start S951 Coordinates: (0.37667, 0.37667, 0.37667)
#   Closest End S954 Coordinates: (0.37247, 0.42217, 0.36508)
#   Distance: 0.04714
# Unit 96:
#   Start S961 Coordinates: (0.37667, 0.37667, 0.71)
#   Closest End S963 Coordinates: (0.37593, 0.38065, 0.70892)
#   Distance: 0.00419
# Unit 97:
#   Start S971 Coordinates: (0.37667, 0.79, 0.12333)
#   Closest End S974 Coordinates: (0.37567, 0.78843, 0.12175)
#   Distance: 0.00244
# Unit 98:
#   Start S981 Coordinates: (0.37667, 0.71, 0.37667)
#   Closest End S982 Coordinates: (0.38345, 0.71224, 0.37079)
#   Distance: 0.00925
# Unit 99:
#   Start S991 Coordinates: (0.37667, 0.79, 0.79)
#   Closest End S994 Coordinates: (0.37211, 0.78399, 0.78869)
#   Distance: 0.00766
# Unit 100:
#   Start S1001 Coordinates: (0.71, 0.12333, 0.12333)
#   Closest End S1001 Coordinates: (0.71079, 0.12418, 0.12112)
#   Distance: 0.00250
# Unit 101:
#   Start S1011 Coordinates: (0.79, 0.12333, 0.37667)
#   Closest End S1011 Coordinates: (0.78624, 0.1246, 0.37645)
#   Distance: 0.00397
# Unit 102:
#   Start S1021 Coordinates: (0.71, 0.12333, 0.79)
#   Closest End S1022 Coordinates: (0.70645, 0.12217, 0.78506)
#   Distance: 0.00619
# Unit 103:
#   Start S1031 Coordinates: (0.79, 0.37667, 0.12333)
#   Closest End S1033 Coordinates: (0.79103, 0.378, 0.12149)
#   Distance: 0.00249
# Unit 104:
#   Start S1041 Coordinates: (0.71, 0.37667, 0.37667)
#   Closest End S1044 Coordinates: (0.72784, 0.35987, 0.38638)
#   Distance: 0.02636
# Unit 105:
#   Start S1051 Coordinates: (0.79, 0.37667, 0.79)
#   Closest End S1051 Coordinates: (0.78851, 0.37642, 0.78913)
#   Distance: 0.00174
# Unit 106:
#   Start S1061 Coordinates: (0.71, 0.79, 0.12333)
#   Closest End S1064 Coordinates: (0.71965, 0.79223, 0.12726)
#   Distance: 0.01066
# Unit 107:
#   Start S1071 Coordinates: (0.79, 0.79, 0.37667)
#   Closest End S1074 Coordinates: (0.78784, 0.79161, 0.37832)
#   Distance: 0.00316
# Unit 108:
#   Start S1081 Coordinates: (0.71, 0.79, 0.79)
#   Closest End S1083 Coordinates: (0.70645, 0.78693, 0.78705)
#   Distance: 0.00554

# %%
# Dictionary to store rotation information
rotation_data = {}

# Calculate theta and phi for each thiophosphate unit
for unit, data in closest_sulfur_pairs.items():
    # Vector from P to starting S1
    start_p_coords = start_coordinates[unit]['P']
    start_s_coords = data['start_sulfur']
    start_vector = np.array([start_s_coords[0] - start_p_coords[0], 
                             start_s_coords[1] - start_p_coords[1], 
                             start_s_coords[2] - start_p_coords[2]])
    
    # Vector from P to ending Sx
    end_p_coords=end_coordinates[unit]['P']
    end_s_coords = data['end_sulfur_coords']
    end_vector = np.array([end_s_coords[0] - end_p_coords[0], 
                           end_s_coords[1] - end_p_coords[1], 
                           end_s_coords[2] - end_p_coords[2]])
    
    # Convert vectors to spherical coordinates
    start_r, start_theta, start_phi = cartesian_to_spherical(*start_vector)
    end_r, end_theta, end_phi = cartesian_to_spherical(*end_vector)
    
    # Store the rotation data
    rotation_data[unit] = {
        'start_theta': start_theta, 'start_phi': start_phi,  # Reference (0, 0)
        'end_theta': end_theta, 
        'end_phi': end_phi,
        'rotation_theta': end_theta-start_theta,  # Since start_theta is 0
        'rotation_phi': end_phi-start_phi  # Since start_phi is 0
    }

# Example: Print the rotational data for each thiophosphate unit
for unit, data in rotation_data.items():
    print(f"Unit {unit}:")
    print(f"  Start θ: {data['start_theta']}°, Start φ: {data['start_phi']}°")
    print(f"  End θ: {data['end_theta']}°, End φ: {data['end_phi']}°")
    print(f"  Rotation θ: {data['rotation_theta']}°, Rotation φ: {data['rotation_phi']}°")
# Out:
# Unit 1:
#   Start θ: 54.737636079599916°, Start φ: -45.00000000000002°
#   End θ: 54.76297504220758°, End φ: -41.83954920361161°
#   Rotation θ: 0.025338962607662552°, Rotation φ: 3.1604507963884103°
# Unit 2:
#   Start θ: 125.2623639204001°, Start φ: 45.0°
#   End θ: 125.25509798914368°, End φ: 48.62038114673799°
#   Rotation θ: -0.0072659312564269385°, Rotation φ: 3.6203811467379907°
# Unit 3:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 124.16479792123113°, End φ: 51.99401099961597°
#   Rotation θ: -1.0995917615235555°, Rotation φ: 6.994010999615973°
# Unit 4:
#   Start θ: 54.73662324273851°, Start φ: 135.00214867230594°
#   End θ: 61.40365619078592°, End φ: 128.03622365675693°
#   Rotation θ: 6.667032948047407°, Rotation φ: -6.965925015549004°
# Unit 5:
#   Start θ: 125.26337675726151°, Start φ: 44.997851327694114°
#   End θ: 124.56733491310698°, End φ: 42.25583429195896°
#   Rotation θ: -0.6960418441545357°, Rotation φ: -2.7420170357351523°
# Unit 6:
#   Start θ: 125.26540254493958°, Start φ: 44.997851327694114°
#   End θ: 129.2489394169091°, End φ: 48.74871535371379°
#   Rotation θ: 3.983536871969534°, Rotation φ: 3.750864026019677°
# Unit 7:
#   Start θ: 54.7366232427385°, Start φ: -44.997851327694114°
#   End θ: 53.30198824038176°, End φ: -40.844659796814774°
#   Rotation θ: -1.4346350023567425°, Rotation φ: 4.15319153087934°
# Unit 8:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230594°
#   End θ: 131.04173553680755°, End φ: -125.69197368642725°
#   Rotation θ: 5.778358779546039°, Rotation φ: 9.310174985878689°
# Unit 9:
#   Start θ: 54.73459745506044°, Start φ: -44.997851327694114°
#   End θ: 56.30425103257911°, End φ: -50.981683222554146°
#   Rotation θ: 1.5696535775186717°, Rotation φ: -5.983831894860032°
# Unit 10:
#   Start θ: 54.73662324273851°, Start φ: -45.00214867230591°
#   End θ: 50.797510424774735°, End φ: -38.82075579058895°
#   Rotation θ: -3.9391128179637747°, Rotation φ: 6.18139288171696°
# Unit 11:
#   Start θ: 125.26337675726151°, Start φ: 45.00214867230589°
#   End θ: 131.90459015547083°, End φ: 52.19931705011508°
#   Rotation θ: 6.641213398209317°, Rotation φ: 7.197168377809184°
# Unit 12:
#   Start θ: 125.26540254493958°, Start φ: 45.00214867230589°
#   End θ: 128.38529911328354°, End φ: 45.31093367294932°
#   Rotation θ: 3.119896568343961°, Rotation φ: 0.3087850006434252°
# Unit 13:
#   Start θ: 54.737636155562235°, Start φ: 135.0042971834554°
#   End θ: 55.03160351858154°, End φ: 124.14817360127736°
#   Rotation θ: 0.2939673630193056°, Rotation φ: -10.856123582178043°
# Unit 14:
#   Start θ: 125.26438968275463°, Start φ: 45.0°
#   End θ: 123.01023231498804°, End φ: 48.9942021976468°
#   Rotation θ: -2.254157367766581°, Rotation φ: 3.9942021976468°
# Unit 15:
#   Start θ: 125.2664154957558°, Start φ: 45.0°
#   End θ: 122.85929540617498°, End φ: 46.705696701462884°
#   Rotation θ: -2.4071200895808147°, Rotation φ: 1.7056967014628839°
# Unit 16:
#   Start θ: 54.735610317245396°, Start φ: -45.0°
#   End θ: 56.147443687651574°, End φ: -45.55111042644154°
#   Rotation θ: 1.4118333704061783°, Rotation φ: -0.5511104264415394°
# Unit 17:
#   Start θ: 125.26236384443777°, Start φ: 45.00429718345539°
#   End θ: 87.4013949305388°, End φ: 50.12439178853546°
#   Rotation θ: -37.86096891389897°, Rotation φ: 5.1200946050800695°
# Unit 18:
#   Start θ: 54.733584504244206°, Start φ: -45.0°
#   End θ: 56.00732273510371°, End φ: -51.61129039509505°
#   Rotation θ: 1.2737382308595073°, Rotation φ: -6.611290395095047°
# Unit 19:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769412°
#   End θ: 47.54518828686444°, End φ: 138.31719761674412°
#   Rotation θ: -7.191434955874065°, Rotation φ: 3.319346289050003°
# Unit 20:
#   Start θ: 125.26337675726151°, Start φ: -134.9978513276941°
#   End θ: 85.31491752517744°, End φ: -117.76994728606029°
#   Rotation θ: -39.948459232084076°, Rotation φ: 17.227904041633806°
# Unit 21:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769412°
#   End θ: 45.19083257762144°, End φ: 161.482524905139°
#   Rotation θ: -9.543764877438996°, Rotation φ: 26.48467357744488°
# Unit 22:
#   Start θ: 54.735610317245396°, Start φ: 135.0°
#   End θ: 46.82938281497079°, End φ: 119.32695341854051°
#   Rotation θ: -7.906227502274604°, Rotation φ: -15.673046581459488°
# Unit 23:
#   Start θ: 125.26236384443777°, Start φ: -134.99570281654462°
#   End θ: 126.09740269687772°, End φ: -137.16580079042222°
#   Rotation θ: 0.8350388524399506°, Rotation φ: -2.1700979738776027°
# Unit 24:
#   Start θ: 54.733584504244206°, Start φ: 135.0°
#   End θ: 52.14200576228665°, End φ: 139.3004279565006°
#   Rotation θ: -2.591578741957555°, Rotation φ: 4.300427956500613°
# Unit 25:
#   Start θ: 54.737636155562235°, Start φ: -44.995702816544615°
#   End θ: 62.618531755315814°, End φ: -43.02922338029558°
#   Rotation θ: 7.880895599753579°, Rotation φ: 1.9664794362490312°
# Unit 26:
#   Start θ: 125.26438968275463°, Start φ: -135.0°
#   End θ: 115.77220184899681°, End φ: -136.24249169312048°
#   Rotation θ: -9.49218783375781°, Rotation φ: -1.2424916931204848°
# Unit 27:
#   Start θ: 125.2664154957558°, Start φ: -135.0°
#   End θ: 70.08662794431537°, End φ: -122.79218137674528°
#   Rotation θ: -55.17978755144043°, Rotation φ: 12.207818623254724°
# Unit 28:
#   Start θ: 54.73459745506047°, Start φ: -45.002148672305964°
#   End θ: 57.25562552838378°, End φ: -46.187893327672505°
#   Rotation θ: 2.521028073323315°, Rotation φ: -1.1857446553665412°
# Unit 29:
#   Start θ: 54.73662324273844°, Start φ: -45.002148672305964°
#   End θ: 51.850141685784926°, End φ: -53.15362103238743°
#   Rotation θ: -2.8864815569535125°, Rotation φ: -8.151472360081463°
# Unit 30:
#   Start θ: 125.26337675726158°, Start φ: 45.002148672305935°
#   End θ: 122.47718363991747°, End φ: 43.336041080007895°
#   Rotation θ: -2.786193117344112°, Rotation φ: -1.6661075922980402°
# Unit 31:
#   Start θ: 125.2664154957558°, Start φ: 45.00000000000005°
#   End θ: 121.49336271941311°, End φ: 44.33744900350663°
#   Rotation θ: -3.7730527763426807°, Rotation φ: -0.6625509964934224°
# Unit 32:
#   Start θ: 125.26844120745872°, Start φ: 45.00000000000005°
#   End θ: 123.47772176645373°, End φ: 47.26781346576317°
#   Rotation θ: -1.7907194410049954°, Rotation φ: 2.267813465763119°
# Unit 33:
#   Start θ: 125.26438968275468°, Start φ: 45.00000000000005°
#   End θ: 115.36454208463029°, End φ: 48.08748770676574°
#   Rotation θ: -9.899847598124396°, Rotation φ: 3.0874877067656925°
# Unit 34:
#   Start θ: 54.73358450424422°, Start φ: -45.00000000000005°
#   End θ: 32.90034461426933°, End φ: -52.36533705559747°
#   Rotation θ: -21.83323988997489°, Rotation φ: -7.365337055597422°
# Unit 35:
#   Start θ: 54.735610317245325°, Start φ: -45.00000000000005°
#   End θ: 47.383463542177964°, End φ: -51.84149026433011°
#   Rotation θ: -7.352146775067361°, Rotation φ: -6.841490264330062°
# Unit 36:
#   Start θ: 54.731558792541286°, Start φ: -45.00000000000005°
#   End θ: 48.41801916192159°, End φ: -48.40663281877794°
#   Rotation θ: -6.313539630619694°, Rotation φ: -3.4066328187778936°
# Unit 37:
#   Start θ: 54.73459745506047°, Start φ: 134.99785132769406°
#   End θ: 59.684514457898565°, End φ: 144.28910741304938°
#   Rotation θ: 4.949917002838099°, Rotation φ: 9.291256085355315°
# Unit 38:
#   Start θ: 54.73662324273844°, Start φ: 134.99785132769406°
#   End θ: 54.63489398187968°, End φ: 132.46863321004273°
#   Rotation θ: -0.101729260858761°, Rotation φ: -2.5292181176513395°
# Unit 39:
#   Start θ: 125.26337675726155°, Start φ: -134.99785132769406°
#   End θ: 131.805257614571°, End φ: -139.95177403709897°
#   Rotation θ: 6.541880857309437°, Rotation φ: -4.953922709404907°
# Unit 40:
#   Start θ: 54.73358450424422°, Start φ: 134.99999999999997°
#   End θ: 56.925083022696334°, End φ: 139.2833149266088°
#   Rotation θ: 2.1914985184521143°, Rotation φ: 4.283314926608824°
# Unit 41:
#   Start θ: 54.735610317245325°, Start φ: 134.99999999999997°
#   End θ: 48.82113782664244°, End φ: 148.8120062383933°
#   Rotation θ: -5.914472490602883°, Rotation φ: 13.812006238393337°
# Unit 42:
#   Start θ: 54.731558792541286°, Start φ: 134.99999999999997°
#   End θ: 67.24727394912235°, End φ: 146.31498902501872°
#   Rotation θ: 12.51571515658106°, Rotation φ: 11.314989025018747°
# Unit 43:
#   Start θ: 125.2664154957558°, Start φ: -134.99999999999997°
#   End θ: 128.7143853961801°, End φ: -129.98635345673745°
#   Rotation θ: 3.4479699004242974°, Rotation φ: 5.013646543262524°
# Unit 44:
#   Start θ: 125.26844120745872°, Start φ: -134.99999999999997°
#   End θ: 130.89681162887763°, End φ: -132.7659678081889°
#   Rotation θ: 5.628370421418907°, Rotation φ: 2.2340321918110817°
# Unit 45:
#   Start θ: 125.26438968275468°, Start φ: -134.99999999999997°
#   End θ: 125.61547099285332°, End φ: -135.76779792356928°
#   Rotation θ: 0.3510813100986354°, Rotation φ: -0.7677979235693044°
# Unit 46:
#   Start θ: 54.73561031724537°, Start φ: 135.00000000000006°
#   End θ: 61.65877086179923°, End φ: 135.16211919813296°
#   Rotation θ: 6.923160544553866°, Rotation φ: 0.1621191981328991°
# Unit 47:
#   Start θ: 54.73763607959988°, Start φ: 135.00000000000006°
#   End θ: 54.7951128264812°, End φ: 131.30884821513848°
#   Rotation θ: 0.05747674688132065°, Rotation φ: -3.6911517848615745°
# Unit 48:
#   Start θ: 125.26236392040013°, Start φ: 44.999999999999964°
#   End θ: 125.11587445465732°, End φ: 40.14642536989463°
#   Rotation θ: -0.14648946574281752°, Rotation φ: -4.853574630105335°
# Unit 49:
#   Start θ: 54.734597455060495°, Start φ: 135.00214867230594°
#   End θ: 60.46263703494712°, End φ: 129.06573711033087°
#   Rotation θ: 5.728039579886627°, Rotation φ: -5.9364115619750635°
# Unit 50:
#   Start θ: 54.73662324273847°, Start φ: 135.00214867230594°
#   End θ: 57.66848898187569°, End φ: 138.26968433017794°
#   Rotation θ: 2.9318657391372227°, Rotation φ: 3.2675356578720027°
# Unit 51:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769408°
#   End θ: 108.05649673479732°, End φ: 42.31358690880109°
#   Rotation θ: -17.206880022464205°, Rotation φ: -2.6842644188929867°
# Unit 52:
#   Start θ: 54.734597455060495°, Start φ: -44.99785132769408°
#   End θ: 47.04507180832177°, End φ: -49.46855236423228°
#   Rotation θ: -7.689525646738723°, Rotation φ: -4.470701036538202°
# Unit 53:
#   Start θ: 54.73662324273847°, Start φ: -44.99785132769408°
#   End θ: 48.69884891911556°, End φ: -47.21081889625139°
#   Rotation θ: -6.037774323622905°, Rotation φ: -2.2129675685573105°
# Unit 54:
#   Start θ: 125.26337675726153°, Start φ: -135.00214867230594°
#   End θ: 127.67773107043098°, End φ: -130.76277200573165°
#   Rotation θ: 2.4143543131694543°, Rotation φ: 4.239376666574287°
# Unit 55:
#   Start θ: 54.73459745506047°, Start φ: 135.00214867230596°
#   End θ: 56.68614233108757°, End φ: 133.29061092464738°
#   Rotation θ: 1.9515448760271°, Rotation φ: -1.711537747658582°
# Unit 56:
#   Start θ: 54.73662324273844°, Start φ: 135.00214867230596°
#   End θ: 54.24365778740045°, End φ: 131.3527601384049°
#   Rotation θ: -0.49296545533798763°, Rotation φ: -3.6493885339010603°
# Unit 57:
#   Start θ: 125.26337675726158°, Start φ: 44.997851327694065°
#   End θ: 134.2704990137915°, End φ: 47.327815089041145°
#   Rotation θ: 9.007122256529911°, Rotation φ: 2.3299637613470807°
# Unit 58:
#   Start θ: 54.73459745506047°, Start φ: -44.99785132769408°
#   End θ: 60.88822033664806°, End φ: -44.61172162190576°
#   Rotation θ: 6.153622881587594°, Rotation φ: 0.3861297057883206°
# Unit 59:
#   Start θ: 54.73662324273844°, Start φ: -44.99785132769408°
#   End θ: 58.30172046492758°, End φ: -47.995140839935665°
#   Rotation θ: 3.565097222189138°, Rotation φ: -2.9972895122415864°
# Unit 60:
#   Start θ: 125.26337675726155°, Start φ: -135.00214867230594°
#   End θ: 114.99234876141936°, End φ: -164.76768688278426°
#   Rotation θ: -10.27102799584219°, Rotation φ: -29.765538210478326°
# Unit 61:
#   Start θ: 54.73561031724537°, Start φ: -45.00000000000004°
#   End θ: 63.662870356048714°, End φ: -45.604349434460616°
#   Rotation θ: 8.927260038803347°, Rotation φ: -0.6043494344605733°
# Unit 62:
#   Start θ: 54.73763607959988°, Start φ: -45.00000000000004°
#   End θ: 58.68738282620796°, End φ: -39.12444160829073°
#   Rotation θ: 3.949746746608078°, Rotation φ: 5.875558391709312°
# Unit 63:
#   Start θ: 125.26236392040013°, Start φ: 45.00000000000004°
#   End θ: 136.5513300889244°, End φ: 55.24059880659292°
#   Rotation θ: 11.288966168524269°, Rotation φ: 10.240598806592878°
# Unit 64:
#   Start θ: 125.2664154957558°, Start φ: 44.99999999999995°
#   End θ: 137.42282604931086°, End φ: 75.83704288791353°
#   Rotation θ: 12.156410553555062°, Rotation φ: 30.837042887913576°
# Unit 65:
#   Start θ: 125.26844120745872°, Start φ: 44.99999999999995°
#   End θ: 121.79930825629518°, End φ: 47.8022558703016°
#   Rotation θ: -3.4691329511635445°, Rotation φ: 2.80225587030165°
# Unit 66:
#   Start θ: 125.26438968275468°, Start φ: 44.99999999999995°
#   End θ: 109.0577777456024°, End φ: 63.303545847805324°
#   Rotation θ: -16.20661193715229°, Rotation φ: 18.303545847805374°
# Unit 67:
#   Start θ: 54.73358450424422°, Start φ: -44.999999999999964°
#   End θ: 54.688264313547386°, End φ: -34.393784972135286°
#   Rotation θ: -0.04532019069683457°, Rotation φ: 10.606215027864678°
# Unit 68:
#   Start θ: 54.735610317245325°, Start φ: -44.999999999999964°
#   End θ: 51.090364781451505°, End φ: -41.165576124776265°
#   Rotation θ: -3.645245535793819°, Rotation φ: 3.834423875223699°
# Unit 69:
#   Start θ: 54.731558792541286°, Start φ: -44.999999999999964°
#   End θ: 54.44899061178406°, End φ: -43.039183217153095°
#   Rotation θ: -0.2825681807572238°, Rotation φ: 1.9608167828468694°
# Unit 70:
#   Start θ: 54.734597455060495°, Start φ: -45.00214867230593°
#   End θ: 60.20219802254419°, End φ: -41.39029791929105°
#   Rotation θ: 5.467600567483693°, Rotation φ: 3.6118507530148776°
# Unit 71:
#   Start θ: 54.73662324273847°, Start φ: -45.00214867230593°
#   End θ: 57.11433257027447°, End φ: -38.55805912143737°
#   Rotation θ: 2.377709327536003°, Rotation φ: 6.444089550868561°
# Unit 72:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230593°
#   End θ: 131.8866961035389°, End φ: 55.05243748664995°
#   Rotation θ: 6.62331934627737°, Rotation φ: 10.050288814344022°
# Unit 73:
#   Start θ: 54.73358450424422°, Start φ: 135.00000000000006°
#   End θ: 53.000951477580756°, End φ: 144.16709309903237°
#   Rotation θ: -1.7326330266634642°, Rotation φ: 9.167093099032314°
# Unit 74:
#   Start θ: 54.735610317245325°, Start φ: 135.00000000000006°
#   End θ: 43.96543408006731°, End φ: 162.36247841485007°
#   Rotation θ: -10.770176237178013°, Rotation φ: 27.362478414850017°
# Unit 75:
#   Start θ: 125.26236384443783°, Start φ: 44.995702816544565°
#   End θ: 124.22586168094287°, End φ: 54.05644592716016°
#   Rotation θ: -1.0365021634949585°, Rotation φ: 9.060743110615597°
# Unit 76:
#   Start θ: 125.2664154957558°, Start φ: -135.00000000000006°
#   End θ: 102.23813122291085°, End φ: -135.48719726696498°
#   Rotation θ: -23.028284272844942°, Rotation φ: -0.4871972669649267°
# Unit 77:
#   Start θ: 125.26844120745872°, Start φ: -135.00000000000006°
#   End θ: 116.40997463353835°, End φ: -136.90074045117908°
#   Rotation θ: -8.858466573920367°, Rotation φ: -1.9007404511790185°
# Unit 78:
#   Start θ: 125.26438968275468°, Start φ: -135.00000000000006°
#   End θ: 105.83766514514024°, End φ: -124.97123697029775°
#   Rotation θ: -19.426724537614447°, Rotation φ: 10.028763029702304°
# Unit 79:
#   Start θ: 54.734597455060495°, Start φ: 134.99785132769406°
#   End θ: 52.51024117811928°, End φ: 126.12096199773214°
#   Rotation θ: -2.224356276941215°, Rotation φ: -8.876889329961926°
# Unit 80:
#   Start θ: 54.73662324273847°, Start φ: 134.99785132769406°
#   End θ: 52.90400107461566°, End φ: 135.15668815865092°
#   Rotation θ: -1.8326221681228105°, Rotation φ: 0.15883683095685797°
# Unit 81:
#   Start θ: 125.26337675726153°, Start φ: -134.99785132769406°
#   End θ: 120.88802765736996°, End φ: -140.883783364236°
#   Rotation θ: -4.375349099891565°, Rotation φ: -5.885932036541931°
# Unit 82:
#   Start θ: 54.737636155562214°, Start φ: 135.00429718345544°
#   End θ: 52.544626869140124°, End φ: 130.60244463154692°
#   Rotation θ: -2.1930092864220896°, Rotation φ: -4.401852551908519°
# Unit 83:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 125.25036245732163°, End φ: 38.52943349973896°
#   Rotation θ: -0.014027225433054014°, Rotation φ: -6.470566500261043°
# Unit 84:
#   Start θ: 125.26641549575585°, Start φ: 45.0°
#   End θ: 124.3995009445506°, End φ: 36.33335194258708°
#   Rotation θ: -0.8669145512052552°, Rotation φ: -8.666648057412921°
# Unit 85:
#   Start θ: 54.735610317245346°, Start φ: -45.000000000000014°
#   End θ: 57.48053108338477°, End φ: -46.7151836381749°
#   Rotation θ: 2.7449207661394226°, Rotation φ: -1.715183638174885°
# Unit 86:
#   Start θ: 125.2623638444378°, Start φ: -135.00429718345544°
#   End θ: 128.984392295225°, End φ: -143.01100699003058°
#   Rotation θ: 3.7220284507872066°, Rotation φ: -8.006709806575145°
# Unit 87:
#   Start θ: 54.73358450424416°, Start φ: -45.000000000000014°
#   End θ: 69.91475079486123°, End φ: -65.82005869576267°
#   Rotation θ: 15.181166290617071°, Rotation φ: -20.820058695762654°
# Unit 88:
#   Start θ: 54.736623242738496°, Start φ: -45.00214867230598°
#   End θ: 57.81586220148903°, End φ: -44.84529895849815°
#   Rotation θ: 3.079238958750537°, Rotation φ: 0.15684971380782997°
# Unit 89:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230598°
#   End θ: 122.94090147971295°, End φ: 45.24109467892939°
#   Rotation θ: -2.322475277548577°, Rotation φ: 0.23894600662341503°
# Unit 90:
#   Start θ: 54.73459745506044°, Start φ: -45.00214867230598°
#   End θ: 50.21653717062031°, End φ: -39.02585584175871°
#   Rotation θ: -4.518060284440125°, Rotation φ: 5.976292830547266°
# Unit 91:
#   Start θ: 54.735610317245346°, Start φ: 135.00000000000003°
#   End θ: 55.56227160360166°, End φ: 127.40869435147327°
#   Rotation θ: 0.8266612863563125°, Rotation φ: -7.591305648526756°
# Unit 92:
#   Start θ: 125.2623638444378°, Start φ: -134.99570281654456°
#   End θ: 124.73848922592857°, End φ: -126.44380795932523°
#   Rotation θ: -0.5238746185092253°, Rotation φ: 8.551894857219338°
# Unit 93:
#   Start θ: 54.73358450424416°, Start φ: 135.00000000000003°
#   End θ: 57.38965074957109°, End φ: 132.7906213047402°
#   Rotation θ: 2.656066245326926°, Rotation φ: -2.2093786952598293°
# Unit 94:
#   Start θ: 54.73763615556222°, Start φ: 134.99570281654456°
#   End θ: 49.27939833016012°, End φ: 136.2315557957982°
#   Rotation θ: -5.458237825402101°, Rotation φ: 1.2358529792536217°
# Unit 95:
#   Start θ: 125.26438968275465°, Start φ: -135.0°
#   End θ: 139.19389943138222°, End φ: 172.90689441333095°
#   Rotation θ: 13.929509748627567°, Rotation φ: 307.906894413331°
# Unit 96:
#   Start θ: 125.26641549575585°, Start φ: -135.0°
#   End θ: 127.0682866405903°, End φ: -138.51870772630514°
#   Rotation θ: 1.8018711448344504°, Rotation φ: -3.518707726305138°
# Unit 97:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769404°
#   End θ: 55.6398906805129°, End φ: 136.85318898603992°
#   Rotation θ: 0.9032674377743959°, Rotation φ: 1.8553376583458885°
# Unit 98:
#   Start θ: 125.26337675726151°, Start φ: -134.99785132769404°
#   End θ: 132.37276447419052°, End φ: -131.34025108500592°
#   Rotation θ: 7.109387716929007°, Rotation φ: 3.657600242688119°
# Unit 99:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769404°
#   End θ: 55.380654926484986°, End φ: 142.66391094612607°
#   Rotation θ: 0.6460574714245482°, Rotation φ: 7.66605961843203°
# Unit 100:
#   Start θ: 54.736623242738496°, Start φ: 135.00214867230596°
#   End θ: 56.28091452395865°, End φ: 133.82648090818904°
#   Rotation θ: 1.5442912812201541°, Rotation φ: -1.1756677641169233°
# Unit 101:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769403°
#   End θ: 126.21517535777761°, End φ: 48.712994758115215°
#   Rotation θ: 0.951798600516085°, Rotation φ: 3.715143430421186°
# Unit 102:
#   Start θ: 54.73459745506044°, Start φ: 135.00214867230596°
#   End θ: 59.00173746506809°, End φ: 138.27187423757107°
#   Rotation θ: 4.267140010007651°, Rotation φ: 3.269725565265105°
# Unit 103:
#   Start θ: 54.7366232427385°, Start φ: -44.99785132769403°
#   End θ: 55.90897769183633°, End φ: -43.30390790360676°
#   Rotation θ: 1.1723544490978242°, Rotation φ: 1.6939434240872657°
# Unit 104:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230596°
#   End θ: 116.41837309947972°, End φ: -111.31278773494276°
#   Rotation θ: -8.845003657781788°, Rotation φ: 23.689360937363205°
# Unit 105:
#   Start θ: 54.73459745506044°, Start φ: -44.99785132769403°
#   End θ: 54.9140158306954°, End φ: -46.265597277701154°
#   Rotation θ: 0.17941837563495966°, Rotation φ: -1.267745950007125°
# Unit 106:
#   Start θ: 54.737636079599945°, Start φ: 135.0°
#   End θ: 49.811206240088325°, End φ: 125.70417525197824°
#   Rotation θ: -4.92642983951162°, Rotation φ: -9.295824748021758°
# Unit 107:
#   Start θ: 125.26236392040008°, Start φ: 45.0°
#   End θ: 124.28868864803563°, End φ: 47.716717269328356°
#   Rotation θ: -0.9736752723644457°, Rotation φ: 2.716717269328356°
# Unit 108:
#   Start θ: 54.735610317245346°, Start φ: 135.0°
#   End θ: 57.02207697966839°, End φ: 139.70236154513233°
#   Rotation θ: 2.286466662423045°, Rotation φ: 4.702361545132334°

# %%
df = pd.DataFrame({
    r'PS$_4$$^{3-}$ unit': list(rotation_data.keys()),
    r'$\theta$ ($^\circ$)': [data['rotation_theta'] for data in rotation_data.values()],
    r'$\phi$ ($^\circ$)': [data['rotation_phi'] for data in rotation_data.values()],
    r'Displacement of S (\AA)': [data['distance']*lattice_param for data in closest_sulfur_pairs.values()]
})

display(df)

readytosave=True
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    df.to_csv(f"{saveloc}/{cleaned_matname} displacements.csv")
# Out:
#      PS$_4$$^{3-}$ unit  $\theta$ ($^\circ$)  $\phi$ ($^\circ$)  \
# 0                     1             0.025339           3.160451
# 1                     2            -0.007266           3.620381
# 2                     3            -1.099592           6.994011
# 3                     4             6.667033          -6.965925
# 4                     5            -0.696042          -2.742017
# ..                  ...                  ...                ...
# 103                 104            -8.845004          23.689361
# 104                 105             0.179418          -1.267746
# 105                 106            -4.926430          -9.295825
# 106                 107            -0.973675           2.716717
# 107                 108             2.286467           4.702362
#
#      Displacement of S (\AA)
# 0                   0.098763
# 1                   0.111481
# 2                   0.212964
# 3                   0.321522
# 4                   0.091139
# ..                       ...
# 103                 0.789957
# 104                 0.052249
# 105                 0.319339
# 106                 0.094677
# 107                 0.166133
#
# [108 rows x 4 columns]

# %%
import numpy as np

# Initialize sums for theta, phi rotations, and distance
total_theta_rotation = 0
total_phi_rotation = 0
total_distance = 0

# Initialize sums for squared differences
sum_squared_diff_theta = 0
sum_squared_diff_phi = 0
sum_squared_diff_distance = 0

# Count the number of units
num_units = len(rotation_data)

# Collect all theta, phi, and distance values
theta_values = []
phi_values = []
distance_values = []

# Sum up the rotations and collect values for all units
for unit, data in rotation_data.items():
    total_theta_rotation += data['rotation_theta']
    total_phi_rotation += data['rotation_phi']
    theta_values.append(data['rotation_theta'])
    phi_values.append(data['rotation_phi'])

for unit, data in closest_sulfur_pairs.items():
    total_distance += data['distance']
    distance_values.append(data['distance'])

# Calculate the average theta, phi rotations, and distance
average_theta_rotation = total_theta_rotation / num_units
average_phi_rotation = total_phi_rotation / num_units
average_distance = total_distance / num_units

# Calculate the squared differences from the mean for each unit
for unit, data in rotation_data.items():
    sum_squared_diff_theta += (data['rotation_theta'] - average_theta_rotation) ** 2
    sum_squared_diff_phi += (data['rotation_phi'] - average_phi_rotation) ** 2

for unit, data in closest_sulfur_pairs.items():
    sum_squared_diff_distance += (data['distance'] - average_distance) ** 2

# Calculate the variances using `num_units - 1` for the denominator
variance_theta = sum_squared_diff_theta / (num_units - 1)
variance_phi = sum_squared_diff_phi / (num_units - 1)
variance_distance = sum_squared_diff_distance / (num_units - 1)

# Calculate the standard deviations
std_dev_theta = variance_theta ** 0.5
std_dev_phi = variance_phi ** 0.5
std_dev_distance = variance_distance ** 0.5

# Convert average distance and standard deviation to angstroms
average_distance_angstrom = average_distance * lattice_param
std_dev_distance_angstrom = std_dev_distance * lattice_param

# Calculate the medians for theta, phi, and distance
median_theta_rotation = np.median(theta_values)
median_phi_rotation = np.median(phi_values)
median_distance = np.median(distance_values)
median_distance_angstrom = median_distance * lattice_param

# Print the average, median rotations, and their standard deviations
print(f"Average θ rotation: {average_theta_rotation}°, Standard Deviation: {std_dev_theta}°")
print(f"Median θ rotation: {median_theta_rotation}°")
print(f"Average φ rotation: {average_phi_rotation}°, Standard Deviation: {std_dev_phi}°")
print(f"Median φ rotation: {median_phi_rotation}°")
print(f"Average Displacement: {average_distance_angstrom} angstroms, Standard Deviation: {std_dev_distance_angstrom} angstroms")
print(f"Median Displacement: {median_distance_angstrom} angstroms")
# Out:
# Average θ rotation: -1.6988075304855612°, Standard Deviation: 9.971040621441698°
# Median θ rotation: -0.010646578344740476°
# Average φ rotation: 4.397004847533855°, Standard Deviation: 30.711463893814205°
# Median φ rotation: 1.6998200627750748°
# Average Displacement: 0.320764971669505 angstroms, Standard Deviation: 0.32559150777161777 angstroms
# Median Displacement: 0.22841195430741013 angstroms

# %%
#generate a table for average displacements

attributes=[r'$\theta$ ($^\circ$)', r'$\phi$ ($^\circ$)', r'Displacement of S (\AA)']
averages=[average_theta_rotation, average_phi_rotation,average_distance_angstrom]
medians=[median_theta_rotation,median_phi_rotation,median_distance_angstrom]
std_devs=[std_dev_theta,std_dev_phi,std_dev_distance_angstrom]

collated={
    r'Attribute':attributes,
    r'Average':averages,
    r'Median':medians,
    r'Standard Deviation':std_devs,
}

collated=pd.DataFrame(collated)

display(collated)

readytosave=False
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    collated.to_csv(f"{saveloc}/{cleaned_matname} dispersities.csv")
# Out:
#                  Attribute   Average    Median  Standard Deviation
# 0      $\theta$ ($^\circ$) -1.698808 -0.010647            9.971041
# 1        $\phi$ ($^\circ$)  4.397005  1.699820           30.711464
# 2  Displacement of S (\AA)  0.320765  0.228412            0.325592

# %%
# Initialize variables to store the maximum distance and the corresponding unit
max_distance = 0
max_unit = None
max_sulfur_pair = None

# Iterate through the closest_sulfur_pairs dictionary
for unit, data in closest_sulfur_pairs.items():
    # Extract the distance value
    distance = data['distance']
    
    # Check if this is the maximum distance encountered so far
    if distance > max_distance:
        max_distance = distance
        max_unit = unit
        max_sulfur_pair = (data['start_sulfur'], data['closest_end_sulfur'])

# Print the results
print(f"Maximum distance: {max_distance}")
print(f"Unit number: {max_unit}")
print(f"Starting sulfur: {max_sulfur_pair[0]}")
print(f"Ending sulfur: {max_sulfur_pair[1]}")
print(f"Maximum θ:{rotation_data[max_unit]['rotation_theta']}°")
print(f"Maximum φ:{rotation_data[max_unit]['rotation_phi']}°")
# Out:
# Maximum distance: 0.06492837361277425
# Unit number: 27
# Starting sulfur: (0.87667, 0.87667, 0.71)
# Ending sulfur: 4
# Maximum θ:-55.17978755144043°
# Maximum φ:12.207818623254724°

# %%
readytosave=True

fig, axs=plt.subplots(1,1, figsize=(6,6))

max_theta = rotation_data[max_unit]['rotation_theta']
max_phi = rotation_data[max_unit]['rotation_phi']

if abs(max_phi)>abs(max_theta):
    lim=abs(max_phi)*1.05
else:
    lim=abs(max_theta)*1.05
    
lim=85


for unit, data in rotation_data.items():
    if unit!=max_unit:
        axs.scatter(data['rotation_phi'],data['rotation_theta'],edgecolor=datacolor,facecolors='white',linewidths=2, marker='o')
    else:
        axs.scatter(rotation_data[max_unit]['rotation_phi'],rotation_data[max_unit]['rotation_theta'], edgecolor='#cc0000',facecolors='white',linewidths=2, marker='o')
#axs.scatter(0,0,color="orange",edgecolor='black',marker='^',s=150)

axs.text(-lim+lim*0.1,lim*.45,fr'Max displacement:' '\n' fr'{max_distance*lattice_param:.2f} \AA' '\n' fr'$\theta$: {max_theta:.2f}$^\circ$' '\n' fr'$\phi$: {max_phi:.2f}$^\circ$',bbox=dict(
        facecolor='none',     # Transparent fill color for the box
       edgecolor="#cc0000",  # Match the box edge color with the marker
        linewidth=2,        # Box edge width
       boxstyle='round,pad=0.3'  # Rounded box with padding
  ))
    
axs.set_xlim([-lim,lim])
axs.set_ylim([-lim,lim])

axs.xaxis.set_major_locator(ticker.MaxNLocator(8))
axs.yaxis.set_major_locator(ticker.MaxNLocator(8))
axs.xaxis.set_minor_locator(AutoMinorLocator(2))
axs.yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(which='major', direction='in', length=6)
plt.tick_params(which='minor', direction='in', length=4)

axs.set_xlabel(r'$\phi$ ($^{\circ}$)')
axs.set_ylabel(r'$\theta$ ($^{\circ}$)')
axs.set_title(material)

plt.tight_layout()

if readytosave==True:
    png=''.join((saveloc,'/',cleaned_matname,'rotation summary','.png'))
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    plt.savefig(png,dpi=800,format='png')


plt.show()

# %%
#import necessary packages
import pandas as pd
from datetime import datetime, timedelta, timezone
import os
from PyEIS import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import csv
import glob
import statistics
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress
import math
from colour import Color
import re
import matplotlib.ticker as ticker
from matplotlib.ticker import FormatStrFormatter
from matplotlib.legend_handler import HandlerLineCollection, HandlerTuple
from matplotlib.ticker import AutoMinorLocator

from matplotlib.pyplot import rc

allSized=20
rc('text',usetex=True)
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']},size=allSized)
rc('text.latex', preamble=r'\usepackage{sfmath}')
plt.rc('font',   size=     allSized,**{'family':"sans-serif"})     # controls default text sizes
plt.rc('axes',   titlesize=allSized)     # fontsize of the axes title
plt.rc('axes',   labelsize=allSized)    # fontsize of the x and y labels
plt.rc('xtick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('ytick',  labelsize=allSized)    # fontsize of the tick labels
plt.rc('legend', fontsize= allSized)    # legend fontsize
plt.rc('figure', titlesize=allSized)  # fontsize of the figure title

# %%
# Function to calculate Euclidean distance between two points
def calculate_distance(coord1, coord2):
    return math.sqrt((coord1[0] - coord2[0])**2 + (coord1[1] - coord2[1])**2 + (coord1[2] - coord2[2])**2)


def cartesian_to_spherical(x, y, z):
    r = np.sqrt(x**2 + y**2 + z**2)
    theta = np.arccos(z / r) if r != 0 else 0  # θ: angle from z-axis
    phi = np.arctan2(y, x)  # φ: angle from x-axis in the xy-plane
    return r, np.degrees(theta), np.degrees(phi)

# %%
start_file="C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Python Processed Str/Consolidated strs/3by3/Li6PS5Br_3by3_P1_dualLi_limited rotation_beqpdfgui_site disorder_Lioccref.txt"

end_file="C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/PDF SA_ Joint Refinement working copy/MW LPSI/Joint Refinement/7_15_2024_I_MW_3by3_Joint_Lioccref.inp"

material=r'MW Li$_6$PS$_5$I'

datacolor='#ce5cff'
lattice_param=30.447804

#filter non-alphanumeric and space characters from the material name so that it's easier to deal with from a file management perspective
cleaned_matname = filter(lambda x: x.isalnum() or x.isspace(), material)

# filter returns a generator, so we need to re-join the string
cleaned_matname = "".join(cleaned_matname)

print(cleaned_matname)

saveloc='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Beamline Data/CLS_12_2023/Joint Refinements/Paper Plotting/PS4 Rotations and cifs/rotation plots'
# Out:
# MW Li6PS5I

# %%
start_coordinates={}

# Regular expression pattern to match the lines with start_coordinates
pattern = re.compile(r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.-]+)\s+y\s+([\d.-]+)\s+z\s+([\d.-]+)")

# Open the file and process each line
with open(start_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in start_coordinates:
                    start_coordinates[unit_number] = {'P': None, 'S': {}}
                start_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)

# Example: Accessing the start_coordinates for a specific thiophosphate unit
example_unit = 1
print(f"start_coordinates for P{example_unit}: {start_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"start_coordinates for S{example_unit}{i}: {start_coordinates[example_unit]['S'][i]}")
# Out:
# start_coordinates for P1: (0.25, 0.25, 0.083333)
# start_coordinates for S11: (0.29, 0.21, 0.12333)
# start_coordinates for S12: (0.21, 0.29, 0.12333)
# start_coordinates for S13: (0.29, 0.29, 0.04333)
# start_coordinates for S14: (0.21, 0.21, 0.04333)

# %%
# Initialize the dictionary to store the end_coordinates
end_coordinates = {}

# Regular expression pattern to match the lines with end_coordinates, accounting for '_0.00000' or any number
pattern = re.compile(
    r"site\s+(P\d+|S\d{2,})\s+num_posns\s+\d+\s+x\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+\s+y\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+\s+z\s+([\d.]+)(?:`_|\s*[_])\s*[\d.]+"
)
# Open the file and process each line
with open(end_file) as file:
    for line in file:
        match = pattern.search(line)
        if match:
            site = match.group(1)
            x = float(match.group(2))
            y = float(match.group(3))
            z = float(match.group(4))
            
            # Determine whether the site is P or S
            if site.startswith('P'):
                unit_number = int(site[1:])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['P'] = (x, y, z)
            elif site.startswith('S'):
                unit_number = int(site[1:-1])
                sulfur_number = int(site[-1])
                if unit_number not in end_coordinates:
                    end_coordinates[unit_number] = {'P': None, 'S': {}}
                end_coordinates[unit_number]['S'][sulfur_number] = (x, y, z)


# Example: Accessing the end_coordinates for a specific thiophosphate unit
example_unit = 50
print(f"end_coordinates for P{example_unit}: {end_coordinates[example_unit]['P']}")
for i in range(1, 5):
    print(f"end_coordinates for S{example_unit}{i}: {end_coordinates[example_unit]['S'][i]}")
# Out:
# end_coordinates for P50: (0.75, 0.58333, 0.58333)
# end_coordinates for S501: (0.79062, 0.62283, 0.54628)
# end_coordinates for S502: (0.78725, 0.54691, 0.62656)
# end_coordinates for S503: (0.70649, 0.62192, 0.61799)
# end_coordinates for S504: (0.71565, 0.54168, 0.5425)

# %%
# Dictionary to store closest sulfur pairs
closest_sulfur_pairs = {}

# Find the closest sulfur atom for each S1 from start to end units
for unit_number, start_sulfurs in start_coordinates.items():
    if 'S' in start_sulfurs:
        start_sulfur1_coords = start_sulfurs['S'].get(1)
        if start_sulfur1_coords:
            min_distance = float('inf')
            closest_sulfur = None
            for sulfur_number, end_sulfur_coords in end_coordinates[unit_number]['S'].items():
                distance = calculate_distance(start_sulfur1_coords, end_sulfur_coords)
                if distance < min_distance:
                    min_distance = distance
                    closest_sulfur = sulfur_number
            closest_sulfur_pairs[unit_number] = {
                'start_sulfur': start_sulfur1_coords,
                'closest_end_sulfur': closest_sulfur,
                'end_sulfur_coords': end_coordinates[unit_number]['S'][closest_sulfur],
                'distance': min_distance
            }

# Example: Print out the closest sulfur atom pairs
for unit, data in closest_sulfur_pairs.items():
    print(f"Unit {unit}:")
    print(f"  Start S{unit}1 Coordinates: {data['start_sulfur']}")
    print(f"  Closest End S{unit}{data['closest_end_sulfur']} Coordinates: {data['end_sulfur_coords']}")
    print(f"  Distance: {data['distance']:.5f}")
# Out:
# Unit 1:
#   Start S11 Coordinates: (0.29, 0.21, 0.12333)
#   Closest End S14 Coordinates: (0.29045, 0.20541, 0.11434)
#   Distance: 0.01010
# Unit 2:
#   Start S21 Coordinates: (0.29, 0.29, 0.37667)
#   Closest End S21 Coordinates: (0.29083, 0.29132, 0.38186)
#   Distance: 0.00542
# Unit 3:
#   Start S31 Coordinates: (0.29, 0.29, 0.71)
#   Closest End S33 Coordinates: (0.28865, 0.29369, 0.7156)
#   Distance: 0.00684
# Unit 4:
#   Start S41 Coordinates: (0.21, 0.62333, 0.12333)
#   Closest End S42 Coordinates: (0.21145, 0.6195, 0.12567)
#   Distance: 0.00472
# Unit 5:
#   Start S51 Coordinates: (0.29, 0.62333, 0.37667)
#   Closest End S51 Coordinates: (0.29084, 0.62445, 0.38163)
#   Distance: 0.00515
# Unit 6:
#   Start S61 Coordinates: (0.29, 0.62333, 0.71)
#   Closest End S64 Coordinates: (0.27188, 0.64116, 0.72237)
#   Distance: 0.02827
# Unit 7:
#   Start S71 Coordinates: (0.29, 0.87667, 0.12333)
#   Closest End S71 Coordinates: (0.28814, 0.87355, 0.119)
#   Distance: 0.00565
# Unit 8:
#   Start S81 Coordinates: (0.21, 0.87667, 0.37667)
#   Closest End S83 Coordinates: (0.2103, 0.88308, 0.37333)
#   Distance: 0.00723
# Unit 9:
#   Start S91 Coordinates: (0.29, 0.87667, 0.79)
#   Closest End S92 Coordinates: (0.28866, 0.87381, 0.78538)
#   Distance: 0.00560
# Unit 10:
#   Start S101 Coordinates: (0.62333, 0.21, 0.12333)
#   Closest End S104 Coordinates: (0.62049, 0.20635, 0.11934)
#   Distance: 0.00611
# Unit 11:
#   Start S111 Coordinates: (0.62333, 0.29, 0.37667)
#   Closest End S112 Coordinates: (0.62372, 0.29211, 0.38233)
#   Distance: 0.00605
# Unit 12:
#   Start S121 Coordinates: (0.62333, 0.29, 0.71)
#   Closest End S124 Coordinates: (0.62101, 0.29056, 0.71101)
#   Distance: 0.00259
# Unit 13:
#   Start S131 Coordinates: (0.54333, 0.62333, 0.12333)
#   Closest End S132 Coordinates: (0.54543, 0.61974, 0.12602)
#   Distance: 0.00495
# Unit 14:
#   Start S141 Coordinates: (0.62333, 0.62333, 0.37667)
#   Closest End S144 Coordinates: (0.62376, 0.625, 0.38185)
#   Distance: 0.00546
# Unit 15:
#   Start S151 Coordinates: (0.62333, 0.62333, 0.71)
#   Closest End S154 Coordinates: (0.62306, 0.62668, 0.71646)
#   Distance: 0.00728
# Unit 16:
#   Start S161 Coordinates: (0.62333, 0.87667, 0.12333)
#   Closest End S161 Coordinates: (0.62169, 0.87372, 0.11893)
#   Distance: 0.00555
# Unit 17:
#   Start S171 Coordinates: (0.62333, 0.95667, 0.37667)
#   Closest End S171 Coordinates: (0.62304, 0.95991, 0.38296)
#   Distance: 0.00708
# Unit 18:
#   Start S181 Coordinates: (0.62333, 0.87667, 0.79)
#   Closest End S181 Coordinates: (0.62239, 0.87353, 0.78459)
#   Distance: 0.00633
# Unit 19:
#   Start S191 Coordinates: (0.87667, 0.29, 0.12333)
#   Closest End S194 Coordinates: (0.87721, 0.28515, 0.12564)
#   Distance: 0.00540
# Unit 20:
#   Start S201 Coordinates: (0.87667, 0.21, 0.37667)
#   Closest End S201 Coordinates: (0.87763, 0.21652, 0.37264)
#   Distance: 0.00772
# Unit 21:
#   Start S211 Coordinates: (0.87667, 0.29, 0.79)
#   Closest End S213 Coordinates: (0.8762, 0.28307, 0.79303)
#   Distance: 0.00758
# Unit 22:
#   Start S221 Coordinates: (0.87667, 0.62333, 0.12333)
#   Closest End S224 Coordinates: (0.87771, 0.62007, 0.12475)
#   Distance: 0.00370
# Unit 23:
#   Start S231 Coordinates: (0.87667, 0.54333, 0.37667)
#   Closest End S231 Coordinates: (0.87728, 0.5498, 0.37299)
#   Distance: 0.00747
# Unit 24:
#   Start S241 Coordinates: (0.87667, 0.62333, 0.79)
#   Closest End S242 Coordinates: (0.87654, 0.61805, 0.79204)
#   Distance: 0.00566
# Unit 25:
#   Start S251 Coordinates: (0.95667, 0.87667, 0.12333)
#   Closest End S251 Coordinates: (0.95447, 0.87251, 0.11803)
#   Distance: 0.00709
# Unit 26:
#   Start S261 Coordinates: (0.87667, 0.87667, 0.37667)
#   Closest End S263 Coordinates: (0.87709, 0.88316, 0.37315)
#   Distance: 0.00740
# Unit 27:
#   Start S271 Coordinates: (0.87667, 0.87667, 0.71)
#   Closest End S271 Coordinates: (0.87082, 0.89189, 0.7068)
#   Distance: 0.01662
# Unit 28:
#   Start S281 Coordinates: (0.12333, 0.21, 0.29)
#   Closest End S282 Coordinates: (0.12167, 0.21532, 0.29371)
#   Distance: 0.00669
# Unit 29:
#   Start S291 Coordinates: (0.12333, 0.21, 0.62333)
#   Closest End S292 Coordinates: (0.12094, 0.21405, 0.62665)
#   Distance: 0.00576
# Unit 30:
#   Start S301 Coordinates: (0.12333, 0.29, 0.87667)
#   Closest End S304 Coordinates: (0.12308, 0.29065, 0.87991)
#   Distance: 0.00331
# Unit 31:
#   Start S311 Coordinates: (0.12333, 0.62333, 0.21)
#   Closest End S313 Coordinates: (0.12258, 0.62406, 0.2128)
#   Distance: 0.00299
# Unit 32:
#   Start S321 Coordinates: (0.12333, 0.62333, 0.54333)
#   Closest End S323 Coordinates: (0.11525, 0.60833, 0.52911)
#   Distance: 0.02219
# Unit 33:
#   Start S331 Coordinates: (0.12333, 0.62333, 0.87667)
#   Closest End S333 Coordinates: (0.12316, 0.62325, 0.87921)
#   Distance: 0.00255
# Unit 34:
#   Start S341 Coordinates: (0.12333, 0.87667, 0.29)
#   Closest End S341 Coordinates: (0.12197, 0.88153, 0.29307)
#   Distance: 0.00591
# Unit 35:
#   Start S351 Coordinates: (0.12333, 0.87667, 0.62333)
#   Closest End S351 Coordinates: (0.12102, 0.88051, 0.62641)
#   Distance: 0.00544
# Unit 36:
#   Start S361 Coordinates: (0.12333, 0.87667, 0.95667)
#   Closest End S362 Coordinates: (0.11996, 0.88101, 0.96105)
#   Distance: 0.00703
# Unit 37:
#   Start S371 Coordinates: (0.37667, 0.29, 0.29)
#   Closest End S372 Coordinates: (0.37174, 0.28756, 0.28397)
#   Distance: 0.00816
# Unit 38:
#   Start S381 Coordinates: (0.37667, 0.29, 0.62333)
#   Closest End S384 Coordinates: (0.37226, 0.28857, 0.61685)
#   Distance: 0.00797
# Unit 39:
#   Start S391 Coordinates: (0.37667, 0.21, 0.87667)
#   Closest End S391 Coordinates: (0.38341, 0.2077, 0.87558)
#   Distance: 0.00720
# Unit 40:
#   Start S401 Coordinates: (0.37667, 0.62333, 0.29)
#   Closest End S402 Coordinates: (0.3712, 0.61974, 0.2845)
#   Distance: 0.00855
# Unit 41:
#   Start S411 Coordinates: (0.37667, 0.62333, 0.62333)
#   Closest End S412 Coordinates: (0.37201, 0.62151, 0.61696)
#   Distance: 0.00810
# Unit 42:
#   Start S421 Coordinates: (0.37667, 0.62333, 0.95667)
#   Closest End S424 Coordinates: (0.38516, 0.61179, 0.96939)
#   Distance: 0.01916
# Unit 43:
#   Start S431 Coordinates: (0.37667, 0.87667, 0.21)
#   Closest End S431 Coordinates: (0.38465, 0.8735, 0.20884)
#   Distance: 0.00866
# Unit 44:
#   Start S441 Coordinates: (0.37667, 0.87667, 0.54333)
#   Closest End S441 Coordinates: (0.38286, 0.87525, 0.5418)
#   Distance: 0.00653
# Unit 45:
#   Start S451 Coordinates: (0.37667, 0.87667, 0.87667)
#   Closest End S452 Coordinates: (0.38383, 0.87361, 0.87604)
#   Distance: 0.00781
# Unit 46:
#   Start S461 Coordinates: (0.71, 0.29, 0.29)
#   Closest End S462 Coordinates: (0.70472, 0.28744, 0.28364)
#   Distance: 0.00865
# Unit 47:
#   Start S471 Coordinates: (0.71, 0.29, 0.62333)
#   Closest End S471 Coordinates: (0.70554, 0.28747, 0.61801)
#   Distance: 0.00739
# Unit 48:
#   Start S481 Coordinates: (0.79, 0.29, 0.87667)
#   Closest End S483 Coordinates: (0.79056, 0.28941, 0.87946)
#   Distance: 0.00291
# Unit 49:
#   Start S491 Coordinates: (0.71, 0.62333, 0.29)
#   Closest End S494 Coordinates: (0.7044, 0.62031, 0.28371)
#   Distance: 0.00895
# Unit 50:
#   Start S501 Coordinates: (0.71, 0.62333, 0.62333)
#   Closest End S503 Coordinates: (0.70649, 0.62192, 0.61799)
#   Distance: 0.00654
# Unit 51:
#   Start S511 Coordinates: (0.79, 0.62333, 0.87667)
#   Closest End S514 Coordinates: (0.79179, 0.62254, 0.88062)
#   Distance: 0.00441
# Unit 52:
#   Start S521 Coordinates: (0.79, 0.87667, 0.29)
#   Closest End S522 Coordinates: (0.78873, 0.88292, 0.29409)
#   Distance: 0.00758
# Unit 53:
#   Start S531 Coordinates: (0.79, 0.87667, 0.62333)
#   Closest End S534 Coordinates: (0.78758, 0.88143, 0.62725)
#   Distance: 0.00662
# Unit 54:
#   Start S541 Coordinates: (0.71, 0.87667, 0.87667)
#   Closest End S541 Coordinates: (0.71611, 0.87307, 0.87751)
#   Distance: 0.00714
# Unit 55:
#   Start S551 Coordinates: (0.21, 0.12333, 0.29)
#   Closest End S552 Coordinates: (0.21125, 0.12038, 0.29134)
#   Distance: 0.00347
# Unit 56:
#   Start S561 Coordinates: (0.21, 0.12333, 0.62333)
#   Closest End S563 Coordinates: (0.2123, 0.12149, 0.62464)
#   Distance: 0.00322
# Unit 57:
#   Start S571 Coordinates: (0.29, 0.12333, 0.87667)
#   Closest End S572 Coordinates: (0.28598, 0.1205, 0.873)
#   Distance: 0.00613
# Unit 58:
#   Start S581 Coordinates: (0.29, 0.37667, 0.29)
#   Closest End S582 Coordinates: (0.29538, 0.38189, 0.28624)
#   Distance: 0.00839
# Unit 59:
#   Start S591 Coordinates: (0.29, 0.37667, 0.62333)
#   Closest End S592 Coordinates: (0.29449, 0.38125, 0.62006)
#   Distance: 0.00720
# Unit 60:
#   Start S601 Coordinates: (0.21, 0.37667, 0.87667)
#   Closest End S603 Coordinates: (0.20986, 0.37437, 0.88228)
#   Distance: 0.00606
# Unit 61:
#   Start S611 Coordinates: (0.29, 0.71, 0.29)
#   Closest End S612 Coordinates: (0.29517, 0.7144, 0.28571)
#   Distance: 0.00803
# Unit 62:
#   Start S621 Coordinates: (0.29, 0.71, 0.62333)
#   Closest End S622 Coordinates: (0.29452, 0.71361, 0.61907)
#   Distance: 0.00718
# Unit 63:
#   Start S631 Coordinates: (0.29, 0.79, 0.87667)
#   Closest End S634 Coordinates: (0.28339, 0.78979, 0.87326)
#   Distance: 0.00744
# Unit 64:
#   Start S641 Coordinates: (0.62333, 0.12333, 0.21)
#   Closest End S643 Coordinates: (0.61595, 0.12437, 0.20716)
#   Distance: 0.00798
# Unit 65:
#   Start S651 Coordinates: (0.62333, 0.12333, 0.54333)
#   Closest End S651 Coordinates: (0.6162, 0.12323, 0.53962)
#   Distance: 0.00804
# Unit 66:
#   Start S661 Coordinates: (0.62333, 0.12333, 0.87667)
#   Closest End S664 Coordinates: (0.6164, 0.12275, 0.87267)
#   Distance: 0.00802
# Unit 67:
#   Start S671 Coordinates: (0.62333, 0.37667, 0.29)
#   Closest End S672 Coordinates: (0.62853, 0.38166, 0.28626)
#   Distance: 0.00812
# Unit 68:
#   Start S681 Coordinates: (0.62333, 0.37667, 0.62333)
#   Closest End S684 Coordinates: (0.63546, 0.38394, 0.61153)
#   Distance: 0.01842
# Unit 69:
#   Start S691 Coordinates: (0.62333, 0.37667, 0.95667)
#   Closest End S692 Coordinates: (0.62813, 0.38084, 0.95261)
#   Distance: 0.00754
# Unit 70:
#   Start S701 Coordinates: (0.62333, 0.71, 0.29)
#   Closest End S702 Coordinates: (0.62629, 0.71308, 0.28707)
#   Distance: 0.00518
# Unit 71:
#   Start S711 Coordinates: (0.62333, 0.71, 0.62333)
#   Closest End S714 Coordinates: (0.62839, 0.71425, 0.61904)
#   Distance: 0.00788
# Unit 72:
#   Start S721 Coordinates: (0.62333, 0.79, 0.87667)
#   Closest End S722 Coordinates: (0.61652, 0.79003, 0.87332)
#   Distance: 0.00759
# Unit 73:
#   Start S731 Coordinates: (0.87667, 0.12333, 0.29)
#   Closest End S733 Coordinates: (0.87762, 0.12015, 0.29126)
#   Distance: 0.00355
# Unit 74:
#   Start S741 Coordinates: (0.87667, 0.12333, 0.62333)
#   Closest End S743 Coordinates: (0.88691, 0.13507, 0.61529)
#   Distance: 0.01753
# Unit 75:
#   Start S751 Coordinates: (0.95667, 0.12333, 0.87667)
#   Closest End S754 Coordinates: (0.94979, 0.12381, 0.87368)
#   Distance: 0.00752
# Unit 76:
#   Start S761 Coordinates: (0.87667, 0.37667, 0.21)
#   Closest End S763 Coordinates: (0.87752, 0.37399, 0.21494)
#   Distance: 0.00568
# Unit 77:
#   Start S771 Coordinates: (0.87667, 0.37667, 0.54333)
#   Closest End S773 Coordinates: (0.87618, 0.37524, 0.5483)
#   Distance: 0.00519
# Unit 78:
#   Start S781 Coordinates: (0.87667, 0.37667, 0.87667)
#   Closest End S783 Coordinates: (0.87874, 0.37639, 0.87765)
#   Distance: 0.00231
# Unit 79:
#   Start S791 Coordinates: (0.87667, 0.79, 0.29)
#   Closest End S792 Coordinates: (0.87839, 0.78764, 0.29125)
#   Distance: 0.00318
# Unit 80:
#   Start S801 Coordinates: (0.87667, 0.79, 0.62333)
#   Closest End S802 Coordinates: (0.87985, 0.78772, 0.62581)
#   Distance: 0.00463
# Unit 81:
#   Start S811 Coordinates: (0.87667, 0.71, 0.87667)
#   Closest End S814 Coordinates: (0.87672, 0.70753, 0.88226)
#   Distance: 0.00611
# Unit 82:
#   Start S821 Coordinates: (0.04333, 0.12333, 0.12333)
#   Closest End S824 Coordinates: (0.0489, 0.12859, 0.12006)
#   Distance: 0.00833
# Unit 83:
#   Start S831 Coordinates: (0.12333, 0.12333, 0.37667)
#   Closest End S833 Coordinates: (0.12616, 0.11611, 0.37574)
#   Distance: 0.00781
# Unit 84:
#   Start S841 Coordinates: (0.12333, 0.12333, 0.71)
#   Closest End S842 Coordinates: (0.12945, 0.13084, 0.73589)
#   Distance: 0.02764
# Unit 85:
#   Start S851 Coordinates: (0.12333, 0.37667, 0.12333)
#   Closest End S854 Coordinates: (0.11802, 0.37556, 0.12444)
#   Distance: 0.00554
# Unit 86:
#   Start S861 Coordinates: (0.04333, 0.37667, 0.37667)
#   Closest End S862 Coordinates: (0.03822, 0.38322, 0.37886)
#   Distance: 0.00859
# Unit 87:
#   Start S871 Coordinates: (0.12333, 0.37667, 0.79)
#   Closest End S871 Coordinates: (0.11971, 0.37675, 0.79081)
#   Distance: 0.00371
# Unit 88:
#   Start S881 Coordinates: (0.12333, 0.71, 0.12333)
#   Closest End S881 Coordinates: (0.13043, 0.72552, 0.12535)
#   Distance: 0.01719
# Unit 89:
#   Start S891 Coordinates: (0.12333, 0.79, 0.37667)
#   Closest End S891 Coordinates: (0.12667, 0.78241, 0.37599)
#   Distance: 0.00832
# Unit 90:
#   Start S901 Coordinates: (0.12333, 0.71, 0.79)
#   Closest End S902 Coordinates: (0.12, 0.71086, 0.79131)
#   Distance: 0.00368
# Unit 91:
#   Start S911 Coordinates: (0.37667, 0.12333, 0.12333)
#   Closest End S914 Coordinates: (0.38197, 0.12785, 0.12072)
#   Distance: 0.00744
# Unit 92:
#   Start S921 Coordinates: (0.37667, 0.04333, 0.37667)
#   Closest End S923 Coordinates: (0.37341, 0.04813, 0.37828)
#   Distance: 0.00602
# Unit 93:
#   Start S931 Coordinates: (0.37667, 0.12333, 0.79)
#   Closest End S931 Coordinates: (0.3807, 0.12672, 0.78755)
#   Distance: 0.00581
# Unit 94:
#   Start S941 Coordinates: (0.37667, 0.45667, 0.12333)
#   Closest End S942 Coordinates: (0.38317, 0.4613, 0.12169)
#   Distance: 0.00815
# Unit 95:
#   Start S951 Coordinates: (0.37667, 0.37667, 0.37667)
#   Closest End S951 Coordinates: (0.374, 0.37904, 0.37992)
#   Distance: 0.00483
# Unit 96:
#   Start S961 Coordinates: (0.37667, 0.37667, 0.71)
#   Closest End S964 Coordinates: (0.37357, 0.37862, 0.71421)
#   Distance: 0.00558
# Unit 97:
#   Start S971 Coordinates: (0.37667, 0.79, 0.12333)
#   Closest End S972 Coordinates: (0.38248, 0.7943, 0.12147)
#   Distance: 0.00746
# Unit 98:
#   Start S981 Coordinates: (0.37667, 0.71, 0.37667)
#   Closest End S984 Coordinates: (0.37346, 0.71422, 0.37874)
#   Distance: 0.00569
# Unit 99:
#   Start S991 Coordinates: (0.37667, 0.79, 0.79)
#   Closest End S991 Coordinates: (0.3803, 0.79368, 0.78681)
#   Distance: 0.00607
# Unit 100:
#   Start S1001 Coordinates: (0.71, 0.12333, 0.12333)
#   Closest End S1002 Coordinates: (0.71596, 0.12934, 0.11953)
#   Distance: 0.00928
# Unit 101:
#   Start S1011 Coordinates: (0.79, 0.12333, 0.37667)
#   Closest End S1014 Coordinates: (0.79194, 0.11618, 0.37486)
#   Distance: 0.00763
# Unit 102:
#   Start S1021 Coordinates: (0.71, 0.12333, 0.79)
#   Closest End S1022 Coordinates: (0.71435, 0.12773, 0.78666)
#   Distance: 0.00703
# Unit 103:
#   Start S1031 Coordinates: (0.79, 0.37667, 0.12333)
#   Closest End S1034 Coordinates: (0.7783, 0.38475, 0.13593)
#   Distance: 0.01900
# Unit 104:
#   Start S1041 Coordinates: (0.71, 0.37667, 0.37667)
#   Closest End S1043 Coordinates: (0.70693, 0.38018, 0.37926)
#   Distance: 0.00533
# Unit 105:
#   Start S1051 Coordinates: (0.79, 0.37667, 0.79)
#   Closest End S1051 Coordinates: (0.78474, 0.37619, 0.79173)
#   Distance: 0.00556
# Unit 106:
#   Start S1061 Coordinates: (0.71, 0.79, 0.12333)
#   Closest End S1062 Coordinates: (0.71587, 0.79595, 0.11948)
#   Distance: 0.00920
# Unit 107:
#   Start S1071 Coordinates: (0.79, 0.79, 0.37667)
#   Closest End S1071 Coordinates: (0.79271, 0.78235, 0.37528)
#   Distance: 0.00823
# Unit 108:
#   Start S1081 Coordinates: (0.71, 0.79, 0.79)
#   Closest End S1081 Coordinates: (0.7154, 0.79471, 0.78724)
#   Distance: 0.00768

# %%
# Dictionary to store rotation information
rotation_data = {}

# Calculate theta and phi for each thiophosphate unit
for unit, data in closest_sulfur_pairs.items():
    # Vector from P to starting S1
    start_p_coords = start_coordinates[unit]['P']
    start_s_coords = data['start_sulfur']
    start_vector = np.array([start_s_coords[0] - start_p_coords[0], 
                             start_s_coords[1] - start_p_coords[1], 
                             start_s_coords[2] - start_p_coords[2]])
    
    # Vector from P to ending Sx
    end_p_coords=end_coordinates[unit]['P']
    end_s_coords = data['end_sulfur_coords']
    end_vector = np.array([end_s_coords[0] - end_p_coords[0], 
                           end_s_coords[1] - end_p_coords[1], 
                           end_s_coords[2] - end_p_coords[2]])
    
    # Convert vectors to spherical coordinates
    start_r, start_theta, start_phi = cartesian_to_spherical(*start_vector)
    end_r, end_theta, end_phi = cartesian_to_spherical(*end_vector)
    
    # Store the rotation data
    rotation_data[unit] = {
        'start_theta': start_theta, 'start_phi': start_phi,  # Reference (0, 0)
        'end_theta': end_theta, 
        'end_phi': end_phi,
        'rotation_theta': end_theta-start_theta,  # Since start_theta is 0
        'rotation_phi': end_phi-start_phi  # Since start_phi is 0
    }

# Example: Print the rotational data for each thiophosphate unit
for unit, data in rotation_data.items():
    print(f"Unit {unit}:")
    print(f"  Start θ: {data['start_theta']}°, Start φ: {data['start_phi']}°")
    print(f"  End θ: {data['end_theta']}°, End φ: {data['end_phi']}°")
    print(f"  Rotation θ: {data['rotation_theta']}°, Rotation φ: {data['rotation_phi']}°")
# Out:
# Unit 1:
#   Start θ: 54.737636079599916°, Start φ: -45.00000000000002°
#   End θ: 62.747652715433354°, End φ: -47.78712839979333°
#   Rotation θ: 8.010016635833438°, Rotation φ: -2.7871283997933105°
# Unit 2:
#   Start θ: 125.2623639204001°, Start φ: 45.0°
#   End θ: 120.93189815043841°, End φ: 45.341748010006064°
#   Rotation θ: -4.330465769961691°, Rotation φ: 0.34174801000606436°
# Unit 3:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 120.52897285560476°, End φ: 48.50268277230977°
#   Rotation θ: -4.735416827149919°, Rotation φ: 3.502682772309768°
# Unit 4:
#   Start θ: 54.73662324273851°, Start φ: 135.00214867230594°
#   End θ: 51.306799652474254°, End φ: 136.82438258246856°
#   Rotation θ: -3.429823590264256°, Rotation φ: 1.8222339101626233°
# Unit 5:
#   Start θ: 125.26337675726151°, Start φ: 44.997851327694114°
#   End θ: 121.157535687931°, End φ: 45.195738846407984°
#   Rotation θ: -4.105841069330509°, Rotation φ: 0.19788751871386978°
# Unit 6:
#   Start θ: 125.26540254493958°, Start φ: 44.997851327694114°
#   End θ: 114.07819303157696°, End φ: 69.27584657377177°
#   Rotation θ: -11.187209513362617°, Rotation φ: 24.27799524607766°
# Unit 7:
#   Start θ: 54.7366232427385°, Start φ: -44.997851327694114°
#   End θ: 58.216709124281046°, End φ: -48.50697224725111°
#   Rotation θ: 3.480085881542543°, Rotation φ: -3.509120919556999°
# Unit 8:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230594°
#   End θ: 129.8079359493357°, End φ: -139.76558262658222°
#   Rotation θ: 4.544559192074189°, Rotation φ: -4.76343395427628°
# Unit 9:
#   Start θ: 54.73459745506044°, Start φ: -44.997851327694114°
#   End θ: 58.49331675556125°, End φ: -47.94933378610546°
#   Rotation θ: 3.7587193005008146°, Rotation φ: -2.9514824584113484°
# Unit 10:
#   Start θ: 54.73662324273851°, Start φ: -45.00214867230591°
#   End θ: 57.86421082000298°, End φ: -49.59167446044291°
#   Rotation θ: 3.127587577264471°, Rotation φ: -4.589525788137003°
# Unit 11:
#   Start θ: 125.26337675726151°, Start φ: 45.00214867230589°
#   End θ: 120.47799397839006°, End φ: 46.19435716495575°
#   Rotation θ: -4.785382778871451°, Rotation φ: 1.1922084926498542°
# Unit 12:
#   Start θ: 125.26540254493958°, Start φ: 45.00214867230589°
#   End θ: 125.1562711733535°, End φ: 47.108095312357044°
#   Rotation θ: -0.10913137158607356°, Rotation φ: 2.105946640051151°
# Unit 13:
#   Start θ: 54.737636155562235°, Start φ: 135.0042971834554°
#   End θ: 50.9136800706932°, End φ: 136.14869160529534°
#   Rotation θ: -3.823956084869039°, Rotation φ: 1.1443944218399338°
# Unit 14:
#   Start θ: 125.26438968275463°, Start φ: 45.0°
#   End θ: 120.95210703419625°, End φ: 45.86530286258026°
#   Rotation θ: -4.31228264855838°, Rotation φ: 0.8653028625802577°
# Unit 15:
#   Start θ: 125.2664154957558°, Start φ: 45.0°
#   End θ: 119.69987751922874°, End φ: 47.49493994511902°
#   Rotation θ: -5.566537976527059°, Rotation φ: 2.4949399451190217°
# Unit 16:
#   Start θ: 54.735610317245396°, Start φ: -45.0°
#   End θ: 58.275575061858234°, End φ: -48.230953253590826°
#   Rotation θ: 3.5399647446128384°, Rotation φ: -3.230953253590826°
# Unit 17:
#   Start θ: 125.26236384443777°, Start φ: 45.00429718345539°
#   End θ: 119.86451515547202°, End φ: 47.43679494428517°
#   Rotation θ: -5.397848688965752°, Rotation φ: 2.4324977608297758°
# Unit 18:
#   Start θ: 54.733584504244206°, Start φ: -45.0°
#   End θ: 59.273872772192654°, End φ: -47.84154612571062°
#   Rotation θ: 4.540288267948448°, Rotation φ: -2.8415461257106216°
# Unit 19:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769412°
#   End θ: 51.317821475432304°, End φ: 138.3061341743073°
#   Rotation θ: -3.4188017673061992°, Rotation φ: 3.3082828466131673°
# Unit 20:
#   Start θ: 125.26337675726151°, Start φ: -134.9978513276941°
#   End θ: 130.56740055541903°, End φ: -139.38420498930716°
#   Rotation θ: 5.304023798157516°, Rotation φ: -4.386353661613072°
# Unit 21:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769412°
#   End θ: 50.53427697338715°, End φ: 140.746075171973°
#   Rotation θ: -4.2003204816732875°, Rotation φ: 5.7482238442788685°
# Unit 22:
#   Start θ: 54.735610317245396°, Start φ: 135.0°
#   End θ: 52.27918360447071°, End φ: 136.6797910828041°
#   Rotation θ: -2.456426712774686°, Rotation φ: 1.679791082804087°
# Unit 23:
#   Start θ: 125.26236384443777°, Start φ: -134.99570281654462°
#   End θ: 130.17806621274303°, End φ: -139.59453215030783°
#   Rotation θ: 4.915702368305261°, Rotation φ: -4.598829333763206°
# Unit 24:
#   Start θ: 54.733584504244206°, Start φ: 135.0°
#   End θ: 51.61247504265047°, End φ: 139.13402914825312°
#   Rotation θ: -3.1211094615937327°, Rotation φ: 4.13402914825312°
# Unit 25:
#   Start θ: 54.737636155562235°, Start φ: -44.995702816544615°
#   End θ: 59.164857273707°, End φ: -49.43719333365317°
#   Rotation θ: 4.4272211181447645°, Rotation φ: -4.441490517108555°
# Unit 26:
#   Start θ: 125.26438968275463°, Start φ: -135.0°
#   End θ: 130.00258971810052°, End φ: -139.74742253826543°
#   Rotation θ: 4.738200035345898°, Rotation φ: -4.747422538265425°
# Unit 27:
#   Start θ: 125.2664154957558°, Start φ: -135.0°
#   End θ: 129.65501579713091°, End φ: -151.61063989711835°
#   Rotation θ: 4.388600301375121°, Rotation φ: -16.610639897118347°
# Unit 28:
#   Start θ: 54.73459745506047°, Start φ: -45.002148672305964°
#   End θ: 49.78577309852378°, End φ: -42.13055049956862°
#   Rotation θ: -4.94882435653669°, Rotation φ: 2.871598172737343°
# Unit 29:
#   Start θ: 54.73662324273844°, Start φ: -45.002148672305964°
#   End θ: 50.21827692413669°, End φ: -43.70724777367093°
#   Rotation θ: -4.5183463186017505°, Rotation φ: 1.294900898635035°
# Unit 30:
#   Start θ: 125.26337675726158°, Start φ: 45.002148672305935°
#   End θ: 122.88499696999747°, End φ: 45.64134387894256°
#   Rotation θ: -2.378379787264109°, Rotation φ: 0.6391952066366215°
# Unit 31:
#   Start θ: 125.2664154957558°, Start φ: 45.00000000000005°
#   End θ: 123.33136612224533°, End φ: 46.0601159892248°
#   Rotation θ: -1.9350493735104664°, Rotation φ: 1.060115989224748°
# Unit 32:
#   Start θ: 125.26844120745872°, Start φ: 45.00000000000005°
#   End θ: 143.211434102903°, End φ: 38.06833200438517°
#   Rotation θ: 17.94299289544429°, Rotation φ: -6.93166799561488°
# Unit 33:
#   Start θ: 125.26438968275468°, Start φ: 45.00000000000005°
#   End θ: 123.59533099713987°, End φ: 45.0646597864209°
#   Rotation θ: -1.6690586856148144°, Rotation φ: 0.06465978642084735°
# Unit 34:
#   Start θ: 54.73358450424422°, Start φ: -45.00000000000005°
#   End θ: 50.48972793977233°, End φ: -42.284020015630695°
#   Rotation θ: -4.243856564471891°, Rotation φ: 2.715979984369355°
# Unit 35:
#   Start θ: 54.735610317245325°, Start φ: -45.00000000000005°
#   End θ: 50.484294240072934°, End φ: -43.81313468305133°
#   Rotation θ: -4.25131607717239°, Rotation φ: 1.1868653169487189°
# Unit 36:
#   Start θ: 54.731558792541286°, Start φ: -45.00000000000005°
#   End θ: 49.03775772784986°, End φ: -44.231241236765506°
#   Rotation θ: -5.693801064691428°, Rotation φ: 0.7687587632345441°
# Unit 37:
#   Start θ: 54.73459745506047°, Start φ: 134.99785132769406°
#   End θ: 59.88313035209752°, End φ: 140.10548760995428°
#   Rotation θ: 5.14853289703705°, Rotation φ: 5.107636282260216°
# Unit 38:
#   Start θ: 54.73662324273844°, Start φ: 134.99785132769406°
#   End θ: 60.322659031983115°, End φ: 139.02574762929686°
#   Rotation θ: 5.586035789244676°, Rotation φ: 4.027896301602794°
# Unit 39:
#   Start θ: 125.26337675726155°, Start φ: -134.99785132769406°
#   End θ: 127.36580624102821°, End φ: -128.17755993206214°
#   Rotation θ: 2.102429483766656°, Rotation φ: 6.820291395631926°
# Unit 40:
#   Start θ: 54.73358450424422°, Start φ: 134.99999999999997°
#   End θ: 59.36335731718934°, End φ: 141.31407768965437°
#   Rotation θ: 4.62977281294512°, Rotation φ: 6.314077689654397°
# Unit 41:
#   Start θ: 54.735610317245325°, Start φ: 134.99999999999997°
#   End θ: 60.214457504643434°, End φ: 139.47274453412584°
#   Rotation θ: 5.4788471873981095°, Rotation φ: 4.472744534125866°
# Unit 42:
#   Start θ: 54.731558792541286°, Start φ: 134.99999999999997°
#   End θ: 38.847516015941316°, End φ: 137.91148388922858°
#   Rotation θ: -15.88404277659997°, Rotation φ: 2.911483889228606°
# Unit 43:
#   Start θ: 125.2664154957558°, Start φ: -134.99999999999997°
#   End θ: 127.44435406008279°, End φ: -126.56502233356288°
#   Rotation θ: 2.1779385643269933°, Rotation φ: 8.434977666437092°
# Unit 44:
#   Start θ: 125.26844120745872°, Start φ: -134.99999999999997°
#   End θ: 127.8378847807467°, End φ: -129.22381053346461°
#   Rotation θ: 2.569443573287984°, Rotation φ: 5.776189466535357°
# Unit 45:
#   Start θ: 125.26438968275468°, Start φ: -134.99999999999997°
#   End θ: 126.87983911371485°, End φ: -127.33119953847934°
#   Rotation θ: 1.6154494309601688°, Rotation φ: 7.668800461520632°
# Unit 46:
#   Start θ: 54.73561031724537°, Start φ: 135.00000000000006°
#   End θ: 60.20641149840434°, End φ: 140.41418151729735°
#   Rotation θ: 5.470801181158976°, Rotation φ: 5.414181517297294°
# Unit 47:
#   Start θ: 54.73763607959988°, Start φ: 135.00000000000006°
#   End θ: 59.185908248578755°, End φ: 139.87647977142672°
#   Rotation θ: 4.448272168978875°, Rotation φ: 4.876479771426659°
# Unit 48:
#   Start θ: 125.26236392040013°, Start φ: 44.999999999999964°
#   End θ: 123.34350961491612°, End φ: 44.17612098198462°
#   Rotation θ: -1.9188543054840181°, Rotation φ: -0.8238790180153472°
# Unit 49:
#   Start θ: 54.734597455060495°, Start φ: 135.00214867230594°
#   End θ: 60.13655691674216°, End φ: 140.95916031063933°
#   Rotation θ: 5.401959461681663°, Rotation φ: 5.957011638333398°
# Unit 50:
#   Start θ: 54.73662324273847°, Start φ: 135.00214867230594°
#   End θ: 59.20646720387397°, End φ: 138.42945809663323°
#   Rotation θ: 4.469843961135503°, Rotation φ: 3.427309424327291°
# Unit 51:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769408°
#   End θ: 122.17372267659967°, End φ: 43.17564011469567°
#   Rotation θ: -3.089654080661859°, Rotation φ: -1.8222112129984112°
# Unit 52:
#   Start θ: 54.734597455060495°, Start φ: -44.99785132769408°
#   End θ: 49.36213189988071°, End φ: -41.06946409212776°
#   Rotation θ: -5.372465555179787°, Rotation φ: 3.928387235566319°
# Unit 53:
#   Start θ: 54.73662324273847°, Start φ: -44.99785132769408°
#   End θ: 49.55187675282844°, End φ: -43.159489080033985°
#   Rotation θ: -5.184746489910026°, Rotation φ: 1.8383622476600934°
# Unit 54:
#   Start θ: 125.26337675726153°, Start φ: -135.00214867230594°
#   End θ: 125.34178825500304°, End φ: -127.85769381774045°
#   Rotation θ: 0.0784114977415129°, Rotation φ: 7.144454854565481°
# Unit 55:
#   Start θ: 54.73459745506047°, Start φ: 135.00214867230596°
#   End θ: 52.36441530486281°, End φ: 136.28478231152584°
#   Rotation θ: -2.3701821501976568°, Rotation φ: 1.2826336392198812°
# Unit 56:
#   Start θ: 54.73662324273844°, Start φ: 135.00214867230596°
#   End θ: 52.399988790266626°, End φ: 134.6525740106983°
#   Rotation θ: -2.336634452471813°, Rotation φ: -0.3495746616076758°
# Unit 57:
#   Start θ: 125.26337675726158°, Start φ: 44.997851327694065°
#   End θ: 130.16982508868324°, End φ: 45.93200224033581°
#   Rotation θ: 4.906448331421657°, Rotation φ: 0.9341509126417478°
# Unit 58:
#   Start θ: 54.73459745506047°, Start φ: -44.99785132769408°
#   End θ: 57.631748769627244°, End φ: -37.46716637284232°
#   Rotation θ: 2.897151314566777°, Rotation φ: 7.530684954851758°
# Unit 59:
#   Start θ: 54.73662324273844°, Start φ: -44.99785132769408°
#   End θ: 57.14218998851956°, End φ: -38.524487685164395°
#   Rotation θ: 2.4055667457811225°, Rotation φ: 6.473363642529684°
# Unit 60:
#   Start θ: 125.26337675726155°, Start φ: -135.00214867230594°
#   End θ: 120.52952949944684°, End φ: -133.4991439127066°
#   Rotation θ: -4.733847257814716°, Rotation φ: 1.5030047595993494°
# Unit 61:
#   Start θ: 54.73561031724537°, Start φ: -45.00000000000004°
#   End θ: 58.16350753892729°, End φ: -38.24283614753456°
#   Rotation θ: 3.427897221681924°, Rotation φ: 6.757163852465482°
# Unit 62:
#   Start θ: 54.73763607959988°, Start φ: -45.00000000000004°
#   End θ: 58.13640192181875°, End φ: -39.2620640675543°
#   Rotation θ: 3.3987658422188716°, Rotation φ: 5.737935932445744°
# Unit 63:
#   Start θ: 125.26236392040013°, Start φ: 45.00000000000004°
#   End θ: 129.88598781666448°, End φ: 49.998119356396295°
#   Rotation θ: 4.623623896264348°, Rotation φ: 4.998119356396252°
# Unit 64:
#   Start θ: 125.2664154957558°, Start φ: 44.99999999999995°
#   End θ: 129.25475018991352°, End φ: 51.521117998343236°
#   Rotation θ: 3.9883346941577287°, Rotation φ: 6.521117998343286°
# Unit 65:
#   Start θ: 125.26844120745872°, Start φ: 44.99999999999995°
#   End θ: 130.2153425763607°, End φ: 50.51797810576484°
#   Rotation θ: 4.94690136890199°, Rotation φ: 5.51797810576489°
# Unit 66:
#   Start θ: 125.26438968275468°, Start φ: 44.99999999999995°
#   End θ: 130.53458365277882°, End φ: 50.00623332963842°
#   Rotation θ: 5.270193970024138°, Rotation φ: 5.006233329638469°
# Unit 67:
#   Start θ: 54.73358450424422°, Start φ: -44.999999999999964°
#   End θ: 57.61645145137408°, End φ: -37.75984202758062°
#   Rotation θ: 2.8828669471298625°, Rotation φ: 7.240157972419347°
# Unit 68:
#   Start θ: 54.735610317245325°, Start φ: -44.999999999999964°
#   End θ: 65.38555803091847°, End φ: -32.12279849365017°
#   Rotation θ: 10.64994771367315°, Rotation φ: 12.877201506349792°
# Unit 69:
#   Start θ: 54.731558792541286°, Start φ: -44.999999999999964°
#   End θ: 57.932598293997465°, End φ: -38.65200908998806°
#   Rotation θ: 3.2010395014561794°, Rotation φ: 6.347990910011902°
# Unit 70:
#   Start θ: 54.734597455060495°, Start φ: -45.00214867230593°
#   End θ: 56.798160779476824°, End φ: -40.67589848241714°
#   Rotation θ: 2.0635633244163287°, Rotation φ: 4.326250189888789°
# Unit 71:
#   Start θ: 54.73662324273847°, Start φ: -45.00214867230593°
#   End θ: 58.166523674801674°, End φ: -38.42801285434826°
#   Rotation θ: 3.4299004320632065°, Rotation φ: 6.574135817957668°
# Unit 72:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230593°
#   End θ: 129.8165270231648°, End φ: 50.33691682542145°
#   Rotation θ: 4.553150265903284°, Rotation φ: 5.334768153115519°
# Unit 73:
#   Start θ: 54.73358450424422°, Start φ: 135.00000000000006°
#   End θ: 52.4486226690063°, End φ: 136.6835747130163°
#   Rotation θ: -2.2849618352379224°, Rotation φ: 1.6835747130162417°
# Unit 74:
#   Start θ: 54.735610317245325°, Start φ: 135.00000000000006°
#   End θ: 61.83322513025676°, End φ: 119.90680734465535°
#   Rotation θ: 7.0976148130114325°, Rotation φ: -15.093192655344708°
# Unit 75:
#   Start θ: 125.26236384443783°, Start φ: 44.995702816544565°
#   End θ: 129.41840067028002°, End φ: 50.710593137499615°
#   Rotation θ: 4.156036825842193°, Rotation φ: 5.71489032095505°
# Unit 76:
#   Start θ: 125.2664154957558°, Start φ: -135.00000000000006°
#   End θ: 121.18885556032083°, End φ: -132.52989388991432°
#   Rotation θ: -4.077559935434962°, Rotation φ: 2.4701061100857373°
# Unit 77:
#   Start θ: 125.26844120745872°, Start φ: -135.00000000000006°
#   End θ: 121.1611568528321°, End φ: -134.3425821635753°
#   Rotation θ: -4.107284354626628°, Rotation φ: 0.65741783642477°
# Unit 78:
#   Start θ: 125.26438968275468°, Start φ: -135.00000000000006°
#   End θ: 125.19346101182339°, End φ: -133.2789338605064°
#   Rotation θ: -0.07092867093129485°, Rotation φ: 1.7210661394936437°
# Unit 79:
#   Start θ: 54.734597455060495°, Start φ: 134.99785132769406°
#   End θ: 52.46260159572301°, End φ: 135.4829877543105°
#   Rotation θ: -2.271995859337487°, Rotation φ: 0.4851364266164353°
# Unit 80:
#   Start θ: 54.73662324273847°, Start φ: 134.99785132769406°
#   End θ: 51.13483264197574°, End φ: 134.30824126697817°
#   Rotation θ: -3.601790600762726°, Rotation φ: -0.6896100607158928°
# Unit 81:
#   Start θ: 125.26337675726153°, Start φ: -134.99785132769406°
#   End θ: 120.54708044722132°, End φ: -133.2487212165082°
#   Rotation θ: -4.716296310040207°, Rotation φ: 1.7491301111858775°
# Unit 82:
#   Start θ: 54.737636155562214°, Start φ: 135.00429718345544°
#   End θ: 57.142012344162545°, End φ: 127.26082398993145°
#   Rotation θ: 2.404376188600331°, Rotation φ: -7.7434731935239824°
# Unit 83:
#   Start θ: 125.26438968275468°, Start φ: 45.0°
#   End θ: 127.19422808379525°, End φ: 37.4286869453638°
#   Rotation θ: 1.9298384010405698°, Rotation φ: -7.5713130546361995°
# Unit 84:
#   Start θ: 125.26641549575585°, Start φ: 45.0°
#   End θ: 102.02967145339592°, End φ: 45.850531704478264°
#   Rotation θ: -23.23674404235993°, Rotation φ: 0.8505317044782643°
# Unit 85:
#   Start θ: 54.735610317245346°, Start φ: -45.000000000000014°
#   End θ: 52.610767735814°, End φ: -49.84120192216171°
#   Rotation θ: -2.124842581431345°, Rotation φ: -4.841201922161694°
# Unit 86:
#   Start θ: 125.2623638444378°, Start φ: -135.00429718345544°
#   End θ: 123.95115903929786°, End φ: -143.44229892484853°
#   Rotation θ: -1.311204805139937°, Rotation φ: -8.438001741393094°
# Unit 87:
#   Start θ: 54.73358450424416°, Start φ: -45.000000000000014°
#   End θ: 52.92542095130375°, End φ: -47.656378950813405°
#   Rotation θ: -1.8081635529404139°, Rotation φ: -2.656378950813391°
# Unit 88:
#   Start θ: 54.736623242738496°, Start φ: -45.00214867230598°
#   End θ: 51.6345804758497°, End φ: -27.462939833837602°
#   Rotation θ: -3.1020427668887933°, Rotation φ: 17.539208838468376°
# Unit 89:
#   Start θ: 125.26337675726153°, Start φ: 45.00214867230598°
#   End θ: 126.93181882199912°, End φ: 36.789435020092725°
#   Rotation θ: 1.6684420647375902°, Rotation φ: -8.212713652213253°
# Unit 90:
#   Start θ: 54.73459745506044°, Start φ: -45.00214867230598°
#   End θ: 52.3959111870384°, End φ: -46.86611964332293°
#   Rotation θ: -2.3386862680220375°, Rotation φ: -1.863970971016954°
# Unit 91:
#   Start θ: 54.735610317245346°, Start φ: 135.00000000000003°
#   End θ: 56.47926285642709°, End φ: 127.9337412278131°
#   Rotation θ: 1.7436525391817455°, Rotation φ: -7.066258772186927°
# Unit 92:
#   Start θ: 125.2623638444378°, Start φ: -134.99570281654456°
#   End θ: 124.5413310447092°, End φ: -140.86527821087338°
#   Rotation θ: -0.7210327997286043°, Rotation φ: -5.86957539432882°
# Unit 93:
#   Start θ: 54.73358450424416°, Start φ: 135.00000000000003°
#   End θ: 56.326704737944816°, End φ: 129.6584889490276°
#   Rotation θ: 1.5931202337006525°, Rotation φ: -5.341511050972429°
# Unit 94:
#   Start θ: 54.73763615556222°, Start φ: 134.99570281654456°
#   End θ: 55.49513953931633°, End φ: 126.8924857593123°
#   Rotation θ: 0.7575033837541056°, Rotation φ: -8.103217057232271°
# Unit 95:
#   Start θ: 125.26438968275465°, Start φ: -135.0°
#   End θ: 122.86068792615629°, End φ: -138.59143746110357°
#   Rotation θ: -2.403701756598366°, Rotation φ: -3.591437461103567°
# Unit 96:
#   Start θ: 125.26641549575585°, Start φ: -135.0°
#   End θ: 121.90282670223571°, End φ: -138.56094941788535°
#   Rotation θ: -3.3635887935201367°, Rotation φ: -3.560949417885354°
# Unit 97:
#   Start θ: 54.7366232427385°, Start φ: 134.99785132769404°
#   End θ: 55.72296931185824°, End φ: 127.66036008707947°
#   Rotation θ: 0.9863460691197403°, Rotation φ: -7.337491240614568°
# Unit 98:
#   Start θ: 125.26337675726151°, Start φ: -134.99785132769404°
#   End θ: 124.06274651031133°, End φ: -140.3735757083011°
#   Rotation θ: -1.2006302469501833°, Rotation φ: -5.375724380607068°
# Unit 99:
#   Start θ: 54.73459745506044°, Start φ: 134.99785132769404°
#   End θ: 57.07234256137915°, End φ: 129.78233941216428°
#   Rotation θ: 2.337745106318714°, Rotation φ: -5.21551191552976°
# Unit 100:
#   Start θ: 54.736623242738496°, Start φ: 135.00214867230596°
#   End θ: 57.68665615558589°, End φ: 126.49548618864051°
#   Rotation θ: 2.9500329128473908°, Rotation φ: -8.506662483665451°
# Unit 101:
#   Start θ: 125.26337675726153°, Start φ: 44.99785132769403°
#   End θ: 128.12536048203629°, End φ: 38.07024188598351°
#   Rotation θ: 2.8619837247747597°, Rotation φ: -6.927609441710516°
# Unit 102:
#   Start θ: 54.73459745506044°, Start φ: 135.00214867230596°
#   End θ: 57.225600859183835°, End φ: 128.76195366612524°
#   Rotation θ: 2.491003404123397°, Rotation φ: -6.240195006180727°
# Unit 103:
#   Start θ: 54.7366232427385°, Start φ: -44.99785132769403°
#   End θ: 39.042208375314594°, End φ: -48.44007691025627°
#   Rotation θ: -15.694414867423909°, Rotation φ: -3.4422255825622443°
# Unit 104:
#   Start θ: 125.26337675726151°, Start φ: -135.00214867230596°
#   End θ: 123.53308692049492°, End φ: -139.72788026011798°
#   Rotation θ: -1.7302898367665875°, Rotation φ: -4.725731587812021°
# Unit 105:
#   Start θ: 54.73459745506044°, Start φ: -44.99785132769403°
#   End θ: 51.96418965416382°, End φ: -49.36375470082324°
#   Rotation θ: -2.7704078008966206°, Rotation φ: -4.365903373129214°
# Unit 106:
#   Start θ: 54.737636079599945°, Start φ: 135.0°
#   End θ: 57.72486099001992°, End φ: 126.60363104613704°
#   Rotation θ: 2.9872249104199753°, Rotation φ: -8.396368953862961°
# Unit 107:
#   Start θ: 125.26236392040008°, Start φ: 45.0°
#   End θ: 127.68644110695752°, End φ: 37.141520680894395°
#   Rotation θ: 2.42407718655744°, Rotation φ: -7.858479319105605°
# Unit 108:
#   Start θ: 54.735610317245346°, Start φ: 135.0°
#   End θ: 56.62656838431612°, End φ: 127.73543107356255°
#   Rotation θ: 1.8909580670707768°, Rotation φ: -7.264568926437448°

# %%
df = pd.DataFrame({
    r'PS$_4$$^{3-}$ unit': list(rotation_data.keys()),
    r'$\theta$ ($^\circ$)': [data['rotation_theta'] for data in rotation_data.values()],
    r'$\phi$ ($^\circ$)': [data['rotation_phi'] for data in rotation_data.values()],
    r'Displacement of S (\AA)': [data['distance']*lattice_param for data in closest_sulfur_pairs.values()]
})

display(df)

readytosave=True
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    df.to_csv(f"{saveloc}/{cleaned_matname} displacements.csv")
# Out:
#      PS$_4$$^{3-}$ unit  $\theta$ ($^\circ$)  $\phi$ ($^\circ$)  \
# 0                     1             8.010017          -2.787128
# 1                     2            -4.330466           0.341748
# 2                     3            -4.735417           3.502683
# 3                     4            -3.429824           1.822234
# 4                     5            -4.105841           0.197888
# ..                  ...                  ...                ...
# 103                 104            -1.730290          -4.725732
# 104                 105            -2.770408          -4.365903
# 105                 106             2.987225          -8.396369
# 106                 107             2.424077          -7.858479
# 107                 108             1.890958          -7.264569
#
#      Displacement of S (\AA)
# 0                   0.307644
# 1                   0.165002
# 2                   0.208292
# 3                   0.143612
# 4                   0.156922
# ..                       ...
# 103                 0.162413
# 104                 0.169228
# 105                 0.280189
# 106                 0.250707
# 107                 0.233798
#
# [108 rows x 4 columns]

# %%
import numpy as np

# Initialize sums for theta, phi rotations, and distance
total_theta_rotation = 0
total_phi_rotation = 0
total_distance = 0

# Initialize sums for squared differences
sum_squared_diff_theta = 0
sum_squared_diff_phi = 0
sum_squared_diff_distance = 0

# Count the number of units
num_units = len(rotation_data)

# Collect all theta, phi, and distance values
theta_values = []
phi_values = []
distance_values = []

# Sum up the rotations and collect values for all units
for unit, data in rotation_data.items():
    total_theta_rotation += data['rotation_theta']
    total_phi_rotation += data['rotation_phi']
    theta_values.append(data['rotation_theta'])
    phi_values.append(data['rotation_phi'])

for unit, data in closest_sulfur_pairs.items():
    total_distance += data['distance']
    distance_values.append(data['distance'])

# Calculate the average theta, phi rotations, and distance
average_theta_rotation = total_theta_rotation / num_units
average_phi_rotation = total_phi_rotation / num_units
average_distance = total_distance / num_units

# Calculate the squared differences from the mean for each unit
for unit, data in rotation_data.items():
    sum_squared_diff_theta += (data['rotation_theta'] - average_theta_rotation) ** 2
    sum_squared_diff_phi += (data['rotation_phi'] - average_phi_rotation) ** 2

for unit, data in closest_sulfur_pairs.items():
    sum_squared_diff_distance += (data['distance'] - average_distance) ** 2

# Calculate the variances using `num_units - 1` for the denominator
variance_theta = sum_squared_diff_theta / (num_units - 1)
variance_phi = sum_squared_diff_phi / (num_units - 1)
variance_distance = sum_squared_diff_distance / (num_units - 1)

# Calculate the standard deviations
std_dev_theta = variance_theta ** 0.5
std_dev_phi = variance_phi ** 0.5
std_dev_distance = variance_distance ** 0.5

# Convert average distance and standard deviation to angstroms
average_distance_angstrom = average_distance * lattice_param
std_dev_distance_angstrom = std_dev_distance * lattice_param

# Calculate the medians for theta, phi, and distance
median_theta_rotation = np.median(theta_values)
median_phi_rotation = np.median(phi_values)
median_distance = np.median(distance_values)
median_distance_angstrom = median_distance * lattice_param

# Print the average, median rotations, and their standard deviations
print(f"Average θ rotation: {average_theta_rotation}°, Standard Deviation: {std_dev_theta}°")
print(f"Median θ rotation: {median_theta_rotation}°")
print(f"Average φ rotation: {average_phi_rotation}°, Standard Deviation: {std_dev_phi}°")
print(f"Median φ rotation: {median_phi_rotation}°")
print(f"Average Displacement: {average_distance_angstrom} angstroms, Standard Deviation: {std_dev_distance_angstrom} angstroms")
print(f"Median Displacement: {median_distance_angstrom} angstroms")
# Out:
# Average θ rotation: 0.05902616484220496°, Standard Deviation: 5.317715833658924°
# Median θ rotation: 1.2897331514101964°
# Average φ rotation: 0.3899994345250587°, Standard Deviation: 6.0576778209423745°
# Median φ rotation: 1.102255205532341°
# Average Displacement: 0.23163976180853765 angstroms, Standard Deviation: 0.13577271808608324 angstroms
# Median Displacement: 0.2157086487043658 angstroms

# %%
#generate a table for average displacements

attributes=[r'$\theta$ ($^\circ$)', r'$\phi$ ($^\circ$)', r'Displacement of S (\AA)']
averages=[average_theta_rotation, average_phi_rotation,average_distance_angstrom]
medians=[median_theta_rotation,median_phi_rotation,median_distance_angstrom]
std_devs=[std_dev_theta,std_dev_phi,std_dev_distance_angstrom]

collated={
    r'Attribute':attributes,
    r'Average':averages,
    r'Median':medians,
    r'Standard Deviation':std_devs,
}

collated=pd.DataFrame(collated)

display(collated)

readytosave=False
if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    collated.to_csv(f"{saveloc}/{cleaned_matname} dispersities.csv")
# Out:
#                  Attribute   Average    Median  Standard Deviation
# 0      $\theta$ ($^\circ$)  0.059026  1.289733            5.317716
# 1        $\phi$ ($^\circ$)  0.389999  1.102255            6.057678
# 2  Displacement of S (\AA)  0.231640  0.215709            0.135773

# %%
# Initialize variables to store the maximum distance and the corresponding unit
max_distance = 0
max_unit = None
max_sulfur_pair = None

# Iterate through the closest_sulfur_pairs dictionary
for unit, data in closest_sulfur_pairs.items():
    # Extract the distance value
    distance = data['distance']
    
    # Check if this is the maximum distance encountered so far
    if distance > max_distance:
        max_distance = distance
        max_unit = unit
        max_sulfur_pair = (data['start_sulfur'], data['closest_end_sulfur'])

# Print the results
print(f"Maximum distance: {max_distance}")
print(f"Unit number: {max_unit}")
print(f"Starting sulfur: {max_sulfur_pair[0]}")
print(f"Ending sulfur: {max_sulfur_pair[1]}")
print(f"Maximum θ:{rotation_data[max_unit]['rotation_theta']}°")
print(f"Maximum φ:{rotation_data[max_unit]['rotation_phi']}°")
# Out:
# Maximum distance: 0.02827119028268876
# Unit number: 6
# Starting sulfur: (0.29, 0.62333, 0.71)
# Ending sulfur: 4
# Maximum θ:-11.187209513362617°
# Maximum φ:24.27799524607766°

# %%
readytosave=True

fig, axs=plt.subplots(1,1, figsize=(6,6))

max_theta = rotation_data[max_unit]['rotation_theta']
max_phi = rotation_data[max_unit]['rotation_phi']

if abs(max_phi)>abs(max_theta):
    lim=abs(max_phi)*1.05
else:
    lim=abs(max_theta)*1.05
    
lim=85


for unit, data in rotation_data.items():
    if unit!=max_unit:
        axs.scatter(data['rotation_phi'],data['rotation_theta'],edgecolor=datacolor,facecolors='white',linewidths=2, marker='o')
    else:
        axs.scatter(rotation_data[max_unit]['rotation_phi'],rotation_data[max_unit]['rotation_theta'], edgecolor='#cc0000',facecolors='white',linewidths=2, marker='o')
#axs.scatter(0,0,color="orange",edgecolor='black',marker='^',s=150)

axs.text(-lim+lim*0.1,lim*.45,fr'Max displacement:' '\n' fr'{max_distance*lattice_param:.2f} \AA' '\n' fr'$\theta$: {max_theta:.2f}$^\circ$' '\n' fr'$\phi$: {max_phi:.2f}$^\circ$',bbox=dict(
        facecolor='none',     # Transparent fill color for the box
       edgecolor="#cc0000",  # Match the box edge color with the marker
        linewidth=2,        # Box edge width
       boxstyle='round,pad=0.3'  # Rounded box with padding
  ))
    
axs.set_xlim([-lim,lim])
axs.set_ylim([-lim,lim])

axs.xaxis.set_major_locator(ticker.MaxNLocator(8))
axs.yaxis.set_major_locator(ticker.MaxNLocator(8))
axs.xaxis.set_minor_locator(AutoMinorLocator(2))
axs.yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(which='major', direction='in', length=6)
plt.tick_params(which='minor', direction='in', length=4)

axs.set_xlabel(r'$\phi$ ($^{\circ}$)')
axs.set_ylabel(r'$\theta$ ($^{\circ}$)')
axs.set_title(material)

plt.tight_layout()

if readytosave==True:
    png=''.join((saveloc,'/',cleaned_matname,'rotation summary','.png'))
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc)
    plt.savefig(png,dpi=800,format='png')


plt.show()
